# %% [markdown]
# ![sql](../../static/sql-logo.jpg)
#
# # A guide to databases, SQL, & using them with `pandas`

# %% [markdown]
# Let's start with Peter Bell's great blog piece [on relational databases](https://flatironschool.com/blog/an-introduction-to-the-relational-database).
#
# Themes:
# - Structured vs. Unstructured Data
# - Records (Rows) in Tables in Databases
# - Eliminating Redundancy

# %% [markdown]
# ## Learning goals:
# - Goal 1: Summarize the use case for sql in the data science skill set
# - Goal 2: Define key sql terminology
# - Goal 3: Get information about DB schema and table structure
# - Goal 4: Use basic SQL commands:
#     - Construct SQL queries
#     - Use JOIN to merge tables along logical columns
#     - Group Data with SQL
# - Goal 5: Query data from pandas dataframes using SQL
# - Goal 6: Convert SQL to pandas

# %% [markdown]
# ## Goal 1: Summarize
#
# [Netflix has a great article](https://medium.com/netflix-techblog/notebook-innovation-591ee3221233) describing three different data roles at their company, their different needs, and their toolsets.
#
# ![netflix](../../static/netflix-data-roles.jpeg)
#
# Examining that graphic, SQL shows up as one of the tools of the _Data Engineer_

# %% [markdown]
# Data Engineers provide the essential data architecture services that make data science possible.
#
# ![hierarchy](../../static/ai-hierachy.png)
#
# [Source: Monica Rogati’s fantastic Medium post “The AI Hierarchy of Needs”
# ](https://hackernoon.com/the-ai-hierarchy-of-needs-18f111fcc007)

# %% [markdown]
# ### What is a Relational Database?
#
# ![rdb](../../static/relational-dbms-model.png)
# [reference for image ](https://www.studytonight.com/dbms/database-model.php)

# %% [markdown]
# ### POPULAR RDBMS
#
# - SQLite
# - MySQL
# - PostgreSql
# - Oracle DB
# - SQL Server

# %% [markdown]
# ***
# ## Goal 2: Database terminology
#
# ### Relational Database Schema
#
# ![schema](../../static/MySQL_Schema_Music_Example.png)
#
# [source of image](https://database.guide/what-is-a-database-schema/)
#
# This sort of picture is sometimes called an **E**ntity **R**elationship **D**iagram. [Here](https://www.smartdraw.com/entity-relationship-diagram/) is another good resource for explaining typical ERD conventions.

# %% [markdown]
# ### Table columns view
# ![table example](../../static/columns.png)

# %% [markdown]
# ### Terminology
#
# - Schema
#     - [An excellent explainer](https://www.youtube.com/watch?v=3BZz8R7mqu0) on db schemas
# - Primary Key
# - Foreign Key
# - Structured queries
# - Views

# %% [markdown]
# ***
# ### SQLite
#
# ![sqlite](../../static/SQLite-Python.jpg)
#
# "SQLite is a C library that provides a lightweight disk-based database that doesn’t require a separate server process and allows accessing the database using a nonstandard variant of the SQL query language. Some applications can use SQLite for internal data storage. It’s also possible to prototype an application using SQLite and then port the code to a larger database such as PostgreSQL or Oracle." - [sqlite documentation](https://docs.python.org/2/library/sqlite3.html)

# %% [markdown]
# ## Goal 3: Get going with sqlite!

# %%
import sqlite3
import os
cd_dot_dot = os.pardir
data_path = os.path.join(cd_dot_dot, cd_dot_dot, 'data')

# %% [markdown]
# #### Load a DB object with `connect` and `cursor`

# %%
# !ls
# Out:
# lesson.ipynb

# %%
con = sqlite3.connect(os.path.join(data_path,'flights.db'))
cursor = con.cursor()
cursor2 = con.cursor()

# %% [markdown]
# #### Use sqlite_master to find all the tables in the schema
# Get the schema of a database from a db in sqlite

# %%
cursor.execute(
"""
SELECT name
FROM sqlite_master
WHERE type='table';
"""
)

# %%
print(cursor.fetchall())
# Out:
# [('airports',), ('airlines',), ('routes',)]

# %% [markdown]
# For more on "sqlite_master", see [here](https://www.techonthenet.com/sqlite/sys_tables/index.php).

# %% [markdown]
# #### Get information about one table
#
# **A note about** `execute`<br>
# Each time you use it, you reset the value of cursor

# %%
cursor.execute(
"""
SELECT *
FROM airports
"""
)

# %% [markdown]
# #### Use description

# %%
cursor.description
# Out:
# (('index', None, None, None, None, None, None),
#  ('id', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('city', None, None, None, None, None, None),
#  ('country', None, None, None, None, None, None),
#  ('code', None, None, None, None, None, None),
#  ('icao', None, None, None, None, None, None),
#  ('latitude', None, None, None, None, None, None),
#  ('longitude', None, None, None, None, None, None),
#  ('altitude', None, None, None, None, None, None),
#  ('offset', None, None, None, None, None, None),
#  ('dst', None, None, None, None, None, None),
#  ('timezone', None, None, None, None, None, None))

# %% [markdown]
# The septuple structure has to do with Python API [compatibility issues](https://kite.com/python/docs/sqlite3.Cursor.description).

# %% [markdown]
# #### Making fetch happen
#
# `.fetchall()` is how you get the query results out of the object.
#
# You can also `.fetchone()` or `.fetchmany()`. The latter takes a number of records to return as a parameter.

# %%
cursor.fetchmany(10)
# Out:
# [(0,
#   '1',
#   'Goroka',
#   'Goroka',
#   'Papua New Guinea',
#   'GKA',
#   'AYGA',
#   '-6.081689',
#   '145.391881',
#   '5282',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (1,
#   '2',
#   'Madang',
#   'Madang',
#   'Papua New Guinea',
#   'MAG',
#   'AYMD',
#   '-5.207083',
#   '145.7887',
#   '20',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (2,
#   '3',
#   'Mount Hagen',
#   'Mount Hagen',
#   'Papua New Guinea',
#   'HGU',
#   'AYMH',
#   '-5.826789',
#   '144.295861',
#   '5388',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (3,
#   '4',
#   'Nadzab',
#   'Nadzab',
#   'Papua New Guinea',
#   'LAE',
#   'AYNZ',
#   '-6.569828',
#   '146.726242',
#   '239',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (4,
#   '5',
#   'Port Moresby Jacksons Intl',
#   'Port Moresby',
#   'Papua New Guinea',
#   'POM',
#   'AYPY',
#   '-9.443383',
#   '147.22005',
#   '146',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (5,
#   '6',
#   'Wewak Intl',
#   'Wewak',
#   'Papua New Guinea',
#   'WWK',
#   'AYWK',
#   '-3.583828',
#   '143.669186',
#   '19',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (6,
#   '7',
#   'Narsarsuaq',
#   'Narssarssuaq',
#   'Greenland',
#   'UAK',
#   'BGBW',
#   '61.160517',
#   '-45.425978',
#   '112',
#   '-3',
#   'E',
#   'America/Godthab'),
#  (7,
#   '8',
#   'Nuuk',
#   'Godthaab',
#   'Greenland',
#   'GOH',
#   'BGGH',
#   '64.190922',
#   '-51.678064',
#   '283',
#   '-3',
#   'E',
#   'America/Godthab'),
#  (8,
#   '9',
#   'Sondre Stromfjord',
#   'Sondrestrom',
#   'Greenland',
#   'SFJ',
#   'BGSF',
#   '67.016969',
#   '-50.689325',
#   '165',
#   '-3',
#   'E',
#   'America/Godthab'),
#  (9,
#   '10',
#   'Thule Air Base',
#   'Thule',
#   'Greenland',
#   'THU',
#   'BGTL',
#   '76.531203',
#   '-68.703161',
#   '251',
#   '-4',
#   'E',
#   'America/Thule')]

# %% [markdown]
# **Task:** Get the descriptive data for airlines and routes tables

# %%
cursor.execute(
    """
    SELECT *
    FROM airlines
    """
).description
# Out:
# (('index', None, None, None, None, None, None),
#  ('id', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('alias', None, None, None, None, None, None),
#  ('iata', None, None, None, None, None, None),
#  ('icao', None, None, None, None, None, None),
#  ('callsign', None, None, None, None, None, None),
#  ('country', None, None, None, None, None, None),
#  ('active', None, None, None, None, None, None))

# %%
cursor.execute(
    """SELECT *
    FROM routes
    """
).description
# Out:
# (('index', None, None, None, None, None, None),
#  ('airline', None, None, None, None, None, None),
#  ('airline_id', None, None, None, None, None, None),
#  ('source', None, None, None, None, None, None),
#  ('source_id', None, None, None, None, None, None),
#  ('dest', None, None, None, None, None, None),
#  ('dest_id', None, None, None, None, None, None),
#  ('codeshare', None, None, None, None, None, None),
#  ('stops', None, None, None, None, None, None),
#  ('equipment', None, None, None, None, None, None))

# %% [markdown]
# ***
# ## Goal 4: Use basic SQL commands
# - Construct SQL queries
# - Use JOIN to merge tables along logical columns
# - Grouping Data with SQL

# %% [markdown]
# ### Construct SQL queries

# %% [markdown]
# **SELECT**

# %% [markdown]
# **FROM**

# %% [markdown]
# **WHERE**

# %% [markdown]
# **GROUP BY**

# %% [markdown]
# **ORDER BY**

# %% [markdown]
# **LIMIT**

# %% [markdown]
# #### Options for each:

# %% [markdown]
# **Select**:  `DISTINCT`, using `AS` to rename columns, single number aggregates, `COUNT()` to count, `*` for "all"

# %% [markdown]
# **From:** also uses aliasing with `AS`

# %% [markdown]
# **Where**: `=`, `BETWEEN`, `IN`, wildcards with `%`, `AND`, `OR`, `NOT` pattern matching with `LIKE` and `ILIKE`

# %% [markdown]
# **Order by**: `ASC` and `DESC`

# %% [markdown]
# **Limit**:  #

# %% [markdown]
# ***

# %% [markdown]
# **Exercises**:
# - Select only active airlines in the United Kingdom from the airlines table <br/>
# Hint: The values for 'active' are 'Y' and 'N'.
# - Select the unique list of countries with airports

# %%
# Your code here
cursor.execute("""SELECT * 
                  FROM airlines
                  WHERE active = 'Y'
                  AND country = 'United Kingdom'""").fetchall()
# Out:
# [(111,
#   '112',
#   'Astraeus',
#   '\\N',
#   '5W',
#   'AEU',
#   'FLYSTAR',
#   'United Kingdom',
#   'Y'),
#  (491,
#   '492',
#   'Air Southwest',
#   '\\N',
#   None,
#   'WOW',
#   'SWALLOW',
#   'United Kingdom',
#   'Y'),
#  (507,
#   '508',
#   'Aurigny Air Services',
#   '\\N',
#   'GR',
#   'AUR',
#   'AYLINE',
#   'United Kingdom',
#   'Y'),
#  (564,
#   '565',
#   'Air Wales',
#   '\\N',
#   '6G',
#   'AWW',
#   'RED DRAGON',
#   'United Kingdom',
#   'Y'),
#  (664,
#   '665',
#   'AD Aviation',
#   '\\N',
#   None,
#   'VUE',
#   'FLIGHTVUE',
#   'United Kingdom',
#   'Y'),
#  (689, '690', 'Air Foyle', '\\N', 'GS', 'UPA', 'FOYLE', 'United Kingdom', 'Y'),
#  (1353,
#   '1355',
#   'British Airways',
#   '\\N',
#   'BA',
#   'BAW',
#   'SPEEDBIRD',
#   'United Kingdom',
#   'Y'),
#  (1409,
#   '1411',
#   'British International Helicopters',
#   '\\N',
#   'BS',
#   'BIH',
#   'BRINTEL',
#   'United Kingdom',
#   'Y'),
#  (1435,
#   '1437',
#   'bmi',
#   'bmi British Midland',
#   'BD',
#   'BMA',
#   'MIDLAND',
#   'United Kingdom',
#   'Y'),
#  (1439, '1441', 'bmibaby', '\\N', 'WW', 'BMI', 'BABY', 'United Kingdom', 'Y'),
#  (1443,
#   '1445',
#   'British Midland Regional',
#   '\\N',
#   None,
#   'BMR',
#   None,
#   'United Kingdom',
#   'Y'),
#  (1541,
#   '1543',
#   'British Mediterranean Airways',
#   '\\N',
#   'KJ',
#   'LAJ',
#   'BEE MED',
#   'United Kingdom',
#   'Y'),
#  (1793,
#   '1795',
#   'BA CityFlyer',
#   '\\N',
#   'CJ',
#   'CFE',
#   'FLYER',
#   'United Kingdom',
#   'Y'),
#  (1921,
#   '1923',
#   'Crest Aviation',
#   '\\N',
#   None,
#   'CAN',
#   'CREST',
#   'United Kingdom',
#   'Y'),
#  (2115,
#   '2117',
#   'Eastern Airways',
#   '\\N',
#   'T3',
#   'EZE',
#   'EASTFLIGHT',
#   'United Kingdom',
#   'Y'),
#  (2262,
#   '2264',
#   'Excel Airways',
#   '\\N',
#   'JN',
#   'XLA',
#   'EXPO',
#   'United Kingdom',
#   'Y'),
#  (2263,
#   '2265',
#   'Excel Charter',
#   '\\N',
#   None,
#   'XEL',
#   'HELI EXCEL',
#   'United Kingdom',
#   'Y'),
#  (2295,
#   '2297',
#   'easyJet',
#   'EasyJet Airline',
#   'U2',
#   'EZY',
#   'EASY',
#   'United Kingdom',
#   'Y'),
#  (2355,
#   '2357',
#   'First Choice Airways',
#   '\\N',
#   'DP',
#   'FCA',
#   'JETSET',
#   'United Kingdom',
#   'Y'),
#  (2393,
#   '2395',
#   'Flightline',
#   '\\N',
#   'B5',
#   'FLT',
#   'FLIGHTLINE',
#   'United Kingdom',
#   'Y'),
#  (2419, '2421', 'Flybe', '\\N', 'BE', 'BEE', 'JERSEY', 'United Kingdom', 'Y'),
#  (2423,
#   '2425',
#   'Flyglobespan',
#   '\\N',
#   'B4',
#   'GSM',
#   'GLOBESPAN',
#   'United Kingdom',
#   'Y'),
#  (2484,
#   '2486',
#   'GB Airways',
#   '\\N',
#   'GT',
#   'GBL',
#   'GEEBEE AIRWAYS',
#   'United Kingdom',
#   'Y'),
#  (2758,
#   '2761',
#   'Highland Airways',
#   '\\N',
#   None,
#   'HWY',
#   'HIWAY',
#   'United Kingdom',
#   'Y'),
#  (3023,
#   '3026',
#   'Jet2.com',
#   '\\N',
#   'LS',
#   'EXS',
#   'CHANNEX',
#   'United Kingdom',
#   'Y'),
#  (3526,
#   '3532',
#   'Monarch Airlines',
#   '\\N',
#   'ZB',
#   'MON',
#   'MONARCH',
#   'United Kingdom',
#   'Y'),
#  (3562,
#   '3568',
#   'MyTravel Airways',
#   '\\N',
#   'VZ',
#   'MYT',
#   'KESTREL',
#   'United Kingdom',
#   'Y'),
#  (3678,
#   '3684',
#   'Norfolk County Flight College',
#   '\\N',
#   None,
#   'NCF',
#   'COUNTY',
#   'United Kingdom',
#   'Y'),
#  (4106,
#   '4113',
#   'Kinloss Flying Training Unit',
#   '\\N',
#   None,
#   'KIN',
#   'KINLOSS',
#   'United Kingdom',
#   'Y'),
#  (4314,
#   '4323',
#   'ScotAirways',
#   '\\N',
#   None,
#   'SAY',
#   'SUCKLING',
#   'United Kingdom',
#   'Y'),
#  (4886,
#   '4897',
#   'Thomas Cook Airlines',
#   '\\N',
#   'MT',
#   'TCX',
#   'KESTREL',
#   'United Kingdom',
#   'Y'),
#  (5002,
#   '5013',
#   'Thomsonfly',
#   '\\N',
#   'BY',
#   'TOM',
#   'TOMSON',
#   'United Kingdom',
#   'Y'),
#  (5329,
#   '5347',
#   'Virgin Atlantic Airways',
#   '\\N',
#   'VS',
#   'VIR',
#   'VIRGIN',
#   'United Kingdom',
#   'Y'),
#  (5589,
#   '10642',
#   'Jc royal.britannica',
#   None,
#   None,
#   'JRB',
#   None,
#   'United Kingdom',
#   'Y'),
#  (5724,
#   '13936',
#   'Royal European Airlines',
#   None,
#   '69',
#   '\\N',
#   None,
#   'United Kingdom',
#   'Y'),
#  (5782,
#   '16261',
#   'CB Airways UK ( Interliging Flights )',
#   None,
#   '1F',
#   'CIF',
#   None,
#   'United Kingdom',
#   'Y'),
#  (5848,
#   '16881',
#   'Air Cudlua',
#   'Air Cudlua',
#   None,
#   'CUD',
#   'Cudlua',
#   'United Kingdom',
#   'Y'),
#  (6010,
#   '19525',
#   'BBN-Airways',
#   'BlackBurn',
#   None,
#   'EGH',
#   'BBN',
#   'United Kingdom',
#   'Y'),
#  (6022,
#   '19677',
#   'Rainbow Air Euro',
#   'Rainbow Air EU',
#   'RU',
#   'RUE',
#   'Rainbow Air',
#   'United Kingdom',
#   'Y'),
#  (6034,
#   '19808',
#   'All Europe',
#   'All Europe',
#   'N9',
#   'N99',
#   None,
#   'United Kingdom',
#   'Y')]

# %%
# Your code here
cursor.execute(
    """SELECT DISTINCT country
       FROM airports
       LIMIT 3
    """
).fetchall()
# Out:
# [('Papua New Guinea',), ('Greenland',), ('Iceland',)]

# %% [markdown]
# ### SQL Joins

# %% [markdown]
# SQL joins can be used to both **add** data to a table and **remove** data from a table.

# %% [markdown]
# ![venn](../../static/venn.png)

# %% [markdown]
# **Exercise**: Write a query that will join the latitude and longitude data from the airports table to the information on the routes table. <br/>
# Hint: Which column can serve as the link between the two tables? That is, which column in `airports` can serve as foreign key to `routes`?

# %%
# Your code here
cursor.execute(
    """SELECT*FROM routes r
       JOIN airports a
       ON a.code = r.dest
    """
).fetchall()
# Out:
# [(0,
#   '2B',
#   '410',
#   'AER',
#   '2965',
#   'KZN',
#   '2990',
#   None,
#   '0',
#   'CR2',
#   2910,
#   '2990',
#   'Kazan',
#   'Kazan',
#   'Russia',
#   'KZN',
#   'UWKD',
#   '55.606186',
#   '49.278728',
#   '411',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (1,
#   '2B',
#   '410',
#   'ASF',
#   '2966',
#   'KZN',
#   '2990',
#   None,
#   '0',
#   'CR2',
#   2910,
#   '2990',
#   'Kazan',
#   'Kazan',
#   'Russia',
#   'KZN',
#   'UWKD',
#   '55.606186',
#   '49.278728',
#   '411',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (2,
#   '2B',
#   '410',
#   'ASF',
#   '2966',
#   'MRV',
#   '2962',
#   None,
#   '0',
#   'CR2',
#   2883,
#   '2962',
#   'Mineralnyye Vody',
#   'Mineralnye Vody',
#   'Russia',
#   'MRV',
#   'URMM',
#   '44.225072',
#   '43.081889',
#   '1054',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (3,
#   '2B',
#   '410',
#   'CEK',
#   '2968',
#   'KZN',
#   '2990',
#   None,
#   '0',
#   'CR2',
#   2910,
#   '2990',
#   'Kazan',
#   'Kazan',
#   'Russia',
#   'KZN',
#   'UWKD',
#   '55.606186',
#   '49.278728',
#   '411',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (4,
#   '2B',
#   '410',
#   'CEK',
#   '2968',
#   'OVB',
#   '4078',
#   None,
#   '0',
#   'CR2',
#   3969,
#   '4078',
#   'Tolmachevo',
#   'Novosibirsk',
#   'Russia',
#   'OVB',
#   'UNNT',
#   '55.012622',
#   '82.650656',
#   '365',
#   '7',
#   'N',
#   'Asia/Omsk'),
#  (5,
#   '2B',
#   '410',
#   'DME',
#   '4029',
#   'KZN',
#   '2990',
#   None,
#   '0',
#   'CR2',
#   2910,
#   '2990',
#   'Kazan',
#   'Kazan',
#   'Russia',
#   'KZN',
#   'UWKD',
#   '55.606186',
#   '49.278728',
#   '411',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (6,
#   '2B',
#   '410',
#   'DME',
#   '4029',
#   'NBC',
#   '6969',
#   None,
#   '0',
#   'CR2',
#   5544,
#   '6969',
#   'Begishevo',
#   'Nizhnekamsk',
#   'Russia',
#   'NBC',
#   'UWKE',
#   '55.34',
#   '52.06',
#   '50',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (8,
#   '2B',
#   '410',
#   'DME',
#   '4029',
#   'UUA',
#   '6160',
#   None,
#   '0',
#   'CR2',
#   5033,
#   '6160',
#   'Bugulma Airport',
#   'Bugulma',
#   'Russia',
#   'UUA',
#   'UWKB',
#   '54.64',
#   '52.8017',
#   '991',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (9,
#   '2B',
#   '410',
#   'EGO',
#   '6156',
#   'KGD',
#   '2952',
#   None,
#   '0',
#   'CR2',
#   2874,
#   '2952',
#   'Khrabrovo',
#   'Kaliningrad',
#   'Russia',
#   'KGD',
#   'UMKK',
#   '54.89005',
#   '20.592633',
#   '42',
#   '3',
#   'N',
#   'Europe/Kaliningrad'),
#  (10,
#   '2B',
#   '410',
#   'EGO',
#   '6156',
#   'KZN',
#   '2990',
#   None,
#   '0',
#   'CR2',
#   2910,
#   '2990',
#   'Kazan',
#   'Kazan',
#   'Russia',
#   'KZN',
#   'UWKD',
#   '55.606186',
#   '49.278728',
#   '411',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (11,
#   '2B',
#   '410',
#   'GYD',
#   '2922',
#   'NBC',
#   '6969',
#   None,
#   '0',
#   'CR2',
#   5544,
#   '6969',
#   'Begishevo',
#   'Nizhnekamsk',
#   'Russia',
#   'NBC',
#   'UWKE',
#   '55.34',
#   '52.06',
#   '50',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (12,
#   '2B',
#   '410',
#   'KGD',
#   '2952',
#   'EGO',
#   '6156',
#   None,
#   '0',
#   'CR2',
#   5029,
#   '6156',
#   'Belgorod International Airport',
#   'Belgorod',
#   'Russia',
#   'EGO',
#   'UUOB',
#   '50.6438',
#   '36.5901',
#   '735',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (13,
#   '2B',
#   '410',
#   'KZN',
#   '2990',
#   'AER',
#   '2965',
#   None,
#   '0',
#   'CR2',
#   2886,
#   '2965',
#   'Sochi',
#   'Sochi',
#   'Russia',
#   'AER',
#   'URSS',
#   '43.449928',
#   '39.956589',
#   '89',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (14,
#   '2B',
#   '410',
#   'KZN',
#   '2990',
#   'ASF',
#   '2966',
#   None,
#   '0',
#   'CR2',
#   2887,
#   '2966',
#   'Astrakhan',
#   'Astrakhan',
#   'Russia',
#   'ASF',
#   'URWA',
#   '46.283333',
#   '48.006278',
#   '-65',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (15,
#   '2B',
#   '410',
#   'KZN',
#   '2990',
#   'CEK',
#   '2968',
#   None,
#   '0',
#   'CR2',
#   2889,
#   '2968',
#   'Balandino',
#   'Chelyabinsk',
#   'Russia',
#   'CEK',
#   'USCC',
#   '55.305836',
#   '61.503333',
#   '769',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (16,
#   '2B',
#   '410',
#   'KZN',
#   '2990',
#   'DME',
#   '4029',
#   None,
#   '0',
#   'CR2',
#   3921,
#   '4029',
#   'Domododevo',
#   'Moscow',
#   'Russia',
#   'DME',
#   'UUDD',
#   '55.408611',
#   '37.906111',
#   '588',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (17,
#   '2B',
#   '410',
#   'KZN',
#   '2990',
#   'EGO',
#   '6156',
#   None,
#   '0',
#   'CR2',
#   5029,
#   '6156',
#   'Belgorod International Airport',
#   'Belgorod',
#   'Russia',
#   'EGO',
#   'UUOB',
#   '50.6438',
#   '36.5901',
#   '735',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (18,
#   '2B',
#   '410',
#   'KZN',
#   '2990',
#   'LED',
#   '2948',
#   None,
#   '0',
#   'CR2',
#   2870,
#   '2948',
#   'Pulkovo',
#   'St. Petersburg',
#   'Russia',
#   'LED',
#   'ULLI',
#   '59.800292',
#   '30.262503',
#   '78',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (19,
#   '2B',
#   '410',
#   'KZN',
#   '2990',
#   'SVX',
#   '2975',
#   None,
#   '0',
#   'CR2',
#   2895,
#   '2975',
#   'Koltsovo',
#   'Yekaterinburg',
#   'Russia',
#   'SVX',
#   'USSS',
#   '56.743108',
#   '60.802728',
#   '764',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (20,
#   '2B',
#   '410',
#   'LED',
#   '2948',
#   'KZN',
#   '2990',
#   None,
#   '0',
#   'CR2',
#   2910,
#   '2990',
#   'Kazan',
#   'Kazan',
#   'Russia',
#   'KZN',
#   'UWKD',
#   '55.606186',
#   '49.278728',
#   '411',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (21,
#   '2B',
#   '410',
#   'LED',
#   '2948',
#   'NBC',
#   '6969',
#   None,
#   '0',
#   'CR2',
#   5544,
#   '6969',
#   'Begishevo',
#   'Nizhnekamsk',
#   'Russia',
#   'NBC',
#   'UWKE',
#   '55.34',
#   '52.06',
#   '50',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (22,
#   '2B',
#   '410',
#   'LED',
#   '2948',
#   'UUA',
#   '6160',
#   None,
#   '0',
#   'CR2',
#   5033,
#   '6160',
#   'Bugulma Airport',
#   'Bugulma',
#   'Russia',
#   'UUA',
#   'UWKB',
#   '54.64',
#   '52.8017',
#   '991',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (23,
#   '2B',
#   '410',
#   'MRV',
#   '2962',
#   'ASF',
#   '2966',
#   None,
#   '0',
#   'CR2',
#   2887,
#   '2966',
#   'Astrakhan',
#   'Astrakhan',
#   'Russia',
#   'ASF',
#   'URWA',
#   '46.283333',
#   '48.006278',
#   '-65',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (24,
#   '2B',
#   '410',
#   'NBC',
#   '6969',
#   'DME',
#   '4029',
#   None,
#   '0',
#   'CR2',
#   3921,
#   '4029',
#   'Domododevo',
#   'Moscow',
#   'Russia',
#   'DME',
#   'UUDD',
#   '55.408611',
#   '37.906111',
#   '588',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (25,
#   '2B',
#   '410',
#   'NBC',
#   '6969',
#   'GYD',
#   '2922',
#   None,
#   '0',
#   'CR2',
#   2846,
#   '2922',
#   'Heydar Aliyev',
#   'Baku',
#   'Azerbaijan',
#   'GYD',
#   'UBBB',
#   '40.4675',
#   '50.046667',
#   '10',
#   '4',
#   'E',
#   'Asia/Baku'),
#  (26,
#   '2B',
#   '410',
#   'NBC',
#   '6969',
#   'LED',
#   '2948',
#   None,
#   '0',
#   'CR2',
#   2870,
#   '2948',
#   'Pulkovo',
#   'St. Petersburg',
#   'Russia',
#   'LED',
#   'ULLI',
#   '59.800292',
#   '30.262503',
#   '78',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (27,
#   '2B',
#   '410',
#   'NBC',
#   '6969',
#   'SVX',
#   '2975',
#   None,
#   '0',
#   'CR2',
#   2895,
#   '2975',
#   'Koltsovo',
#   'Yekaterinburg',
#   'Russia',
#   'SVX',
#   'USSS',
#   '56.743108',
#   '60.802728',
#   '764',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (28,
#   '2B',
#   '410',
#   'NJC',
#   '2972',
#   'SVX',
#   '2975',
#   None,
#   '0',
#   'CR2',
#   2895,
#   '2975',
#   'Koltsovo',
#   'Yekaterinburg',
#   'Russia',
#   'SVX',
#   'USSS',
#   '56.743108',
#   '60.802728',
#   '764',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (29,
#   '2B',
#   '410',
#   'NJC',
#   '2972',
#   'UUA',
#   '6160',
#   None,
#   '0',
#   'CR2',
#   5033,
#   '6160',
#   'Bugulma Airport',
#   'Bugulma',
#   'Russia',
#   'UUA',
#   'UWKB',
#   '54.64',
#   '52.8017',
#   '991',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (30,
#   '2B',
#   '410',
#   'NUX',
#   '4364',
#   'SVX',
#   '2975',
#   None,
#   '0',
#   'CR2',
#   2895,
#   '2975',
#   'Koltsovo',
#   'Yekaterinburg',
#   'Russia',
#   'SVX',
#   'USSS',
#   '56.743108',
#   '60.802728',
#   '764',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (31,
#   '2B',
#   '410',
#   'OVB',
#   '4078',
#   'CEK',
#   '2968',
#   None,
#   '0',
#   'CR2',
#   2889,
#   '2968',
#   'Balandino',
#   'Chelyabinsk',
#   'Russia',
#   'CEK',
#   'USCC',
#   '55.305836',
#   '61.503333',
#   '769',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (32,
#   '2B',
#   '410',
#   'OVB',
#   '4078',
#   'SVX',
#   '2975',
#   None,
#   '0',
#   'CR2',
#   2895,
#   '2975',
#   'Koltsovo',
#   'Yekaterinburg',
#   'Russia',
#   'SVX',
#   'USSS',
#   '56.743108',
#   '60.802728',
#   '764',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (33,
#   '2B',
#   '410',
#   'SVX',
#   '2975',
#   'KZN',
#   '2990',
#   None,
#   '0',
#   'CR2',
#   2910,
#   '2990',
#   'Kazan',
#   'Kazan',
#   'Russia',
#   'KZN',
#   'UWKD',
#   '55.606186',
#   '49.278728',
#   '411',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (34,
#   '2B',
#   '410',
#   'SVX',
#   '2975',
#   'NBC',
#   '6969',
#   None,
#   '0',
#   'CR2',
#   5544,
#   '6969',
#   'Begishevo',
#   'Nizhnekamsk',
#   'Russia',
#   'NBC',
#   'UWKE',
#   '55.34',
#   '52.06',
#   '50',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (35,
#   '2B',
#   '410',
#   'SVX',
#   '2975',
#   'NJC',
#   '2972',
#   None,
#   '0',
#   'CR2',
#   2892,
#   '2972',
#   'Nizhnevartovsk',
#   'Nizhnevartovsk',
#   'Russia',
#   'NJC',
#   'USNN',
#   '60.949272',
#   '76.483617',
#   '177',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (36,
#   '2B',
#   '410',
#   'SVX',
#   '2975',
#   'NUX',
#   '4364',
#   None,
#   '0',
#   'CR2',
#   4251,
#   '4364',
#   'Novyi Urengoy',
#   'Novy Urengoy',
#   'Russia',
#   'NUX',
#   'USMU',
#   '66.041811',
#   '76.313938',
#   '20',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (37,
#   '2B',
#   '410',
#   'SVX',
#   '2975',
#   'OVB',
#   '4078',
#   None,
#   '0',
#   'CR2',
#   3969,
#   '4078',
#   'Tolmachevo',
#   'Novosibirsk',
#   'Russia',
#   'OVB',
#   'UNNT',
#   '55.012622',
#   '82.650656',
#   '365',
#   '7',
#   'N',
#   'Asia/Omsk'),
#  (38,
#   '2B',
#   '410',
#   'TGK',
#   '\\N',
#   'DME',
#   '4029',
#   None,
#   '0',
#   'CR2',
#   3921,
#   '4029',
#   'Domododevo',
#   'Moscow',
#   'Russia',
#   'DME',
#   'UUDD',
#   '55.408611',
#   '37.906111',
#   '588',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (39,
#   '2B',
#   '410',
#   'UUA',
#   '6160',
#   'DME',
#   '4029',
#   None,
#   '0',
#   'CR2',
#   3921,
#   '4029',
#   'Domododevo',
#   'Moscow',
#   'Russia',
#   'DME',
#   'UUDD',
#   '55.408611',
#   '37.906111',
#   '588',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (40,
#   '2B',
#   '410',
#   'UUA',
#   '6160',
#   'LED',
#   '2948',
#   None,
#   '0',
#   'CR2',
#   2870,
#   '2948',
#   'Pulkovo',
#   'St. Petersburg',
#   'Russia',
#   'LED',
#   'ULLI',
#   '59.800292',
#   '30.262503',
#   '78',
#   '4',
#   'N',
#   'Europe/Moscow'),
#  (41,
#   '2B',
#   '410',
#   'UUA',
#   '6160',
#   'NJC',
#   '2972',
#   None,
#   '0',
#   'CR2',
#   2892,
#   '2972',
#   'Nizhnevartovsk',
#   'Nizhnevartovsk',
#   'Russia',
#   'NJC',
#   'USNN',
#   '60.949272',
#   '76.483617',
#   '177',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (42,
#   '2G',
#   '1654',
#   'BTK',
#   '2936',
#   'IKT',
#   '2937',
#   None,
#   '0',
#   'A81',
#   2860,
#   '2937',
#   'Irkutsk',
#   'Irkutsk',
#   'Russia',
#   'IKT',
#   'UIII',
#   '52.268028',
#   '104.388975',
#   '1675',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (43,
#   '2G',
#   '1654',
#   'BTK',
#   '2936',
#   'OVB',
#   '4078',
#   None,
#   '0',
#   'A81',
#   3969,
#   '4078',
#   'Tolmachevo',
#   'Novosibirsk',
#   'Russia',
#   'OVB',
#   'UNNT',
#   '55.012622',
#   '82.650656',
#   '365',
#   '7',
#   'N',
#   'Asia/Omsk'),
#  (44,
#   '2G',
#   '1654',
#   'CEK',
#   '2968',
#   'OVB',
#   '4078',
#   None,
#   '0',
#   'A81',
#   3969,
#   '4078',
#   'Tolmachevo',
#   'Novosibirsk',
#   'Russia',
#   'OVB',
#   'UNNT',
#   '55.012622',
#   '82.650656',
#   '365',
#   '7',
#   'N',
#   'Asia/Omsk'),
#  (45,
#   '2G',
#   '1654',
#   'HTA',
#   '2935',
#   'IKT',
#   '2937',
#   None,
#   '0',
#   'AN4',
#   2860,
#   '2937',
#   'Irkutsk',
#   'Irkutsk',
#   'Russia',
#   'IKT',
#   'UIII',
#   '52.268028',
#   '104.388975',
#   '1675',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (46,
#   '2G',
#   '1654',
#   'IKT',
#   '2937',
#   'BTK',
#   '2936',
#   None,
#   '0',
#   'A81',
#   2859,
#   '2936',
#   'Bratsk',
#   'Bratsk',
#   'Russia',
#   'BTK',
#   'UIBB',
#   '56.370556',
#   '101.698331',
#   '1610',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (47,
#   '2G',
#   '1654',
#   'IKT',
#   '2937',
#   'HTA',
#   '2935',
#   None,
#   '0',
#   'AN4',
#   2858,
#   '2935',
#   'Kadala',
#   'Chita',
#   'Russia',
#   'HTA',
#   'UIAA',
#   '52.026317',
#   '113.305556',
#   '2272',
#   '10',
#   'N',
#   'Asia/Yakutsk'),
#  (49,
#   '2G',
#   '1654',
#   'IKT',
#   '2937',
#   'ODO',
#   '8944',
#   None,
#   '0',
#   'AN4',
#   7510,
#   '8944',
#   'Bodaibo',
#   'Bodaibo',
#   'Russia',
#   'ODO',
#   'UIKB',
#   '57.5137',
#   '114.1348',
#   '940',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (50,
#   '2G',
#   '1654',
#   'IKT',
#   '2937',
#   'OVB',
#   '4078',
#   None,
#   '0',
#   'A81',
#   3969,
#   '4078',
#   'Tolmachevo',
#   'Novosibirsk',
#   'Russia',
#   'OVB',
#   'UNNT',
#   '55.012622',
#   '82.650656',
#   '365',
#   '7',
#   'N',
#   'Asia/Omsk'),
#  (51,
#   '2G',
#   '1654',
#   'IKT',
#   '2937',
#   'UKX',
#   '6924',
#   None,
#   '0',
#   'AN4',
#   5405,
#   '6924',
#   'Ust-Kut',
#   'Ust-Kut',
#   'Russia',
#   'UKX',
#   'UITT',
#   '56.85',
#   '105.7167',
#   '2033',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (52,
#   '2G',
#   '1654',
#   'IKT',
#   '2937',
#   'ULK',
#   '9026',
#   None,
#   '0',
#   'AN4',
#   7591,
#   '9026',
#   'Lensk',
#   'Lensk',
#   'Russia',
#   'ULK',
#   'UERL',
#   '60.723',
#   '114.825',
#   '843',
#   '10',
#   'U',
#   'Asia/Yakutsk'),
#  (53,
#   '2G',
#   '1654',
#   'IKT',
#   '2937',
#   'YKS',
#   '2923',
#   None,
#   '0',
#   'A81',
#   2847,
#   '2923',
#   'Yakutsk',
#   'Yakutsk',
#   'Russia',
#   'YKS',
#   'UEEE',
#   '62.09325',
#   '129.770672',
#   '325',
#   '10',
#   'N',
#   'Asia/Yakutsk'),
#  (54,
#   '2G',
#   '1654',
#   'KCK',
#   '\\N',
#   'IKT',
#   '2937',
#   None,
#   '0',
#   'AN4',
#   2860,
#   '2937',
#   'Irkutsk',
#   'Irkutsk',
#   'Russia',
#   'IKT',
#   'UIII',
#   '52.268028',
#   '104.388975',
#   '1675',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (55,
#   '2G',
#   '1654',
#   'MJZ',
#   '2925',
#   'OVB',
#   '4078',
#   None,
#   '0',
#   'A81',
#   3969,
#   '4078',
#   'Tolmachevo',
#   'Novosibirsk',
#   'Russia',
#   'OVB',
#   'UNNT',
#   '55.012622',
#   '82.650656',
#   '365',
#   '7',
#   'N',
#   'Asia/Omsk'),
#  (56,
#   '2G',
#   '1654',
#   'ODO',
#   '8944',
#   'IKT',
#   '2937',
#   None,
#   '0',
#   'AN4',
#   2860,
#   '2937',
#   'Irkutsk',
#   'Irkutsk',
#   'Russia',
#   'IKT',
#   'UIII',
#   '52.268028',
#   '104.388975',
#   '1675',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (57,
#   '2G',
#   '1654',
#   'OVB',
#   '4078',
#   'BTK',
#   '2936',
#   None,
#   '0',
#   'A81',
#   2859,
#   '2936',
#   'Bratsk',
#   'Bratsk',
#   'Russia',
#   'BTK',
#   'UIBB',
#   '56.370556',
#   '101.698331',
#   '1610',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (58,
#   '2G',
#   '1654',
#   'OVB',
#   '4078',
#   'CEK',
#   '2968',
#   None,
#   '0',
#   'A81',
#   2889,
#   '2968',
#   'Balandino',
#   'Chelyabinsk',
#   'Russia',
#   'CEK',
#   'USCC',
#   '55.305836',
#   '61.503333',
#   '769',
#   '6',
#   'N',
#   'Asia/Yekaterinburg'),
#  (59,
#   '2G',
#   '1654',
#   'OVB',
#   '4078',
#   'IKT',
#   '2937',
#   None,
#   '0',
#   'A81',
#   2860,
#   '2937',
#   'Irkutsk',
#   'Irkutsk',
#   'Russia',
#   'IKT',
#   'UIII',
#   '52.268028',
#   '104.388975',
#   '1675',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (60,
#   '2G',
#   '1654',
#   'UKX',
#   '6924',
#   'IKT',
#   '2937',
#   None,
#   '0',
#   'AN4',
#   2860,
#   '2937',
#   'Irkutsk',
#   'Irkutsk',
#   'Russia',
#   'IKT',
#   'UIII',
#   '52.268028',
#   '104.388975',
#   '1675',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (61,
#   '2G',
#   '1654',
#   'ULK',
#   '9026',
#   'IKT',
#   '2937',
#   None,
#   '0',
#   'AN4',
#   2860,
#   '2937',
#   'Irkutsk',
#   'Irkutsk',
#   'Russia',
#   'IKT',
#   'UIII',
#   '52.268028',
#   '104.388975',
#   '1675',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (62,
#   '2G',
#   '1654',
#   'YKS',
#   '2923',
#   'IKT',
#   '2937',
#   None,
#   '0',
#   'A81',
#   2860,
#   '2937',
#   'Irkutsk',
#   'Irkutsk',
#   'Russia',
#   'IKT',
#   'UIII',
#   '52.268028',
#   '104.388975',
#   '1675',
#   '9',
#   'N',
#   'Asia/Irkutsk'),
#  (63,
#   '2I',
#   '8359',
#   'AYP',
#   '2786',
#   'LIM',
#   '2789',
#   None,
#   '0',
#   '142',
#   2717,
#   '2789',
#   'Jorge Chavez Intl',
#   'Lima',
#   'Peru',
#   'LIM',
#   'SPIM',
#   '-12.021889',
#   '-77.114319',
#   '113',
#   '-5',
#   'U',
#   'America/Lima'),
#  (64,
#   '2I',
#   '8359',
#   'CUZ',
#   '2812',
#   'LIM',
#   '2789',
#   None,
#   '0',
#   '142 141',
#   2717,
#   '2789',
#   'Jorge Chavez Intl',
#   'Lima',
#   'Peru',
#   'LIM',
#   'SPIM',
#   '-12.021889',
#   '-77.114319',
#   '113',
#   '-5',
#   'U',
#   'America/Lima'),
#  (65,
#   '2I',
#   '8359',
#   'CUZ',
#   '2812',
#   'PEM',
#   '2808',
#   None,
#   '0',
#   '142',
#   2735,
#   '2808',
#   'Padre Aldamiz',
#   'Puerto Maldonado',
#   'Peru',
#   'PEM',
#   'SPTU',
#   '-12.613611',
#   '-69.228611',
#   '659',
#   '-5',
#   'U',
#   'America/Lima'),
#  (66,
#   '2I',
#   '8359',
#   'HUU',
#   '6067',
#   'LIM',
#   '2789',
#   None,
#   '0',
#   '141',
#   2717,
#   '2789',
#   'Jorge Chavez Intl',
#   'Lima',
#   'Peru',
#   'LIM',
#   'SPIM',
#   '-12.021889',
#   '-77.114319',
#   '113',
#   '-5',
#   'U',
#   'America/Lima'),
#  (67,
#   '2I',
#   '8359',
#   'IQT',
#   '2801',
#   'PCL',
#   '2781',
#   None,
#   '0',
#   '143',
#   2709,
#   '2781',
#   'Cap Fap David Abenzur Rengifo Intl',
#   'Pucallpa',
#   'Peru',
#   'PCL',
#   'SPCL',
#   '-8.377939',
#   '-74.574297',
#   '513',
#   '-5',
#   'U',
#   'America/Lima'),
#  (68,
#   '2I',
#   '8359',
#   'IQT',
#   '2801',
#   'TPP',
#   '2806',
#   None,
#   '0',
#   '142',
#   2733,
#   '2806',
#   'Cadete Guillermo Del Castillo Paredes',
#   'Tarapoto',
#   'Peru',
#   'TPP',
#   'SPST',
#   '-6.508742',
#   '-76.373247',
#   '869',
#   '-5',
#   'U',
#   'America/Lima'),
#  (69,
#   '2I',
#   '8359',
#   'LIM',
#   '2789',
#   'AYP',
#   '2786',
#   None,
#   '0',
#   '142',
#   2714,
#   '2786',
#   'Coronel Fap Alfredo Mendivil Duarte',
#   'Ayacucho',
#   'Peru',
#   'AYP',
#   'SPHO',
#   '-13.154819',
#   '-74.204417',
#   '8917',
#   '-5',
#   'U',
#   'America/Lima'),
#  (70,
#   '2I',
#   '8359',
#   'LIM',
#   '2789',
#   'CUZ',
#   '2812',
#   None,
#   '0',
#   '142 141',
#   2739,
#   '2812',
#   'Teniente Alejandro Velasco Astete Intl',
#   'Cuzco',
#   'Peru',
#   'CUZ',
#   'SPZO',
#   '-13.535722',
#   '-71.938781',
#   '10860',
#   '-5',
#   'U',
#   'America/Lima'),
#  (71,
#   '2I',
#   '8359',
#   'LIM',
#   '2789',
#   'HUU',
#   '6067',
#   None,
#   '0',
#   '141',
#   4936,
#   '6067',
#   'Alferez Fap David Figueroa Fernandini Airport',
#   'Huánuco',
#   'Peru',
#   'HUU',
#   'SPNC',
#   '-9.878811',
#   '-76.204797',
#   '6070',
#   '-5',
#   'U',
#   'America/Lima'),
#  (72,
#   '2I',
#   '8359',
#   'LIM',
#   '2789',
#   'PCL',
#   '2781',
#   None,
#   '0',
#   '143 146',
#   2709,
#   '2781',
#   'Cap Fap David Abenzur Rengifo Intl',
#   'Pucallpa',
#   'Peru',
#   'PCL',
#   'SPCL',
#   '-8.377939',
#   '-74.574297',
#   '513',
#   '-5',
#   'U',
#   'America/Lima'),
#  (73,
#   '2I',
#   '8359',
#   'LIM',
#   '2789',
#   'TPP',
#   '2806',
#   None,
#   '0',
#   '142 146',
#   2733,
#   '2806',
#   'Cadete Guillermo Del Castillo Paredes',
#   'Tarapoto',
#   'Peru',
#   'TPP',
#   'SPST',
#   '-6.508742',
#   '-76.373247',
#   '869',
#   '-5',
#   'U',
#   'America/Lima'),
#  (74,
#   '2I',
#   '8359',
#   'PCL',
#   '2781',
#   'IQT',
#   '2801',
#   None,
#   '0',
#   '143',
#   2728,
#   '2801',
#   'Coronel Francisco Secada Vignetta Intl',
#   'Iquitos',
#   'Peru',
#   'IQT',
#   'SPQT',
#   '-3.784739',
#   '-73.308806',
#   '306',
#   '-5',
#   'U',
#   'America/Lima'),
#  (75,
#   '2I',
#   '8359',
#   'PCL',
#   '2781',
#   'LIM',
#   '2789',
#   None,
#   '0',
#   '143 146',
#   2717,
#   '2789',
#   'Jorge Chavez Intl',
#   'Lima',
#   'Peru',
#   'LIM',
#   'SPIM',
#   '-12.021889',
#   '-77.114319',
#   '113',
#   '-5',
#   'U',
#   'America/Lima'),
#  (76,
#   '2I',
#   '8359',
#   'PCL',
#   '2781',
#   'TPP',
#   '2806',
#   None,
#   '0',
#   '146',
#   2733,
#   '2806',
#   'Cadete Guillermo Del Castillo Paredes',
#   'Tarapoto',
#   'Peru',
#   'TPP',
#   'SPST',
#   '-6.508742',
#   '-76.373247',
#   '869',
#   '-5',
#   'U',
#   'America/Lima'),
#  (77,
#   '2I',
#   '8359',
#   'PEM',
#   '2808',
#   'CUZ',
#   '2812',
#   None,
#   '0',
#   '142',
#   2739,
#   '2812',
#   'Teniente Alejandro Velasco Astete Intl',
#   'Cuzco',
#   'Peru',
#   'CUZ',
#   'SPZO',
#   '-13.535722',
#   '-71.938781',
#   '10860',
#   '-5',
#   'U',
#   'America/Lima'),
#  (78,
#   '2I',
#   '8359',
#   'TPP',
#   '2806',
#   'IQT',
#   '2801',
#   None,
#   '0',
#   '142',
#   2728,
#   '2801',
#   'Coronel Francisco Secada Vignetta Intl',
#   'Iquitos',
#   'Peru',
#   'IQT',
#   'SPQT',
#   '-3.784739',
#   '-73.308806',
#   '306',
#   '-5',
#   'U',
#   'America/Lima'),
#  (79,
#   '2I',
#   '8359',
#   'TPP',
#   '2806',
#   'LIM',
#   '2789',
#   None,
#   '0',
#   '142 146',
#   2717,
#   '2789',
#   'Jorge Chavez Intl',
#   'Lima',
#   'Peru',
#   'LIM',
#   'SPIM',
#   '-12.021889',
#   '-77.114319',
#   '113',
#   '-5',
#   'U',
#   'America/Lima'),
#  (80,
#   '2I',
#   '8359',
#   'TPP',
#   '2806',
#   'PCL',
#   '2781',
#   None,
#   '0',
#   '146',
#   2709,
#   '2781',
#   'Cap Fap David Abenzur Rengifo Intl',
#   'Pucallpa',
#   'Peru',
#   'PCL',
#   'SPCL',
#   '-8.377939',
#   '-74.574297',
#   '513',
#   '-5',
#   'U',
#   'America/Lima'),
#  (81,
#   '2J',
#   '470',
#   'ABJ',
#   '253',
#   'BOY',
#   '247',
#   None,
#   '0',
#   'CRJ',
#   244,
#   '247',
#   'Bobo Dioulasso',
#   'Bobo-dioulasso',
#   'Burkina Faso',
#   'BOY',
#   'DFOO',
#   '11.160056',
#   '-4.330969',
#   '1511',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (82,
#   '2J',
#   '470',
#   'ABJ',
#   '253',
#   'OUA',
#   '246',
#   None,
#   '0',
#   'E70 CRJ M87',
#   243,
#   '246',
#   'Ouagadougou',
#   'Ouagadougou',
#   'Burkina Faso',
#   'OUA',
#   'DFFD',
#   '12.353194',
#   '-1.512417',
#   '1037',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (83,
#   '2J',
#   '470',
#   'ACC',
#   '248',
#   'OUA',
#   '246',
#   None,
#   '0',
#   'CRJ',
#   243,
#   '246',
#   'Ouagadougou',
#   'Ouagadougou',
#   'Burkina Faso',
#   'OUA',
#   'DFFD',
#   '12.353194',
#   '-1.512417',
#   '1037',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (84,
#   '2J',
#   '470',
#   'BKO',
#   '1044',
#   'ABJ',
#   '253',
#   None,
#   '0',
#   'M87',
#   250,
#   '253',
#   'Abidjan Felix Houphouet Boigny Intl',
#   'Abidjan',
#   "Cote d'Ivoire",
#   'ABJ',
#   'DIAP',
#   '5.261386',
#   '-3.926294',
#   '21',
#   '0',
#   'N',
#   'Africa/Abidjan'),
#  (85,
#   '2J',
#   '470',
#   'BKO',
#   '1044',
#   'DKR',
#   '1084',
#   None,
#   '0',
#   'M87',
#   1064,
#   '1084',
#   'Leopold Sedar Senghor Intl',
#   'Dakar',
#   'Senegal',
#   'DKR',
#   'GOOY',
#   '14.739708',
#   '-17.490225',
#   '85',
#   '0',
#   'N',
#   'Africa/Dakar'),
#  (86,
#   '2J',
#   '470',
#   'BKO',
#   '1044',
#   'OUA',
#   '246',
#   None,
#   '0',
#   'CRJ',
#   243,
#   '246',
#   'Ouagadougou',
#   'Ouagadougou',
#   'Burkina Faso',
#   'OUA',
#   'DFFD',
#   '12.353194',
#   '-1.512417',
#   '1037',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (87,
#   '2J',
#   '470',
#   'BOY',
#   '247',
#   'ABJ',
#   '253',
#   None,
#   '0',
#   'CRJ',
#   250,
#   '253',
#   'Abidjan Felix Houphouet Boigny Intl',
#   'Abidjan',
#   "Cote d'Ivoire",
#   'ABJ',
#   'DIAP',
#   '5.261386',
#   '-3.926294',
#   '21',
#   '0',
#   'N',
#   'Africa/Abidjan'),
#  (88,
#   '2J',
#   '470',
#   'BOY',
#   '247',
#   'OUA',
#   '246',
#   None,
#   '0',
#   'CRJ',
#   243,
#   '246',
#   'Ouagadougou',
#   'Ouagadougou',
#   'Burkina Faso',
#   'OUA',
#   'DFFD',
#   '12.353194',
#   '-1.512417',
#   '1037',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (89,
#   '2J',
#   '470',
#   'COO',
#   '245',
#   'LFW',
#   '298',
#   None,
#   '0',
#   'M87',
#   295,
#   '298',
#   'Gnassingbe Eyadema Intl',
#   'Lome',
#   'Togo',
#   'LFW',
#   'DXXX',
#   '6.165611',
#   '1.254511',
#   '72',
#   '0',
#   'N',
#   'Africa/Lome'),
#  (90,
#   '2J',
#   '470',
#   'COO',
#   '245',
#   'OUA',
#   '246',
#   None,
#   '0',
#   'M87',
#   243,
#   '246',
#   'Ouagadougou',
#   'Ouagadougou',
#   'Burkina Faso',
#   'OUA',
#   'DFFD',
#   '12.353194',
#   '-1.512417',
#   '1037',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (91,
#   '2J',
#   '470',
#   'DKR',
#   '1084',
#   'BKO',
#   '1044',
#   None,
#   '0',
#   'M87',
#   1026,
#   '1044',
#   'Senou',
#   'Bamako',
#   'Mali',
#   'BKO',
#   'GABS',
#   '12.533544',
#   '-7.949944',
#   '1247',
#   '0',
#   'N',
#   'Africa/Bamako'),
#  (92,
#   '2J',
#   '470',
#   'DKR',
#   '1084',
#   'OUA',
#   '246',
#   None,
#   '0',
#   'M87',
#   243,
#   '246',
#   'Ouagadougou',
#   'Ouagadougou',
#   'Burkina Faso',
#   'OUA',
#   'DFFD',
#   '12.353194',
#   '-1.512417',
#   '1037',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (93,
#   '2J',
#   '470',
#   'LFW',
#   '298',
#   'OUA',
#   '246',
#   None,
#   '0',
#   'M87 CRJ',
#   243,
#   '246',
#   'Ouagadougou',
#   'Ouagadougou',
#   'Burkina Faso',
#   'OUA',
#   'DFFD',
#   '12.353194',
#   '-1.512417',
#   '1037',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (94,
#   '2J',
#   '470',
#   'NIM',
#   '280',
#   'OUA',
#   '246',
#   None,
#   '0',
#   'CRJ',
#   243,
#   '246',
#   'Ouagadougou',
#   'Ouagadougou',
#   'Burkina Faso',
#   'OUA',
#   'DFFD',
#   '12.353194',
#   '-1.512417',
#   '1037',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (95,
#   '2J',
#   '470',
#   'OUA',
#   '246',
#   'ABJ',
#   '253',
#   None,
#   '0',
#   'E70 CRJ M87',
#   250,
#   '253',
#   'Abidjan Felix Houphouet Boigny Intl',
#   'Abidjan',
#   "Cote d'Ivoire",
#   'ABJ',
#   'DIAP',
#   '5.261386',
#   '-3.926294',
#   '21',
#   '0',
#   'N',
#   'Africa/Abidjan'),
#  (96,
#   '2J',
#   '470',
#   'OUA',
#   '246',
#   'ACC',
#   '248',
#   None,
#   '0',
#   'CRJ',
#   245,
#   '248',
#   'Kotoka Intl',
#   'Accra',
#   'Ghana',
#   'ACC',
#   'DGAA',
#   '5.605186',
#   '-0.166786',
#   '205',
#   '0',
#   'N',
#   'Africa/Accra'),
#  (97,
#   '2J',
#   '470',
#   'OUA',
#   '246',
#   'BKO',
#   '1044',
#   None,
#   '0',
#   'M87 CRJ',
#   1026,
#   '1044',
#   'Senou',
#   'Bamako',
#   'Mali',
#   'BKO',
#   'GABS',
#   '12.533544',
#   '-7.949944',
#   '1247',
#   '0',
#   'N',
#   'Africa/Bamako'),
#  (98,
#   '2J',
#   '470',
#   'OUA',
#   '246',
#   'BOY',
#   '247',
#   None,
#   '0',
#   'CRJ',
#   244,
#   '247',
#   'Bobo Dioulasso',
#   'Bobo-dioulasso',
#   'Burkina Faso',
#   'BOY',
#   'DFOO',
#   '11.160056',
#   '-4.330969',
#   '1511',
#   '0',
#   'N',
#   'Africa/Ouagadougou'),
#  (99,
#   '2J',
#   '470',
#   'OUA',
#   '246',
#   'COO',
#   '245',
#   None,
#   '0',
#   'M87',
#   242,
#   '245',
#   'Cadjehoun',
#   'Cotonou',
#   'Benin',
#   'COO',
#   'DBBB',
#   '6.357228',
#   '2.384353',
#   '19',
#   '1',
#   'N',
#   'Africa/Porto-Novo'),
#  (100,
#   '2J',
#   '470',
#   'OUA',
#   '246',
#   'DKR',
#   '1084',
#   None,
#   '0',
#   'M87',
#   1064,
#   '1084',
#   'Leopold Sedar Senghor Intl',
#   'Dakar',
#   'Senegal',
#   'DKR',
#   'GOOY',
#   '14.739708',
#   '-17.490225',
#   '85',
#   '0',
#   'N',
#   'Africa/Dakar'),
#  (101,
#   '2J',
#   '470',
#   'OUA',
#   '246',
#   'LFW',
#   '298',
#   None,
#   '0',
#   'CRJ',
#   295,
#   '298',
#   'Gnassingbe Eyadema Intl',
#   'Lome',
#   'Togo',
#   'LFW',
#   'DXXX',
#   '6.165611',
#   '1.254511',
#   '72',
#   '0',
#   'N',
#   'Africa/Lome'),
#  (102,
#   '2J',
#   '470',
#   'OUA',
#   '246',
#   'NIM',
#   '280',
#   None,
#   '0',
#   'CRJ',
#   277,
#   '280',
#   'Diori Hamani',
#   'Niamey',
#   'Niger',
#   'NIM',
#   'DRRN',
#   '13.481547',
#   '2.183614',
#   '732',
#   '1',
#   'N',
#   'Africa/Niamey'),
#  (103,
#   '2K',
#   '1338',
#   'BOG',
#   '2709',
#   'GYE',
#   '2673',
#   None,
#   '0',
#   '319',
#   2603,
#   '2673',
#   'Jose Joaquin De Olmedo Intl',
#   'Guayaquil',
#   'Ecuador',
#   'GYE',
#   'SEGU',
#   '-2.157419',
#   '-79.883558',
#   '19',
#   '-5',
#   'U',
#   'America/Guayaquil'),
#  (104,
#   '2K',
#   '1338',
#   'BOG',
#   '2709',
#   'UIO',
#   '2688',
#   None,
#   '0',
#   '319 320',
#   2618,
#   '2688',
#   'Mariscal Sucre Intl',
#   'Quito',
#   'Ecuador',
#   'UIO',
#   'SEQU',
#   '-0.141144',
#   '-78.488214',
#   '9228',
#   '-5',
#   'U',
#   'America/Guayaquil'),
#  (105,
#   '2K',
#   '1338',
#   'CLO',
#   '2715',
#   'GYE',
#   '2673',
#   None,
#   '0',
#   '319',
#   2603,
#   '2673',
#   'Jose Joaquin De Olmedo Intl',
#   'Guayaquil',
#   'Ecuador',
#   'GYE',
#   'SEGU',
#   '-2.157419',
#   '-79.883558',
#   '19',
#   '-5',
#   'U',
#   'America/Guayaquil'),
#  (106,
#   '2K',
#   '1338',
#   'GYE',
#   '2673',
#   'BOG',
#   '2709',
#   None,
#   '0',
#   '319',
#   2638,
#   '2709',
#   'Eldorado Intl',
#   'Bogota',
#   'Colombia',
#   'BOG',
#   'SKBO',
#   '4.701594',
#   '-74.146947',
#   '8361',
#   '-5',
#   'U',
#   'America/Bogota'),
#  (107,
#   '2K',
#   '1338',
#   'GYE',
#   '2673',
#   'CLO',
#   '2715',
#   None,
#   '0',
#   '319',
#   2644,
#   '2715',
#   'Alfonso Bonilla Aragon Intl',
#   'Cali',
#   'Colombia',
#   'CLO',
#   'SKCL',
#   '3.543222',
#   '-76.381583',
#   '3162',
#   '-5',
#   'U',
#   'America/Bogota'),
#  (108,
#   '2K',
#   '1338',
#   'GYE',
#   '2673',
#   'SCY',
#   '6045',
#   None,
#   '0',
#   '319 320',
#   4949,
#   '6045',
#   'San Cristóbal Airport',
#   'San Cristóbal',
#   'Ecuador',
#   'SCY',
#   'SEST',
#   '-0.910206',
#   '-89.61745',
#   '62',
#   '-6',
#   'U',
#   'Pacific/Galapagos'),
#  (109,
#   '2K',
#   '1338',
#   'GYE',
#   '2673',
#   'UIO',
#   '2688',
#   None,
#   '0',
#   '320 319',
#   2618,
#   '2688',
#   'Mariscal Sucre Intl',
#   'Quito',
#   'Ecuador',
#   'UIO',
#   'SEQU',
#   '-0.141144',
#   '-78.488214',
#   '9228',
#   '-5',
#   'U',
#   'America/Guayaquil'),
#  (110,
#   '2K',
#   '1338',
#   'OCC',
#   '2670',
#   'UIO',
#   '2688',
#   None,
#   '0',
#   '319',
#   2618,
#   '2688',
#   'Mariscal Sucre Intl',
#   'Quito',
#   'Ecuador',
#   'UIO',
#   'SEQU',
#   '-0.141144',
#   '-78.488214',
#   '9228',
#   '-5',
#   'U',
#   'America/Guayaquil'),
#  (111,
#   '2K',
#   '1338',
#   'SCY',
#   '6045',
#   'GYE',
#   '2673',
#   None,
#   '0',
#   '319 320',
#   2603,
#   '2673',
#   'Jose Joaquin De Olmedo Intl',
#   'Guayaquil',
#   'Ecuador',
#   'GYE',
#   'SEGU',
#   '-2.157419',
#   '-79.883558',
#   '19',
#   '-5',
#   'U',
#   'America/Guayaquil'),
#  (112,
#   '2K',
#   '1338',
#   'UIO',
#   '2688',
#   'BOG',
#   '2709',
#   None,
#   '0',
#   '319 320',
#   2638,
#   '2709',
#   'Eldorado Intl',
#   'Bogota',
#   'Colombia',
#   'BOG',
#   'SKBO',
#   '4.701594',
#   '-74.146947',
#   '8361',
#   '-5',
#   'U',
#   'America/Bogota'),
#  (113,
#   '2K',
#   '1338',
#   'UIO',
#   '2688',
#   'GYE',
#   '2673',
#   None,
#   '0',
#   '319',
#   2603,
#   '2673',
#   'Jose Joaquin De Olmedo Intl',
#   'Guayaquil',
#   'Ecuador',
#   'GYE',
#   'SEGU',
#   '-2.157419',
#   '-79.883558',
#   '19',
#   '-5',
#   'U',
#   'America/Guayaquil'),
#  (114,
#   '2K',
#   '1338',
#   'UIO',
#   '2688',
#   'OCC',
#   '2670',
#   None,
#   '0',
#   '319',
#   2600,
#   '2670',
#   'Francisco De Orellana',
#   'Coca',
#   'Ecuador',
#   'OCC',
#   'SECO',
#   '-0.462886',
#   '-76.986842',
#   '834',
#   '-5',
#   'U',
#   'America/Guayaquil'),
#  (115,
#   '2L',
#   '2750',
#   'BDS',
#   '1506',
#   'ZRH',
#   '1678',
#   None,
#   '0',
#   '100',
#   1651,
#   '1678',
#   'Zurich',
#   'Zurich',
#   'Switzerland',
#   'ZRH',
#   'LSZH',
#   '47.464722',
#   '8.549167',
#   '1416',
#   '1',
#   'E',
#   'Europe/Zurich'),
#  (116,
#   '2L',
#   '2750',
#   'BOD',
#   '1264',
#   'ZRH',
#   '1678',
#   None,
#   '0',
#   '100',
#   1651,
#   '1678',
#   'Zurich',
#   'Zurich',
#   'Switzerland',
#   'ZRH',
#   'LSZH',
#   '47.464722',
#   '8.549167',
#   '1416',
#   '1',
#   'E',
#   'Europe/Zurich'),
#  (117,
#   '2L',
#   '2750',
#   'BRS',
#   '490',
#   'ZRH',
#   '1678',
#   None,
#   '0',
#   '100',
#   1651,
#   '1678',
#   'Zurich',
#   'Zurich',
#   'Switzerland',
#   'ZRH',
#   'LSZH',
#   '47.464722',
#   '8.549167',
#   '1416',
#   '1',
#   'E',
#   'Europe/Zurich'),
#  (118,
#   '2L',
#   '2750',
#   'GVA',
#   '1665',
#   'LPA',
#   '1054',
#   None,
#   '0',
#   '319',
#   1036,
#   '1054',
#   'Gran Canaria',
#   'Gran Canaria',
#   'Spain',
#   'LPA',
#   'GCLP',
#   '27.931886',
#   '-15.386586',
#   '78',
#   '0',
#   'E',
#   'Atlantic/Canary'),
#  (119,
#   '2L',
#   '2750',
#   'LCA',
#   '1197',
#   'ZRH',
#   '1678',
#   None,
#   '0',
#   '319',
#   1651,
#   '1678',
#   'Zurich',
#   'Zurich',
#   'Switzerland',
#   'ZRH',
#   'LSZH',
#   '47.464722',
#   '8.549167',
#   '1416',
#   '1',
#   'E',
#   'Europe/Zurich'),
#  (120,
#   '2L',
#   '2750',
#   'LPA',
#   '1054',
#   'ZRH',
#   '1678',
#   None,
#   '0',
#   '319',
#   1651,
#   '1678',
#   'Zurich',
#   'Zurich',
#   'Switzerland',
#   'ZRH',
#   'LSZH',
#   '47.464722',
#   '8.549167',
#   '1416',
#   '1',
#   'E',
#   'Europe/Zurich'),
#  (121,
#   '2L',
#   '2750',
#   'RMF',
#   '4197',
#   'ZRH',
#   '1678',
#   None,
#   '0',
#   '319',
#   1651,
#   '1678',
#   'Zurich',
#   'Zurich',
#   'Switzerland',
#   'ZRH',
#   'LSZH',
#   '47.464722',
#   '8.549167',
#   '1416',
#   '1',
#   'E',
#   'Europe/Zurich'),
#  (122,
#   '2L',
#   '2750',
#   'TFS',
#   '1056',
#   'GVA',
#   '1665',
#   None,
#   '0',
#   '319',
#   1638,
#   '1665',
#   'Geneve Cointrin',
#   'Geneva',
#   'Switzerland',
#   'GVA',
#   'LSGG',
#   '46.238064',
#   '6.10895',
#   '1411',
#   '1',
#   'E',
#   'Europe/Paris'),
#  (123,
#   '2L',
#   '2750',
#   'ZRH',
#   '1678',
#   'BDS',
#   '1506',
#   None,
#   '0',
#   '100',
#   1480,
#   '1506',
#   'Casale',
#   'Brindisi',
#   'Italy',
#   'BDS',
#   'LIBR',
#   '40.657633',
#   '17.947033',
#   '47',
#   '1',
#   'E',
#   'Europe/Rome'),
#  (124,
#   '2L',
#   '2750',
#   'ZRH',
#   '1678',
#   'BOD',
#   '1264',
#   None,
#   '0',
#   '100',
#   1241,
#   '1264',
#   'Merignac',
#   'Bordeaux',
#   'France',
#   'BOD',
#   'LFBD',
#   '44.828335',
#   '-0.715556',
#   '162',
#   '1',
#   'E',
#   'Europe/Paris'),
#  (125,
#   '2L',
#   '2750',
#   'ZRH',
#   '1678',
#   'BRS',
#   '490',
#   None,
#   '0',
#   '100',
#   486,
#   '490',
#   'Bristol',
#   'Bristol',
#   'United Kingdom',
#   'BRS',
#   'EGGD',
#   '51.382669',
#   '-2.719089',
#   '622',
#   '0',
#   'E',
#   'Europe/London'),
#  (126,
#   '2L',
#   '2750',
#   'ZRH',
#   '1678',
#   'LCA',
#   '1197',
#   None,
#   '0',
#   '319',
#   1175,
#   '1197',
#   'Larnaca',
#   'Larnaca',
#   'Cyprus',
#   'LCA',
#   'LCLK',
#   '34.875117',
#   '33.62485',
#   '8',
#   '2',
#   'E',
#   'Asia/Nicosia'),
#  (127,
#   '2L',
#   '2750',
#   'ZRH',
#   '1678',
#   'LPA',
#   '1054',
#   None,
#   '0',
#   '319',
#   1036,
#   '1054',
#   'Gran Canaria',
#   'Gran Canaria',
#   'Spain',
#   'LPA',
#   'GCLP',
#   '27.931886',
#   '-15.386586',
#   '78',
#   '0',
#   'E',
#   'Atlantic/Canary'),
#  (128,
#   '2L',
#   '2750',
#   'ZRH',
#   '1678',
#   'RMF',
#   '4197',
#   None,
#   '0',
#   '319',
#   4087,
#   '4197',
#   'Marsa Alam Intl',
#   'Marsa Alam',
#   'Egypt',
#   'RMF',
#   'HEMA',
#   '25.557111',
#   '34.583711',
#   '251',
#   '2',
#   'U',
#   'Africa/Cairo'),
#  (129,
#   '2N',
#   '3652',
#   'AJR',
#   '730',
#   'LYC',
#   '719',
#   None,
#   '0',
#   'ATP',
#   709,
#   '719',
#   'Lycksele',
#   'Lycksele',
#   'Sweden',
#   'LYC',
#   'ESNL',
#   '64.548322',
#   '18.716219',
#   '705',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (130,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'GEV',
#   '715',
#   None,
#   '0',
#   'ATP',
#   705,
#   '715',
#   'Gallivare',
#   'Gallivare',
#   'Sweden',
#   'GEV',
#   'ESNG',
#   '67.132408',
#   '20.814636',
#   '1027',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (131,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'HAD',
#   '709',
#   None,
#   '0',
#   'SF3',
#   699,
#   '709',
#   'Halmstad',
#   'Halmstad',
#   'Sweden',
#   'HAD',
#   'ESMT',
#   '56.691128',
#   '12.820211',
#   '101',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (132,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'JKG',
#   '688',
#   None,
#   '0',
#   'ATP SF3',
#   678,
#   '688',
#   'Jonkoping',
#   'Joenkoeping',
#   'Sweden',
#   'JKG',
#   'ESGJ',
#   '57.757594',
#   '14.068731',
#   '741',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (133,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'KRF',
#   '718',
#   None,
#   '0',
#   'ATP',
#   708,
#   '718',
#   'Kramfors Solleftea',
#   'Kramfors',
#   'Sweden',
#   'KRF',
#   'ESNK',
#   '63.048597',
#   '17.768856',
#   '34',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (134,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'KSD',
#   '5595',
#   None,
#   '0',
#   'SF3',
#   4726,
#   '5595',
#   'Karlstad Airport',
#   'Karlstad',
#   'Sweden',
#   'KSD',
#   'ESOK',
#   '59.4447',
#   '13.3374',
#   '352',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (135,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'LYC',
#   '719',
#   None,
#   '0',
#   'ATP',
#   709,
#   '719',
#   'Lycksele',
#   'Lycksele',
#   'Sweden',
#   'LYC',
#   'ESNL',
#   '64.548322',
#   '18.716219',
#   '705',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (136,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'MHQ',
#   '442',
#   None,
#   '0',
#   'SF3',
#   439,
#   '442',
#   'Mariehamn',
#   'Mariehamn',
#   'Finland',
#   'MHQ',
#   'EFMA',
#   '60.122203',
#   '19.898156',
#   '17',
#   '2',
#   'E',
#   'Europe/Mariehamn'),
#  (137,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'OER',
#   '722',
#   None,
#   '0',
#   'ATR',
#   712,
#   '722',
#   'Ornskoldsvik',
#   'Ornskoldsvik',
#   'Sweden',
#   'OER',
#   'ESNO',
#   '63.408339',
#   '18.990039',
#   '354',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (138,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'POR',
#   '448',
#   None,
#   '0',
#   'SF3',
#   445,
#   '448',
#   'Pori',
#   'Pori',
#   'Finland',
#   'POR',
#   'EFPO',
#   '61.461686',
#   '21.799983',
#   '44',
#   '2',
#   'E',
#   'Europe/Helsinki'),
#  (139,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'TRF',
#   '664',
#   None,
#   '0',
#   'SF3',
#   655,
#   '664',
#   'Torp',
#   'Sandefjord',
#   'Norway',
#   'TRF',
#   'ENTO',
#   '59.186703',
#   '10.258628',
#   '286',
#   '1',
#   'E',
#   'Europe/Oslo'),
#  (140,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'VBY',
#   '746',
#   None,
#   '0',
#   'SF3 ATP',
#   734,
#   '746',
#   'Visby',
#   'Visby',
#   'Sweden',
#   'VBY',
#   'ESSV',
#   '57.662797',
#   '18.346211',
#   '164',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (141,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'VHM',
#   '729',
#   None,
#   '0',
#   'SF3',
#   719,
#   '729',
#   'Vilhelmina',
#   'Vilhelmina',
#   'Sweden',
#   'VHM',
#   'ESNV',
#   '64.579083',
#   '16.833575',
#   '1140',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (142,
#   '2N',
#   '3652',
#   'ARN',
#   '737',
#   'VXO',
#   '711',
#   None,
#   '0',
#   'SF3',
#   701,
#   '711',
#   'Kronoberg',
#   'Vaxjo',
#   'Sweden',
#   'VXO',
#   'ESMX',
#   '56.929144',
#   '14.727994',
#   '610',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (143,
#   '2N',
#   '3652',
#   'GEV',
#   '715',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'ATP',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (144,
#   '2N',
#   '3652',
#   'GEV',
#   '715',
#   'KRF',
#   '718',
#   None,
#   '0',
#   'ATP',
#   708,
#   '718',
#   'Kramfors Solleftea',
#   'Kramfors',
#   'Sweden',
#   'KRF',
#   'ESNK',
#   '63.048597',
#   '17.768856',
#   '34',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (145,
#   '2N',
#   '3652',
#   'HAD',
#   '709',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'SF3 ATP',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (146,
#   '2N',
#   '3652',
#   'HAD',
#   '709',
#   'JKG',
#   '688',
#   None,
#   '0',
#   'ATP SF3',
#   678,
#   '688',
#   'Jonkoping',
#   'Joenkoeping',
#   'Sweden',
#   'JKG',
#   'ESGJ',
#   '57.757594',
#   '14.068731',
#   '741',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (147,
#   '2N',
#   '3652',
#   'HAD',
#   '709',
#   'VXO',
#   '711',
#   None,
#   '0',
#   'SF3',
#   701,
#   '711',
#   'Kronoberg',
#   'Vaxjo',
#   'Sweden',
#   'VXO',
#   'ESMX',
#   '56.929144',
#   '14.727994',
#   '610',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (148,
#   '2N',
#   '3652',
#   'HMV',
#   '5599',
#   'VHM',
#   '729',
#   None,
#   '0',
#   'SF3',
#   719,
#   '729',
#   'Vilhelmina',
#   'Vilhelmina',
#   'Sweden',
#   'VHM',
#   'ESNV',
#   '64.579083',
#   '16.833575',
#   '1140',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (149,
#   '2N',
#   '3652',
#   'JKG',
#   '688',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'ATP SF3',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (150,
#   '2N',
#   '3652',
#   'JKG',
#   '688',
#   'HAD',
#   '709',
#   None,
#   '0',
#   'ATP SF3',
#   699,
#   '709',
#   'Halmstad',
#   'Halmstad',
#   'Sweden',
#   'HAD',
#   'ESMT',
#   '56.691128',
#   '12.820211',
#   '101',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (151,
#   '2N',
#   '3652',
#   'KOK',
#   '435',
#   'POR',
#   '448',
#   None,
#   '0',
#   'SF3',
#   445,
#   '448',
#   'Pori',
#   'Pori',
#   'Finland',
#   'POR',
#   'EFPO',
#   '61.461686',
#   '21.799983',
#   '44',
#   '2',
#   'E',
#   'Europe/Helsinki'),
#  (152,
#   '2N',
#   '3652',
#   'KRF',
#   '718',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'ATP',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (153,
#   '2N',
#   '3652',
#   'KRF',
#   '718',
#   'GEV',
#   '715',
#   None,
#   '0',
#   'ATP',
#   705,
#   '715',
#   'Gallivare',
#   'Gallivare',
#   'Sweden',
#   'GEV',
#   'ESNG',
#   '67.132408',
#   '20.814636',
#   '1027',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (154,
#   '2N',
#   '3652',
#   'KSD',
#   '5595',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'SF3',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (155,
#   '2N',
#   '3652',
#   'LYC',
#   '719',
#   'AJR',
#   '730',
#   None,
#   '0',
#   'ATP',
#   720,
#   '730',
#   'Arvidsjaur',
#   'Arvidsjaur',
#   'Sweden',
#   'AJR',
#   'ESNX',
#   '65.590278',
#   '19.281944',
#   '1245',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (156,
#   '2N',
#   '3652',
#   'LYC',
#   '719',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'ATP',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (157,
#   '2N',
#   '3652',
#   'MHQ',
#   '442',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'SF3',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (158,
#   '2N',
#   '3652',
#   'MHQ',
#   '442',
#   'TKU',
#   '460',
#   None,
#   '0',
#   'SF3',
#   457,
#   '460',
#   'Turku',
#   'Turku',
#   'Finland',
#   'TKU',
#   'EFTU',
#   '60.514142',
#   '22.262808',
#   '161',
#   '2',
#   'E',
#   'Europe/Helsinki'),
#  (159,
#   '2N',
#   '3652',
#   'OER',
#   '722',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'ATR',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (160,
#   '2N',
#   '3652',
#   'OSL',
#   '644',
#   'VXO',
#   '711',
#   None,
#   '0',
#   'SF3',
#   701,
#   '711',
#   'Kronoberg',
#   'Vaxjo',
#   'Sweden',
#   'VXO',
#   'ESMX',
#   '56.929144',
#   '14.727994',
#   '610',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (161,
#   '2N',
#   '3652',
#   'POR',
#   '448',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'SF3',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (162,
#   '2N',
#   '3652',
#   'POR',
#   '448',
#   'KOK',
#   '435',
#   None,
#   '0',
#   'SF3',
#   432,
#   '435',
#   'Kruunupyy',
#   'Kruunupyy',
#   'Finland',
#   'KOK',
#   'EFKK',
#   '63.721172',
#   '23.143131',
#   '84',
#   '2',
#   'E',
#   'Europe/Helsinki'),
#  (163,
#   '2N',
#   '3652',
#   'TKU',
#   '460',
#   'MHQ',
#   '442',
#   None,
#   '0',
#   'SF3',
#   439,
#   '442',
#   'Mariehamn',
#   'Mariehamn',
#   'Finland',
#   'MHQ',
#   'EFMA',
#   '60.122203',
#   '19.898156',
#   '17',
#   '2',
#   'E',
#   'Europe/Mariehamn'),
#  (164,
#   '2N',
#   '3652',
#   'TRF',
#   '664',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'SF3',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (165,
#   '2N',
#   '3652',
#   'VBY',
#   '746',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'SF3 ATP',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (166,
#   '2N',
#   '3652',
#   'VHM',
#   '729',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'SF3',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (167,
#   '2N',
#   '3652',
#   'VHM',
#   '729',
#   'HMV',
#   '5599',
#   None,
#   '0',
#   'SF3',
#   4722,
#   '5599',
#   'Hemavan Airport',
#   'Hemavan',
#   'Sweden',
#   'HMV',
#   'ESUT',
#   '65.806111',
#   '15.082778',
#   '1503',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (168,
#   '2N',
#   '3652',
#   'VXO',
#   '711',
#   'ARN',
#   '737',
#   None,
#   '0',
#   'SF3',
#   726,
#   '737',
#   'Arlanda',
#   'Stockholm',
#   'Sweden',
#   'ARN',
#   'ESSA',
#   '59.651944',
#   '17.918611',
#   '137',
#   '1',
#   'E',
#   'Europe/Stockholm'),
#  (169,
#   '2N',
#   '3652',
#   'VXO',
#   '711',
#   'OSL',
#   '644',
#   None,
#   '0',
#   'SF3',
#   636,
#   '644',
#   'Gardermoen',
#   'Oslo',
#   'Norway',
#   'OSL',
#   'ENGM',
#   '60.193917',
#   '11.100361',
#   '681',
#   '1',
#   'E',
#   'Europe/Oslo'),
#  (170,
#   '2O',
#   '146',
#   'ADQ',
#   '3531',
#   'AOS',
#   '7167',
#   None,
#   '0',
#   'BNI',
#   5742,
#   '7167',
#   'Amook Bay Seaplane Base',
#   'Amook Bay',
#   'United States',
#   'AOS',
#   '\\N',
#   '57.471389',
#   '-153.815278',
#   '0',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (171,
#   '2O',
#   '146',
#   'ADQ',
#   '3531',
#   'KKB',
#   '7168',
#   None,
#   '0',
#   'BNI',
#   5743,
#   '7168',
#   'Kitoi Bay Seaplane Base',
#   'Kitoi Bay',
#   'United States',
#   'KKB',
#   '\\N',
#   '58.190833',
#   '-152.370556',
#   '0',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (172,
#   '2O',
#   '146',
#   'ADQ',
#   '3531',
#   'KLN',
#   '7162',
#   None,
#   '0',
#   'BNI',
#   5737,
#   '7162',
#   'Larsen Bay Airport',
#   'Larsen Bay',
#   'United States',
#   'KLN',
#   'PALB',
#   '57.535',
#   '-153.976667',
#   '87',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (173,
#   '2O',
#   '146',
#   'ADQ',
#   '3531',
#   'KOZ',
#   '7164',
#   None,
#   '0',
#   'BNI',
#   5739,
#   '7164',
#   'Ouzinkie Airport',
#   'Ouzinkie',
#   'United States',
#   'KOZ',
#   '\\N',
#   '57.922876',
#   '-152.500511',
#   '55',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (174,
#   '2O',
#   '146',
#   'ADQ',
#   '3531',
#   'OLH',
#   '7163',
#   None,
#   '0',
#   'BNI',
#   5738,
#   '7163',
#   'Old Harbor Airport',
#   'Old Harbor',
#   'United States',
#   'OLH',
#   '\\N',
#   '57.218056',
#   '-153.269722',
#   '55',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (175,
#   '2O',
#   '146',
#   'AOS',
#   '7167',
#   'KZB',
#   '7176',
#   None,
#   '0',
#   'BNI',
#   5751,
#   '7176',
#   'Zachar Bay Seaplane Base',
#   'Zachar Bay',
#   'United States',
#   'KZB',
#   '\\N',
#   '57.55',
#   '-153.75',
#   '0',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (176,
#   '2O',
#   '146',
#   'KKB',
#   '7168',
#   'SYB',
#   '7173',
#   None,
#   '0',
#   'BNI',
#   5748,
#   '7173',
#   'Seal Bay Seaplane Base',
#   'Seal Bay',
#   'United States',
#   'SYB',
#   '\\N',
#   '58.166667',
#   '-152.5',
#   '0',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (177,
#   '2O',
#   '146',
#   'KLN',
#   '7162',
#   'KYK',
#   '7161',
#   None,
#   '0',
#   'BNI',
#   5736,
#   '7161',
#   'Karuluk Airport',
#   'Karluk',
#   'United States',
#   'KYK',
#   'PAKY',
#   '57.566944',
#   '-154.450278',
#   '137',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (178,
#   '2O',
#   '146',
#   'KOZ',
#   '7164',
#   'ORI',
#   '7165',
#   None,
#   '0',
#   'BNI',
#   5740,
#   '7165',
#   'Port Lions Airport',
#   'Port Lions',
#   'United States',
#   'ORI',
#   '\\N',
#   '57.885278',
#   '-152.846111',
#   '52',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (179,
#   '2O',
#   '146',
#   'SYB',
#   '7173',
#   'KPR',
#   '7172',
#   None,
#   '0',
#   'BNI',
#   5747,
#   '7172',
#   'Port Williams Seaplane Base',
#   'Port Williams',
#   'United States',
#   'KPR',
#   '\\N',
#   '58.49',
#   '-152.582222',
#   '0',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (180,
#   '2P',
#   '897',
#   'BSO',
#   '6019',
#   'MNL',
#   '2397',
#   None,
#   '0',
#   'DH4',
#   2335,
#   '2397',
#   'Ninoy Aquino Intl',
#   'Manila',
#   'Philippines',
#   'MNL',
#   'RPLL',
#   '14.508647',
#   '121.019581',
#   '75',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (181,
#   '2P',
#   '897',
#   'BXU',
#   '4200',
#   'MNL',
#   '2397',
#   None,
#   '0',
#   '320',
#   2335,
#   '2397',
#   'Ninoy Aquino Intl',
#   'Manila',
#   'Philippines',
#   'MNL',
#   'RPLL',
#   '14.508647',
#   '121.019581',
#   '75',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (182,
#   '2P',
#   '897',
#   'CBO',
#   '2399',
#   'MNL',
#   '2397',
#   None,
#   '0',
#   '320',
#   2335,
#   '2397',
#   'Ninoy Aquino Intl',
#   'Manila',
#   'Philippines',
#   'MNL',
#   'RPLL',
#   '14.508647',
#   '121.019581',
#   '75',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (183,
#   '2P',
#   '897',
#   'CGY',
#   '2400',
#   'MNL',
#   '2397',
#   None,
#   '0',
#   '320',
#   2335,
#   '2397',
#   'Ninoy Aquino Intl',
#   'Manila',
#   'Philippines',
#   'MNL',
#   'RPLL',
#   '14.508647',
#   '121.019581',
#   '75',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (184,
#   '2P',
#   '897',
#   'CRM',
#   '6024',
#   'MNL',
#   '2397',
#   None,
#   '0',
#   'DH4',
#   2335,
#   '2397',
#   'Ninoy Aquino Intl',
#   'Manila',
#   'Philippines',
#   'MNL',
#   'RPLL',
#   '14.508647',
#   '121.019581',
#   '75',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (185,
#   '2P',
#   '897',
#   'DGT',
#   '2425',
#   'MNL',
#   '2397',
#   None,
#   '0',
#   '320',
#   2335,
#   '2397',
#   'Ninoy Aquino Intl',
#   'Manila',
#   'Philippines',
#   'MNL',
#   'RPLL',
#   '14.508647',
#   '121.019581',
#   '75',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (186,
#   '2P',
#   '897',
#   'DWC',
#   '8076',
#   'MNL',
#   '2397',
#   None,
#   '0',
#   '330',
#   2335,
#   '2397',
#   'Ninoy Aquino Intl',
#   'Manila',
#   'Philippines',
#   'MNL',
#   'RPLL',
#   '14.508647',
#   '121.019581',
#   '75',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (187,
#   '2P',
#   '897',
#   'GES',
#   '6011',
#   'MNL',
#   '2397',
#   'Y',
#   '0',
#   '320',
#   2335,
#   '2397',
#   'Ninoy Aquino Intl',
#   'Manila',
#   'Philippines',
#   'MNL',
#   'RPLL',
#   '14.508647',
#   '121.019581',
#   '75',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (188,
#   '2P',
#   '897',
#   'KLO',
#   '2430',
#   'MNL',
#   '2397',
#   None,
#   '0',
#   '320',
#   2335,
#   '2397',
#   'Ninoy Aquino Intl',
#   'Manila',
#   'Philippines',
#   'MNL',
#   'RPLL',
#   '14.508647',
#   '121.019581',
#   '75',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (189,
#   '2P',
#   '897',
#   'LGP',
#   '4203',
#   'MNL',
#   '2397',
#   None,
#   '0',
#   '320',
#   2335,
#   '2397',
#   'Ninoy Aquino Intl',
#   'Manila',
#   'Philippines',
#   'MNL',
#   'RPLL',
#   '14.508647',
#   '121.019581',
#   '75',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (190,
#   '2P',
#   '897',
#   'MNL',
#   '2397',
#   'BSO',
#   '6019',
#   None,
#   '0',
#   'DH4',
#   4962,
#   '6019',
#   'Basco Airport',
#   'Basco',
#   'Philippines',
#   'BSO',
#   'RPUO',
#   '20.451322',
#   '121.979883',
#   '291',
#   '8',
#   'N',
#   '\\N'),
#  (191,
#   '2P',
#   '897',
#   'MNL',
#   '2397',
#   'BXU',
#   '4200',
#   None,
#   '0',
#   '320',
#   4090,
#   '4200',
#   'Butuan',
#   'Butuan',
#   'Philippines',
#   'BXU',
#   'RPME',
#   '8.951322',
#   '125.477972',
#   '141',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (192,
#   '2P',
#   '897',
#   'MNL',
#   '2397',
#   'CBO',
#   '2399',
#   None,
#   '0',
#   '320',
#   2337,
#   '2399',
#   'Cotabato',
#   'Cotabato',
#   'Philippines',
#   'CBO',
#   'RPMC',
#   '7.165242',
#   '124.209619',
#   '189',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (193,
#   '2P',
#   '897',
#   'MNL',
#   '2397',
#   'CGY',
#   '2400',
#   None,
#   '0',
#   '320',
#   2338,
#   '2400',
#   'Cagayan De Oro',
#   'Ladag',
#   'Philippines',
#   'CGY',
#   'RPML',
#   '8.415619',
#   '124.611219',
#   '601',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (194,
#   '2P',
#   '897',
#   'MNL',
#   '2397',
#   'CRM',
#   '6024',
#   None,
#   '0',
#   'DH4',
#   4311,
#   '6024',
#   'Catarman National Airport',
#   'Catarman',
#   'Philippines',
#   'CRM',
#   'RPVF',
#   '12.502417',
#   '124.635778',
#   '6',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (195,
#   '2P',
#   '897',
#   'MNL',
#   '2397',
#   'DGT',
#   '2425',
#   None,
#   '0',
#   '320',
#   2359,
#   '2425',
#   'Dumaguete',
#   'Dumaguete',
#   'Philippines',
#   'DGT',
#   'RPVD',
#   '9.333714',
#   '123.300472',
#   '15',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (196,
#   '2P',
#   '897',
#   'MNL',
#   '2397',
#   'DWC',
#   '8076',
#   None,
#   '0',
#   '330',
#   6649,
#   '8076',
#   'Dubai Al Maktoum',
#   'Dubai',
#   'United Arab Emirates',
#   'DWC',
#   'OMDW',
#   '24.55056',
#   '55.103174',
#   '170',
#   '4',
#   'U',
#   'Asia/Dubai'),
#  (197,
#   '2P',
#   '897',
#   'MNL',
#   '2397',
#   'GES',
#   '6011',
#   'Y',
#   '0',
#   '320',
#   4968,
#   '6011',
#   'General Santos International Airport',
#   'General Santos City',
#   'Philippines',
#   'GES',
#   'RPMB',
#   '6.106439',
#   '125.2353',
#   '28',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (198,
#   '2P',
#   '897',
#   'MNL',
#   '2397',
#   'KLO',
#   '2430',
#   None,
#   '0',
#   '320',
#   2363,
#   '2430',
#   'Kalibo',
#   'Kalibo',
#   'Philippines',
#   'KLO',
#   'RPVK',
#   '11.679431',
#   '122.376294',
#   '14',
#   '8',
#   'N',
#   'Asia/Manila'),
#  (199,
#   '2P',
#   '897',
#   'MNL',
#   '2397',
#   'LGP',
# ...
#   'China',
#   'KWE',
#   'ZUGY',
#   '26.538522',
#   '106.800703',
#   '3736',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (936,
#   '3U',
#   '4608',
#   'WNZ',
#   '6392',
#   'SYX',
#   '4030',
#   None,
#   '0',
#   '321',
#   3922,
#   '4030',
#   'Phoenix International',
#   'Sanya',
#   'China',
#   'SYX',
#   'ZJSY',
#   '18.302897',
#   '109.412272',
#   '92',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (937,
#   '3U',
#   '4608',
#   'WUH',
#   '3376',
#   'CKG',
#   '3393',
#   None,
#   '0',
#   '319',
#   3296,
#   '3393',
#   'Jiangbei',
#   'Chongqing',
#   'China',
#   'CKG',
#   'ZUCK',
#   '29.719217',
#   '106.641678',
#   '1365',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (938,
#   '3U',
#   '4608',
#   'WUH',
#   '3376',
#   'CTU',
#   '3395',
#   None,
#   '0',
#   '319',
#   3298,
#   '3395',
#   'Shuangliu',
#   'Chengdu',
#   'China',
#   'CTU',
#   'ZUUU',
#   '30.578528',
#   '103.947086',
#   '1625',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (939,
#   '3U',
#   '4608',
#   'WUH',
#   '3376',
#   'HRB',
#   '3400',
#   None,
#   '0',
#   '321',
#   3303,
#   '3400',
#   'Taiping',
#   'Harbin',
#   'China',
#   'HRB',
#   'ZYHB',
#   '45.623403',
#   '126.250328',
#   '457',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (940,
#   '3U',
#   '4608',
#   'WUH',
#   '3376',
#   'JJN',
#   '6386',
#   None,
#   '0',
#   '319',
#   5259,
#   '6386',
#   'Quanzhou Airport',
#   'Quanzhou',
#   'China',
#   'JJN',
#   'ZSQZ',
#   '24.7964',
#   '118.59',
#   '0',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (941,
#   '3U',
#   '4608',
#   'WUH',
#   '3376',
#   'NNG',
#   '3373',
#   None,
#   '0',
#   '321',
#   3276,
#   '3373',
#   'Wuxu',
#   'Nanning',
#   'China',
#   'NNG',
#   'ZGNN',
#   '22.608267',
#   '108.172442',
#   '421',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (942,
#   '3U',
#   '4608',
#   'WUH',
#   '3376',
#   'NTG',
#   '5475',
#   None,
#   '0',
#   '319',
#   4846,
#   '5475',
#   'Nantong Airport',
#   'Nantong',
#   'China',
#   'NTG',
#   None,
#   '32.0708',
#   '120.976',
#   '0',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (943,
#   '3U',
#   '4608',
#   'WUX',
#   '6390',
#   'CKG',
#   '3393',
#   None,
#   '0',
#   '319',
#   3296,
#   '3393',
#   'Jiangbei',
#   'Chongqing',
#   'China',
#   'CKG',
#   'ZUCK',
#   '29.719217',
#   '106.641678',
#   '1365',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (944,
#   '3U',
#   '4608',
#   'WUX',
#   '6390',
#   'CTU',
#   '3395',
#   None,
#   '0',
#   '320',
#   3298,
#   '3395',
#   'Shuangliu',
#   'Chengdu',
#   'China',
#   'CTU',
#   'ZUUU',
#   '30.578528',
#   '103.947086',
#   '1625',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (945,
#   '3U',
#   '4608',
#   'WXN',
#   '6403',
#   'CTU',
#   '3395',
#   None,
#   '0',
#   '319',
#   3298,
#   '3395',
#   'Shuangliu',
#   'Chengdu',
#   'China',
#   'CTU',
#   'ZUUU',
#   '30.578528',
#   '103.947086',
#   '1625',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (946,
#   '3U',
#   '4608',
#   'WXN',
#   '6403',
#   'KMG',
#   '3382',
#   None,
#   '0',
#   '320',
#   3285,
#   '3382',
#   'Wujiaba',
#   'Kunming',
#   'China',
#   'KMG',
#   'ZPPP',
#   '24.992364',
#   '102.743536',
#   '6217',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (947,
#   '3U',
#   '4608',
#   'WXN',
#   '6403',
#   'PEK',
#   '3364',
#   None,
#   '0',
#   '320',
#   3268,
#   '3364',
#   'Capital Intl',
#   'Beijing',
#   'China',
#   'PEK',
#   'ZBAA',
#   '40.080111',
#   '116.584556',
#   '116',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (948,
#   '3U',
#   '4608',
#   'WXN',
#   '6403',
#   'SZX',
#   '3374',
#   None,
#   '0',
#   '319',
#   3277,
#   '3374',
#   'Baoan Intl',
#   'Shenzhen',
#   'China',
#   'SZX',
#   'ZGSZ',
#   '22.639258',
#   '113.810664',
#   '13',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (949,
#   '3U',
#   '4608',
#   'XIC',
#   '3396',
#   'CTU',
#   '3395',
#   None,
#   '0',
#   '320',
#   3298,
#   '3395',
#   'Shuangliu',
#   'Chengdu',
#   'China',
#   'CTU',
#   'ZUUU',
#   '30.578528',
#   '103.947086',
#   '1625',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (950,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'BHY',
#   '6351',
#   None,
#   '0',
#   '321',
#   5224,
#   '6351',
#   'Beihai Airport',
#   'Beihai',
#   'China',
#   'BHY',
#   'ZGBH',
#   '21.5394',
#   '109.294',
#   '0',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (951,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'CKG',
#   '3393',
#   None,
#   '0',
#   '319',
#   3296,
#   '3393',
#   'Jiangbei',
#   'Chongqing',
#   'China',
#   'CKG',
#   'ZUCK',
#   '29.719217',
#   '106.641678',
#   '1365',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (952,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'CTU',
#   '3395',
#   None,
#   '0',
#   '320 319',
#   3298,
#   '3395',
#   'Shuangliu',
#   'Chengdu',
#   'China',
#   'CTU',
#   'ZUUU',
#   '30.578528',
#   '103.947086',
#   '1625',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (953,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'FOC',
#   '3385',
#   None,
#   '0',
#   '319',
#   3288,
#   '3385',
#   'Changle',
#   'Fuzhou',
#   'China',
#   'FOC',
#   'ZSFZ',
#   '25.935064',
#   '119.663272',
#   '46',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (954,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'GXH',
#   '9311',
#   None,
#   '0',
#   '319',
#   7876,
#   '9311',
#   'Gannan',
#   'Xiahe city',
#   'China',
#   'GXH',
#   'ZLXH',
#   '34.4909',
#   '102.3719',
#   '10466',
#   '8',
#   'N',
#   'Asia/Chongqing'),
#  (955,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'HRB',
#   '3400',
#   None,
#   '0',
#   '321',
#   3303,
#   '3400',
#   'Taiping',
#   'Harbin',
#   'China',
#   'HRB',
#   'ZYHB',
#   '45.623403',
#   '126.250328',
#   '457',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (956,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'KMG',
#   '3382',
#   None,
#   '0',
#   '320',
#   3285,
#   '3382',
#   'Wujiaba',
#   'Kunming',
#   'China',
#   'KMG',
#   'ZPPP',
#   '24.992364',
#   '102.743536',
#   '6217',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (957,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'LXA',
#   '4097',
#   None,
#   '0',
#   '319',
#   3988,
#   '4097',
#   'Lhasa-Gonggar',
#   'Lhasa',
#   'China',
#   'LXA',
#   'ZULS',
#   '29.297778',
#   '90.911944',
#   '13136',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (958,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'LYI',
#   '6385',
#   None,
#   '0',
#   '319 320',
#   5258,
#   '6385',
#   'Shubuling Airport',
#   'Linyi',
#   'China',
#   'LYI',
#   'ZSLY',
#   '35.0461',
#   '118.412',
#   '0',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (959,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'TNA',
#   '4108',
#   None,
#   '0',
#   '320',
#   3999,
#   '4108',
#   'Jinan',
#   'Jinan',
#   'China',
#   'TNA',
#   'ZSJN',
#   '36.857214',
#   '117.215992',
#   '76',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (960,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'URC',
#   '3399',
#   None,
#   '0',
#   '319',
#   3302,
#   '3399',
#   'Diwopu',
#   'Urumqi',
#   'China',
#   'URC',
#   'ZWWW',
#   '43.907106',
#   '87.474244',
#   '2125',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (961,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'UYN',
#   '6368',
#   None,
#   '0',
#   '319',
#   5241,
#   '6368',
#   'Yulin Airport',
#   'Yulin',
#   'China',
#   'UYN',
#   'ZLYL',
#   '38.2692',
#   '109.731',
#   '0',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (962,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'XMN',
#   '3383',
#   None,
#   '0',
#   '319',
#   3286,
#   '3383',
#   'Gaoqi',
#   'Xiamen',
#   'China',
#   'XMN',
#   'ZSAM',
#   '24.544036',
#   '118.127739',
#   '59',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (963,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'XNN',
#   '6366',
#   None,
#   '0',
#   '319',
#   5239,
#   '6366',
#   'Xining Caojiabu Airport',
#   'Xining',
#   'China',
#   'XNN',
#   'ZLXN',
#   '36.5275',
#   '102.043',
#   '0',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (964,
#   '3U',
#   '4608',
#   'XIY',
#   '3379',
#   'YBP',
#   '4110',
#   None,
#   '0',
#   '319',
#   4001,
#   '4110',
#   'Yibin',
#   'Yibin',
#   'China',
#   'YBP',
#   'ZUYB',
#   '28.800278',
#   '104.544444',
#   '1000',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (965,
#   '3U',
#   '4608',
#   'XMN',
#   '3383',
#   'CSX',
#   '3371',
#   None,
#   '0',
#   '321',
#   3274,
#   '3371',
#   'Huanghua',
#   'Changcha',
#   'China',
#   'CSX',
#   'ZGHA',
#   '28.189158',
#   '113.219633',
#   '217',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (966,
#   '3U',
#   '4608',
#   'XMN',
#   '3383',
#   'CTU',
#   '3395',
#   None,
#   '0',
#   '320',
#   3298,
#   '3395',
#   'Shuangliu',
#   'Chengdu',
#   'China',
#   'CTU',
#   'ZUUU',
#   '30.578528',
#   '103.947086',
#   '1625',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (967,
#   '3U',
#   '4608',
#   'XMN',
#   '3383',
#   'CZX',
#   '4109',
#   None,
#   '0',
#   '321',
#   4000,
#   '4109',
#   'Changzhou',
#   'Changzhou',
#   'China',
#   'CZX',
#   'ZSCG',
#   '31.941667',
#   '119.711667',
#   '39',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (968,
#   '3U',
#   '4608',
#   'XMN',
#   '3383',
#   'KMG',
#   '3382',
#   None,
#   '0',
#   '320',
#   3285,
#   '3382',
#   'Wujiaba',
#   'Kunming',
#   'China',
#   'KMG',
#   'ZPPP',
#   '24.992364',
#   '102.743536',
#   '6217',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (969,
#   '3U',
#   '4608',
#   'XMN',
#   '3383',
#   'KOW',
#   '6379',
#   None,
#   '0',
#   '320',
#   5252,
#   '6379',
#   'Ganzhou Airport',
#   'Ganzhou',
#   'China',
#   'KOW',
#   'ZSGZ',
#   '25.8258',
#   '114.912',
#   '0',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (970,
#   '3U',
#   '4608',
#   'XMN',
#   '3383',
#   'XIY',
#   '3379',
#   None,
#   '0',
#   '319',
#   3282,
#   '3379',
#   'Xianyang',
#   "Xi'an",
#   'China',
#   'XIY',
#   'ZLXY',
#   '34.447119',
#   '108.751592',
#   '1572',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (971,
#   '3U',
#   '4608',
#   'XNN',
#   '6366',
#   'CKG',
#   '3393',
#   None,
#   '0',
#   '320',
#   3296,
#   '3393',
#   'Jiangbei',
#   'Chongqing',
#   'China',
#   'CKG',
#   'ZUCK',
#   '29.719217',
#   '106.641678',
#   '1365',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (972,
#   '3U',
#   '4608',
#   'XNN',
#   '6366',
#   'CTU',
#   '3395',
#   None,
#   '0',
#   '320',
#   3298,
#   '3395',
#   'Shuangliu',
#   'Chengdu',
#   'China',
#   'CTU',
#   'ZUUU',
#   '30.578528',
#   '103.947086',
#   '1625',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (973,
#   '3U',
#   '4608',
#   'XNN',
#   '6366',
#   'LXA',
#   '4097',
#   None,
#   '0',
#   '319',
#   3988,
#   '4097',
#   'Lhasa-Gonggar',
#   'Lhasa',
#   'China',
#   'LXA',
#   'ZULS',
#   '29.297778',
#   '90.911944',
#   '13136',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (974,
#   '3U',
#   '4608',
#   'XNN',
#   '6366',
#   'MIG',
#   '6400',
#   None,
#   '0',
#   '320',
#   5273,
#   '6400',
#   'Mianyang Airport',
#   'Mianyang',
#   'China',
#   'MIG',
#   'ZUMY',
#   '31.4281',
#   '104.741',
#   '0',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (975,
#   '3U',
#   '4608',
#   'XNN',
#   '6366',
#   'XIY',
#   '3379',
#   None,
#   '0',
#   '319',
#   3282,
#   '3379',
#   'Xianyang',
#   "Xi'an",
#   'China',
#   'XIY',
#   'ZLXY',
#   '34.447119',
#   '108.751592',
#   '1572',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (976,
#   '3U',
#   '4608',
#   'XNN',
#   '6366',
#   'ZHY',
#   '8043',
#   None,
#   '0',
#   '320',
#   6616,
#   '8043',
#   'Zhongwei Xiangshan Airport',
#   'Zhongwei',
#   'China',
#   'ZHY',
#   'ZLZW',
#   '37.5728',
#   '105.1544',
#   '4305',
#   '8',
#   'N',
#   'Asia/Chongqing'),
#  (977,
#   '3U',
#   '4608',
#   'XUZ',
#   '4149',
#   'CTU',
#   '3395',
#   None,
#   '0',
#   '320',
#   3298,
#   '3395',
#   'Shuangliu',
#   'Chengdu',
#   'China',
#   'CTU',
#   'ZUUU',
#   '30.578528',
#   '103.947086',
#   '1625',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (978,
#   '3U',
#   '4608',
#   'XUZ',
#   '4149',
#   'DLC',
#   '3404',
#   None,
#   '0',
#   '320',
#   3306,
#   '3404',
#   'Zhoushuizi',
#   'Dalian',
#   'China',
#   'DLC',
#   'ZYTL',
#   '38.965667',
#   '121.5386',
#   '107',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (979,
#   '3U',
#   '4608',
#   'XUZ',
#   '4149',
#   'HRB',
#   '3400',
#   None,
#   '0',
#   '320 321',
#   3303,
#   '3400',
#   'Taiping',
#   'Harbin',
#   'China',
#   'HRB',
#   'ZYHB',
#   '45.623403',
#   '126.250328',
#   '457',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (980,
#   '3U',
#   '4608',
#   'XUZ',
#   '4149',
#   'KMG',
#   '3382',
#   None,
#   '0',
#   '320',
#   3285,
#   '3382',
#   'Wujiaba',
#   'Kunming',
#   'China',
#   'KMG',
#   'ZPPP',
#   '24.992364',
#   '102.743536',
#   '6217',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (981,
#   '3U',
#   '4608',
#   'XUZ',
#   '4149',
#   'KWE',
#   '3394',
#   None,
#   '0',
#   '321',
#   3297,
#   '3394',
#   'Longdongbao',
#   'Guiyang',
#   'China',
#   'KWE',
#   'ZUGY',
#   '26.538522',
#   '106.800703',
#   '3736',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (982,
#   '3U',
#   '4608',
#   'XUZ',
#   '4149',
#   'SHE',
#   '4144',
#   None,
#   '0',
#   '320',
#   4034,
#   '4144',
#   'Shenyang Taoxian International Airport',
#   'Shenyang',
#   'China',
#   'SHE',
#   'ZYTX',
#   '41.3824',
#   '123.2901',
#   '198',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (983,
#   '3U',
#   '4608',
#   'YBP',
#   '4110',
#   'SYX',
#   '4030',
#   None,
#   '0',
#   '319',
#   3922,
#   '4030',
#   'Phoenix International',
#   'Sanya',
#   'China',
#   'SYX',
#   'ZJSY',
#   '18.302897',
#   '109.412272',
#   '92',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (984,
#   '3U',
#   '4608',
#   'YBP',
#   '4110',
#   'XIY',
#   '3379',
#   None,
#   '0',
#   '319',
#   3282,
#   '3379',
#   'Xianyang',
#   "Xi'an",
#   'China',
#   'XIY',
#   'ZLXY',
#   '34.447119',
#   '108.751592',
#   '1572',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (985,
#   '3U',
#   '4608',
#   'YIH',
#   '6361',
#   'CKG',
#   '3393',
#   None,
#   '0',
#   '319',
#   3296,
#   '3393',
#   'Jiangbei',
#   'Chongqing',
#   'China',
#   'CKG',
#   'ZUCK',
#   '29.719217',
#   '106.641678',
#   '1365',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (986,
#   '3U',
#   '4608',
#   'YIH',
#   '6361',
#   'CTU',
#   '3395',
#   None,
#   '0',
#   '320',
#   3298,
#   '3395',
#   'Shuangliu',
#   'Chengdu',
#   'China',
#   'CTU',
#   'ZUUU',
#   '30.578528',
#   '103.947086',
#   '1625',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (987,
#   '3U',
#   '4608',
#   'YIH',
#   '6361',
#   'HKG',
#   '3077',
#   None,
#   '0',
#   '320',
#   2996,
#   '3077',
#   'Hong Kong Intl',
#   'Hong Kong',
#   'Hong Kong',
#   'HKG',
#   'VHHH',
#   '22.308919',
#   '113.914603',
#   '28',
#   '8',
#   'U',
#   'Asia/Hong_Kong'),
#  (988,
#   '3U',
#   '4608',
#   'YTY',
#   '8876',
#   'CTU',
#   '3395',
#   None,
#   '0',
#   '319',
#   3298,
#   '3395',
#   'Shuangliu',
#   'Chengdu',
#   'China',
#   'CTU',
#   'ZUUU',
#   '30.578528',
#   '103.947086',
#   '1625',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (989,
#   '3U',
#   '4608',
#   'YVR',
#   '156',
#   'SHE',
#   '4144',
#   None,
#   '0',
#   '330',
#   4034,
#   '4144',
#   'Shenyang Taoxian International Airport',
#   'Shenyang',
#   'China',
#   'SHE',
#   'ZYTX',
#   '41.3824',
#   '123.2901',
#   '198',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (990,
#   '3U',
#   '4608',
#   'ZHA',
#   '6357',
#   'CKG',
#   '3393',
#   None,
#   '0',
#   '319',
#   3296,
#   '3393',
#   'Jiangbei',
#   'Chongqing',
#   'China',
#   'CKG',
#   'ZUCK',
#   '29.719217',
#   '106.641678',
#   '1365',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (991,
#   '3U',
#   '4608',
#   'ZHA',
#   '6357',
#   'HKG',
#   '3077',
#   None,
#   '0',
#   '319',
#   2996,
#   '3077',
#   'Hong Kong Intl',
#   'Hong Kong',
#   'Hong Kong',
#   'HKG',
#   'VHHH',
#   '22.308919',
#   '113.914603',
#   '28',
#   '8',
#   'U',
#   'Asia/Hong_Kong'),
#  (992,
#   '3U',
#   '4608',
#   'ZHY',
#   '8043',
#   'PEK',
#   '3364',
#   None,
#   '0',
#   '320',
#   3268,
#   '3364',
#   'Capital Intl',
#   'Beijing',
#   'China',
#   'PEK',
#   'ZBAA',
#   '40.080111',
#   '116.584556',
#   '116',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (993,
#   '3U',
#   '4608',
#   'ZHY',
#   '8043',
#   'XNN',
#   '6366',
#   None,
#   '0',
#   '320',
#   5239,
#   '6366',
#   'Xining Caojiabu Airport',
#   'Xining',
#   'China',
#   'XNN',
#   'ZLXN',
#   '36.5275',
#   '102.043',
#   '0',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (994,
#   '3U',
#   '4608',
#   'ZUH',
#   '6355',
#   'CZX',
#   '4109',
#   None,
#   '0',
#   '320',
#   4000,
#   '4109',
#   'Changzhou',
#   'Changzhou',
#   'China',
#   'CZX',
#   'ZSCG',
#   '31.941667',
#   '119.711667',
#   '39',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (995,
#   '3U',
#   '4608',
#   'ZUH',
#   '6355',
#   'HAK',
#   '4120',
#   None,
#   '0',
#   '320',
#   4011,
#   '4120',
#   'Meilan',
#   'Haikou',
#   'China',
#   'HAK',
#   'ZJHK',
#   '19.934856',
#   '110.458961',
#   '75',
#   '8',
#   'U',
#   'Asia/Chongqing'),
#  (996,
#   '4B',
#   '\\N',
#   'LAS',
#   '3877',
#   'LAX',
#   '3484',
#   None,
#   '0',
#   'PL2',
#   3385,
#   '3484',
#   'Los Angeles Intl',
#   'Los Angeles',
#   'United States',
#   'LAX',
#   'KLAX',
#   '33.942536',
#   '-118.408075',
#   '126',
#   '-8',
#   'A',
#   'America/Los_Angeles'),
#  (997,
#   '4B',
#   '\\N',
#   'LAX',
#   '3484',
#   'LAS',
#   '3877',
#   None,
#   '0',
#   'PL2',
#   3778,
#   '3877',
#   'Mc Carran Intl',
#   'Las Vegas',
#   'United States',
#   'LAS',
#   'KLAS',
#   '36.080056',
#   '-115.15225',
#   '2141',
#   '-8',
#   'A',
#   'America/Los_Angeles'),
#  (998,
#   '4D',
#   '442',
#   'CAI',
#   '1128',
#   'TLV',
#   '1590',
#   None,
#   '0',
#   'E70',
#   1563,
#   '1590',
#   'Ben Gurion',
#   'Tel-aviv',
#   'Israel',
#   'TLV',
#   'LLBG',
#   '32.011389',
#   '34.886667',
#   '135',
#   '2',
#   'U',
#   'Asia/Jerusalem'),
#  (999,
#   '4D',
#   '442',
#   'TLV',
#   '1590',
#   'CAI',
#   '1128',
#   None,
#   '0',
#   'E70',
#   1107,
#   '1128',
#   'Cairo Intl',
#   'Cairo',
#   'Egypt',
#   'CAI',
#   'HECA',
#   '30.121944',
#   '31.405556',
#   '382',
#   '2',
#   'U',
#   'Africa/Cairo'),
#  (1000,
#   '4E',
#   '\\N',
#   'MCG',
#   '5965',
#   'NIB',
#   '7214',
#   None,
#   '0',
#   'PAG',
#   5789,
#   '7214',
#   'Nikolai Airport',
#   'Nikolai',
#   'United States',
#   'NIB',
#   'PAFS',
#   '63.010833',
#   '-154.383889',
#   '427',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  (1001,
#   '4E',
#   '\\N',
#   'MCG',
#   '5965',
#   'TCT',
#   '7215',
#   None,
#   '0',
#   'PAG',
#   5790,
#   '7215',
#   'Takotna Airport',
#   'Takotna',
#   'United States',
#   'TCT',
#   '\\N',
#   '62.971944',
#   '-156.082778',
#   '825',
#   '-9',
#   'A',
#   'America/Anchorage'),
#  ...]

# %% [markdown]
# ### Grouping statements
#
# Combines `select` and `group by` when you want aggregates by values

# %% [markdown]
# `select` `min(x)` ... `max()`, `sum()`, etc

# %% [markdown]
# `group by x`

# %% [markdown]
# **Task**<br>
# - Which countries have the highest numbers of active airlines?
# - Which countries have the highest numbers of inactive airlines?

# %%
cursor.execute(
"""
SELECT COUNT() num, country
FROM airlines
WHERE active='Y'
GROUP BY country
HAVING num > 10
ORDER BY num DESC
LIMIT 30
"""
).fetchall()
# Out:
# [(141, 'United States'),
#  (72, 'Russia'),
#  (40, 'United Kingdom'),
#  (37, 'Germany'),
#  (34, 'Canada'),
#  (26, 'Australia'),
#  (25, 'China'),
#  (24, 'Spain'),
#  (23, 'Brazil'),
#  (22, 'France'),
#  (19, 'Japan'),
#  (18, 'Italy'),
#  (17, 'Indonesia'),
#  (17, 'India'),
#  (16, 'Turkey'),
#  (16, 'Thailand'),
#  (15, 'Sweden'),
#  (14, 'Switzerland'),
#  (13, 'Ukraine'),
#  (13, 'Portugal'),
#  (12, 'Mexico'),
#  (12, 'Finland'),
#  (12, 'Egypt'),
#  (12, 'Austria'),
#  (11, 'Peru')]

# %%
cursor.execute(
"""
SELECT COUNT() num, country
FROM airlines
WHERE active='N'
GROUP BY country
HAVING num > 10
ORDER BY num DESC
LIMIT 30
"""
).fetchall()
# Out:
# [(939, 'United States'),
#  (427, 'Mexico'),
#  (367, 'United Kingdom'),
#  (284, 'Canada'),
#  (158, 'Russia'),
#  (142, 'Spain'),
#  (97, 'France'),
#  (94, 'Germany'),
#  (81, 'South Africa'),
#  (80, 'Nigeria'),
#  (76, 'Ukraine'),
#  (73, 'Kazakhstan'),
#  (72, 'Italy'),
#  (67, 'Australia'),
#  (55, 'Sweden'),
#  (47, 'Sudan'),
#  (46, 'Switzerland'),
#  (45, 'China'),
#  (43, 'Netherlands'),
#  (38, 'Austria'),
#  (36, 'Egypt'),
#  (35, 'Chile'),
#  (35, 'Brazil'),
#  (35, 'Angola'),
#  (34, 'Colombia'),
#  (32, 'Thailand'),
#  (32, 'Portugal'),
#  (32, 'Mauritania'),
#  (31, 'Indonesia'),
#  (29, 'Kyrgyzstan')]

# %% [markdown]
# **Exercise**: Run a query that will return the number of airports by time zone. Each row should have a number of airports and a time zone.

# %%
# Your code here
cursor.execute(
    """SELECT COUNT() num, timezone
       FROM airports
       GROUP BY timezone
       ORDER BY num DESC
    """
).fetchall()[:3]
# Out:
# [(628, 'America/New_York'), (373, 'America/Chicago'), (319, 'Europe/Berlin')]

# %% [markdown]
# ### `CASE WHEN`
#
# `CASE WHEN` is SQL's version of `if ... then ... else`. It must *always* be closed with an `END`.

# %%
cursor.execute(
"""
SELECT name, city,
CASE WHEN latitude > 0 THEN 'northern hemisphere'
ELSE 'southern hemisphere'
END AS hemisphere
FROM airports
"""
).fetchall()
# Out:
# [('Goroka', 'Goroka', 'southern hemisphere'),
#  ('Madang', 'Madang', 'southern hemisphere'),
#  ('Mount Hagen', 'Mount Hagen', 'southern hemisphere'),
#  ('Nadzab', 'Nadzab', 'southern hemisphere'),
#  ('Port Moresby Jacksons Intl', 'Port Moresby', 'southern hemisphere'),
#  ('Wewak Intl', 'Wewak', 'southern hemisphere'),
#  ('Narsarsuaq', 'Narssarssuaq', 'northern hemisphere'),
#  ('Nuuk', 'Godthaab', 'northern hemisphere'),
#  ('Sondre Stromfjord', 'Sondrestrom', 'northern hemisphere'),
#  ('Thule Air Base', 'Thule', 'northern hemisphere'),
#  ('Akureyri', 'Akureyri', 'northern hemisphere'),
#  ('Egilsstadir', 'Egilsstadir', 'northern hemisphere'),
#  ('Hornafjordur', 'Hofn', 'northern hemisphere'),
#  ('Husavik', 'Husavik', 'northern hemisphere'),
#  ('Isafjordur', 'Isafjordur', 'northern hemisphere'),
#  ('Keflavik International Airport', 'Keflavik', 'northern hemisphere'),
#  ('Patreksfjordur', 'Patreksfjordur', 'northern hemisphere'),
#  ('Reykjavik', 'Reykjavik', 'northern hemisphere'),
#  ('Siglufjordur', 'Siglufjordur', 'northern hemisphere'),
#  ('Vestmannaeyjar', 'Vestmannaeyjar', 'northern hemisphere'),
#  ('Sault Ste Marie', 'Sault Sainte Marie', 'northern hemisphere'),
#  ('Winnipeg St Andrews', 'Winnipeg', 'northern hemisphere'),
#  ('Shearwater', 'Halifax', 'northern hemisphere'),
#  ('St Anthony', 'St. Anthony', 'northern hemisphere'),
#  ('Tofino', 'Tofino', 'northern hemisphere'),
#  ('Kugaaruk', 'Pelly Bay', 'northern hemisphere'),
#  ('Baie Comeau', 'Baie Comeau', 'northern hemisphere'),
#  ('Bagotville', 'Bagotville', 'northern hemisphere'),
#  ('Baker Lake', 'Baker Lake', 'northern hemisphere'),
#  ('Campbell River', 'Campbell River', 'northern hemisphere'),
#  ('Brandon Muni', 'Brandon', 'northern hemisphere'),
#  ('Cambridge Bay', 'Cambridge Bay', 'northern hemisphere'),
#  ('Nanaimo', 'Nanaimo', 'northern hemisphere'),
#  ('Castlegar', 'Castlegar', 'northern hemisphere'),
#  ('Miramichi', 'Chatham', 'northern hemisphere'),
#  ('Charlo', 'Charlo', 'northern hemisphere'),
#  ('Kugluktuk', 'Coppermine', 'northern hemisphere'),
#  ('Coronation', 'Coronation', 'northern hemisphere'),
#  ('Chilliwack', 'Chilliwack', 'northern hemisphere'),
#  ('Clyde River', 'Clyde River', 'northern hemisphere'),
#  ('Fairmont Hot Springs', 'Coral Harbour', 'northern hemisphere'),
#  ('Dawson City', 'Dawson', 'northern hemisphere'),
#  ('Burwash', 'Burwash', 'northern hemisphere'),
#  ('Princeton', 'Princeton', 'northern hemisphere'),
#  ('Deer Lake', 'Deer Lake', 'northern hemisphere'),
#  ('Dease Lake', 'Dease Lake', 'northern hemisphere'),
#  ('Dauphin Barker', 'Dauphin', 'northern hemisphere'),
#  ('Dawson Creek', 'Dawson Creek', 'northern hemisphere'),
#  ('Edmonton Intl', 'Edmonton', 'northern hemisphere'),
#  ('Arviat', 'Eskimo Point', 'northern hemisphere'),
#  ('Estevan', 'Estevan', 'northern hemisphere'),
#  ('Edson', 'Edson', 'northern hemisphere'),
#  ('Eureka', 'Eureka', 'northern hemisphere'),
#  ('Inuvik Mike Zubko', 'Inuvik', 'northern hemisphere'),
#  ('Iqaluit', 'Iqaluit', 'northern hemisphere'),
#  ('Fredericton', 'Fredericton', 'northern hemisphere'),
#  ('Forestville', 'Forestville', 'northern hemisphere'),
#  ('Flin Flon', 'Flin Flon', 'northern hemisphere'),
#  ('Fort Resolution', 'Fort Resolution', 'northern hemisphere'),
#  ('Fort Simpson', 'Fort Simpson', 'northern hemisphere'),
#  ('Kingston', 'Kingston', 'northern hemisphere'),
#  ('La Grande Riviere', 'La Grande Riviere', 'northern hemisphere'),
#  ('Gaspe', 'Gaspe', 'northern hemisphere'),
#  ('Geraldton Greenstone Regional', 'Geraldton', 'northern hemisphere'),
#  ('Iles De La Madeleine', 'Iles De La Madeleine', 'northern hemisphere'),
#  ('Hudson Bay', 'Hudson Bay', 'northern hemisphere'),
#  ('Dryden Rgnl', 'Dryden', 'northern hemisphere'),
#  ('Ulukhaktok Holman', 'Holman Island', 'northern hemisphere'),
#  ('Gjoa Haven', 'Gjoa Haven', 'northern hemisphere'),
#  ('Hamilton', 'Hamilton', 'northern hemisphere'),
#  ('St Hubert', 'Montreal', 'northern hemisphere'),
#  ('Hay River', 'Hay River', 'northern hemisphere'),
#  ('Halifax Intl', 'Halifax', 'northern hemisphere'),
#  ('Atikokan Muni', 'Atikokan', 'northern hemisphere'),
#  ('Pond Inlet', 'Pond Inlet', 'northern hemisphere'),
#  ('St Jean', 'St. Jean', 'northern hemisphere'),
#  ('Stephenville', 'Stephenville', 'northern hemisphere'),
#  ('Kamloops', 'Kamloops', 'northern hemisphere'),
#  ('Waterloo', 'Waterloo', 'northern hemisphere'),
#  ('Schefferville', 'Schefferville', 'northern hemisphere'),
#  ('Kindersley', 'Kindersley', 'northern hemisphere'),
#  ('Buttonville Muni', 'Toronto', 'northern hemisphere'),
#  ('Chapleau', 'Chapleau', 'northern hemisphere'),
#  ('Meadow Lake', 'Meadow Lake', 'northern hemisphere'),
#  ('Lloydminster', 'Lloydminster', 'northern hemisphere'),
#  ('Alert', 'Alert', 'northern hemisphere'),
#  ('Kelowna', 'Kelowna', 'northern hemisphere'),
#  ('Mayo', 'Mayo', 'northern hemisphere'),
#  ('Moose Jaw Air Vice Marshal C M Mcewen', 'Moose Jaw', 'northern hemisphere'),
#  ('Fort Mcmurray', 'Fort Mcmurray', 'northern hemisphere'),
#  ('Moosonee', 'Moosonee', 'northern hemisphere'),
#  ('Maniwaki', 'Maniwaki', 'northern hemisphere'),
#  ('Montreal Intl Mirabel', 'Montreal', 'northern hemisphere'),
#  ('Natashquan', 'Natashquan', 'northern hemisphere'),
#  ('Gatineau', 'Gatineau', 'northern hemisphere'),
#  ('Matagami', 'Matagami', 'northern hemisphere'),
#  ('Old Crow', 'Old Crow', 'northern hemisphere'),
#  ('Cold Lake', 'Cold Lake', 'northern hemisphere'),
#  ('High Level', 'High Level', 'northern hemisphere'),
#  ('Ottawa Macdonald Cartier Intl', 'Ottawa', 'northern hemisphere'),
#  ('Prince Albert Glass Field', 'Prince Albert', 'northern hemisphere'),
#  ('Peace River', 'Peace River', 'northern hemisphere'),
#  ('Southport', 'Portage-la-prairie', 'northern hemisphere'),
#  ('Pitt Meadows', 'Pitt Meadows', 'northern hemisphere'),
#  ('Pickle Lake', 'Pickle Lake', 'northern hemisphere'),
#  ('Port Menier', 'Port Menier', 'northern hemisphere'),
#  ('Peterborough', 'Peterborough', 'northern hemisphere'),
#  ('Prince Rupert', 'Prince Pupert', 'northern hemisphere'),
#  ('Fort Chipewyan', 'Fort Chipewyan', 'northern hemisphere'),
#  ('Muskoka', 'Muskoka', 'northern hemisphere'),
#  ('Quebec Jean Lesage Intl', 'Quebec', 'northern hemisphere'),
#  ('Red Deer Regional', 'Red Deer Industrial', 'northern hemisphere'),
#  ('Windsor', 'Windsor', 'northern hemisphere'),
#  ('Watson Lake', 'Watson Lake', 'northern hemisphere'),
#  ('Kenora', 'Kenora', 'northern hemisphere'),
#  ('Lethbridge', 'Lethbridge', 'northern hemisphere'),
#  ('Greater Moncton Intl', 'Moncton', 'northern hemisphere'),
#  ('Comox', 'Comox', 'northern hemisphere'),
#  ('Regina Intl', 'Regina', 'northern hemisphere'),
#  ('Thunder Bay', 'Thunder Bay', 'northern hemisphere'),
#  ('Grande Prairie', 'Grande Prairie', 'northern hemisphere'),
#  ('Yorkton Muni', 'Yorkton', 'northern hemisphere'),
#  ('North Battleford', 'North Battleford', 'northern hemisphere'),
#  ('Gander Intl', 'Gander', 'northern hemisphere'),
#  ('Sydney', 'Sydney', 'northern hemisphere'),
#  ('Quesnel', 'Quesnel', 'northern hemisphere'),
#  ('Resolute Bay', 'Resolute', 'northern hemisphere'),
#  ('Riviere Du Loup', 'Riviere Du Loup', 'northern hemisphere'),
#  ('Roberval', 'Roberval', 'northern hemisphere'),
#  ('Rocky Mountain House', 'Rocky Mountain House', 'northern hemisphere'),
#  ('Rankin Inlet', 'Rankin Inlet', 'northern hemisphere'),
#  ('Sudbury', 'Sudbury', 'northern hemisphere'),
#  ('Sherbrooke', 'Sherbrooke', 'northern hemisphere'),
#  ('Saint John', 'St. John', 'northern hemisphere'),
#  ('Fort Smith', 'Fort Smith', 'northern hemisphere'),
#  ('Nanisivik', 'Nanisivik', 'northern hemisphere'),
#  ('Summerside', 'Summerside', 'northern hemisphere'),
#  ('Sachs Harbour', 'Sachs Harbour', 'northern hemisphere'),
#  ('Cape Dorset', 'Cape Dorset', 'northern hemisphere'),
#  ('Thompson', 'Thompson', 'northern hemisphere'),
#  ('Trenton', 'Trenton', 'northern hemisphere'),
#  ('Timmins', 'Timmins', 'northern hemisphere'),
#  ('City Centre', 'Toronto', 'northern hemisphere'),
#  ('Tuktoyaktuk', 'Tuktoyaktuk', 'northern hemisphere'),
#  ('Pierre Elliott Trudeau Intl', 'Montreal', 'northern hemisphere'),
#  ('Repulse Bay', 'Repulse Bay', 'northern hemisphere'),
#  ('Hall Beach', 'Hall Beach', 'northern hemisphere'),
#  ('Rouyn Noranda', 'Rouyn', 'northern hemisphere'),
#  ('La Ronge', 'La Ronge', 'northern hemisphere'),
#  ('Vermilion', 'Vermillion', 'northern hemisphere'),
#  ('Qikiqtarjuaq', 'Broughton Island', 'northern hemisphere'),
#  ('Val D Or', "Val D'or", 'northern hemisphere'),
#  ('Kuujjuaq', 'Quujjuaq', 'northern hemisphere'),
#  ('Norman Wells', 'Norman Wells', 'northern hemisphere'),
#  ('Vancouver Intl', 'Vancouver', 'northern hemisphere'),
#  ('Buffalo Narrows', 'Buffalo Narrows', 'northern hemisphere'),
#  ('Wiarton', 'Wiarton', 'northern hemisphere'),
#  ('Petawawa', 'Petawawa', 'northern hemisphere'),
#  ('Winnipeg Intl', 'Winnipeg', 'northern hemisphere'),
#  ('Wabush', 'Wabush', 'northern hemisphere'),
#  ('Williams Lake', 'Williams Lake', 'northern hemisphere'),
#  ('Wrigley', 'Wrigley', 'northern hemisphere'),
#  ('Canadian Rockies Intl', 'Cranbrook', 'northern hemisphere'),
#  ('Edmonton City Centre', 'Edmonton', 'northern hemisphere'),
#  ('Saskatoon J G Diefenbaker Intl', 'Saskatoon', 'northern hemisphere'),
#  ('Medicine Hat', 'Medicine Hat', 'northern hemisphere'),
#  ('Fort St John', 'Fort Saint John', 'northern hemisphere'),
#  ('Sioux Lookout', 'Sioux Lookout', 'northern hemisphere'),
#  ('Pangnirtung', 'Pangnirtung', 'northern hemisphere'),
#  ('Timiskaming Rgnl', 'Earlton', 'northern hemisphere'),
#  ('Prince George', 'Prince George', 'northern hemisphere'),
#  ('Terrace', 'Terrace', 'northern hemisphere'),
#  ('London', 'London', 'northern hemisphere'),
#  ('Abbotsford', 'Abbotsford', 'northern hemisphere'),
#  ('Whitehorse Intl', 'Whitehorse', 'northern hemisphere'),
#  ('North Bay', 'North Bay', 'northern hemisphere'),
#  ('Calgary Intl', 'Calgary', 'northern hemisphere'),
#  ('Smithers', 'Smithers', 'northern hemisphere'),
#  ('Fort Nelson', 'Fort Nelson', 'northern hemisphere'),
#  ('Penticton', 'Penticton', 'northern hemisphere'),
#  ('Charlottetown', 'Charlottetown', 'northern hemisphere'),
#  ('Taloyoak', 'Spence Bay', 'northern hemisphere'),
#  ('Victoria Intl', 'Victoria', 'northern hemisphere'),
#  ('Lynn Lake', 'Lynn Lake', 'northern hemisphere'),
#  ('Swift Current', 'Swift Current', 'northern hemisphere'),
#  ('Churchill', 'Churchill', 'northern hemisphere'),
#  ('Goose Bay', 'Goose Bay', 'northern hemisphere'),
#  ('St Johns Intl', "St. John's", 'northern hemisphere'),
#  ('Kapuskasing', 'Kapuskasing', 'northern hemisphere'),
#  ('Armstrong', 'Armstrong', 'northern hemisphere'),
#  ('Mont Joli', 'Mont Joli', 'northern hemisphere'),
#  ('Lester B Pearson Intl', 'Toronto', 'northern hemisphere'),
#  ('Downsview', 'Toronto', 'northern hemisphere'),
#  ('Gore Bay Manitoulin', 'Gore Bay', 'northern hemisphere'),
#  ('Yellowknife', 'Yellowknife', 'northern hemisphere'),
#  ('Slave Lake', 'Slave Lake', 'northern hemisphere'),
#  ('Sandspit', 'Sandspit', 'northern hemisphere'),
#  ('Chris Hadfield', 'Sarnia', 'northern hemisphere'),
#  ('Port Hardy', 'Port Hardy', 'northern hemisphere'),
#  ('Whitecourt', 'Whitecourt', 'northern hemisphere'),
#  ('Sept Iles', 'Sept-iles', 'northern hemisphere'),
#  ('Teslin', 'Teslin', 'northern hemisphere'),
#  ('Greenwood', 'Greenwood', 'northern hemisphere'),
#  ('Faro', 'Faro', 'northern hemisphere'),
#  ('Fort Mcpherson', 'Fort Mcpherson', 'northern hemisphere'),
#  ('Blida', 'Blida', 'northern hemisphere'),
#  ('Bou Saada', 'Bou Saada', 'northern hemisphere'),
#  ('Soummam', 'Bejaja', 'northern hemisphere'),
#  ('Houari Boumediene', 'Algier', 'northern hemisphere'),
#  ('Tiska', 'Djanet', 'northern hemisphere'),
#  ('Boufarik', 'Boufarik', 'northern hemisphere'),
#  ('Reggane', 'Reggan', 'northern hemisphere'),
#  ('Illizi Takhamalt', 'Illizi', 'northern hemisphere'),
#  ('Ain Oussera', 'Ain Oussera', 'northern hemisphere'),
#  ('Tamanrasset', 'Tamanrasset', 'northern hemisphere'),
#  ('Jijel', 'Jijel', 'northern hemisphere'),
#  ('Mecheria', 'Mecheria', 'northern hemisphere'),
#  ('Relizane', 'Relizane', 'northern hemisphere'),
#  ('Annaba', 'Annaba', 'northern hemisphere'),
#  ('Mohamed Boudiaf Intl', 'Constantine', 'northern hemisphere'),
#  ('Cheikh Larbi Tebessi', 'Tebessa', 'northern hemisphere'),
#  ('Hassi R Mel', 'Tilrempt', 'northern hemisphere'),
#  ('Bou Chekif', 'Tiaret', 'northern hemisphere'),
#  ('Bou Sfer', 'Bou Sfer', 'northern hemisphere'),
#  ('Tindouf', 'Tindouf', 'northern hemisphere'),
#  ('Ech Cheliff', 'Ech-cheliff', 'northern hemisphere'),
#  ('Tafaraoui', 'Oran', 'northern hemisphere'),
#  ('Zenata', 'Tlemcen', 'northern hemisphere'),
#  ('Es Senia', 'Oran', 'northern hemisphere'),
#  ('Sidi Bel Abbes', 'Sidi Bel Abbes', 'northern hemisphere'),
#  ('Ghriss', 'Ghriss', 'northern hemisphere'),
#  ('Touat Cheikh Sidi Mohamed Belkebir', 'Adrar', 'northern hemisphere'),
#  ('Biskra', 'Biskra', 'northern hemisphere'),
#  ('El Golea', 'El Golea', 'northern hemisphere'),
#  ('Noumerat', 'Ghardaia', 'northern hemisphere'),
#  ('Oued Irara', 'Hassi Messaoud', 'northern hemisphere'),
#  ('In Salah', 'In Salah', 'northern hemisphere'),
#  ('Sidi Mahdi', 'Touggourt', 'northern hemisphere'),
#  ('Laghouat', 'Laghouat', 'northern hemisphere'),
#  ('Timimoun', 'Timimoun', 'northern hemisphere'),
#  ('Ouargla', 'Ouargla', 'northern hemisphere'),
#  ('In Amenas', 'Zarzaitine', 'northern hemisphere'),
#  ('Cadjehoun', 'Cotonou', 'northern hemisphere'),
#  ('Ouagadougou', 'Ouagadougou', 'northern hemisphere'),
#  ('Bobo Dioulasso', 'Bobo-dioulasso', 'northern hemisphere'),
#  ('Kotoka Intl', 'Accra', 'northern hemisphere'),
#  ('Tamale', 'Tamale', 'northern hemisphere'),
#  ('Wa', 'Wa', 'northern hemisphere'),
#  ('Sunyani', 'Sunyani', 'northern hemisphere'),
#  ('Takoradi', 'Takoradi', 'northern hemisphere'),
#  ('Abidjan Felix Houphouet Boigny Intl', 'Abidjan', 'northern hemisphere'),
#  ('Bouake', 'Bouake', 'northern hemisphere'),
#  ('Daloa', 'Daloa', 'northern hemisphere'),
#  ('Korhogo', 'Korhogo', 'northern hemisphere'),
#  ('Man', 'Man', 'northern hemisphere'),
#  ('San Pedro', 'San Pedro', 'northern hemisphere'),
#  ('Yamoussoukro', 'Yamoussoukro', 'northern hemisphere'),
#  ('Nnamdi Azikiwe Intl', 'Abuja', 'northern hemisphere'),
#  ('Akure', 'Akure', 'northern hemisphere'),
#  ('Benin', 'Benin', 'northern hemisphere'),
#  ('Calabar', 'Calabar', 'northern hemisphere'),
#  ('Enugu', 'Enugu', 'northern hemisphere'),
#  ('Gusau', 'Gusau', 'northern hemisphere'),
#  ('Ibadan', 'Ibadan', 'northern hemisphere'),
#  ('Ilorin', 'Ilorin', 'northern hemisphere'),
#  ('Yakubu Gowon', 'Jos', 'northern hemisphere'),
#  ('Kaduna', 'Kaduna', 'northern hemisphere'),
#  ('Mallam Aminu Intl', 'Kano', 'northern hemisphere'),
#  ('Maiduguri', 'Maiduguri', 'northern hemisphere'),
#  ('Makurdi', 'Makurdi', 'northern hemisphere'),
#  ('Murtala Muhammed', 'Lagos', 'northern hemisphere'),
#  ('Minna New', 'Minna', 'northern hemisphere'),
#  ('Port Harcourt Intl', 'Port Hartcourt', 'northern hemisphere'),
#  ('Sadiq Abubakar Iii Intl', 'Sokoto', 'northern hemisphere'),
#  ('Yola', 'Yola', 'northern hemisphere'),
#  ('Zaria', 'Zaria', 'northern hemisphere'),
#  ('Maradi', 'Maradi', 'northern hemisphere'),
#  ('Diori Hamani', 'Niamey', 'northern hemisphere'),
#  ('Tahoua', 'Tahoua', 'northern hemisphere'),
#  ('Manu Dayak', 'Agadez', 'northern hemisphere'),
#  ('Dirkou', 'Dirkou', 'northern hemisphere'),
#  ('Diffa', 'Diffa', 'northern hemisphere'),
#  ('Zinder', 'Zinder', 'northern hemisphere'),
#  ('Habib Bourguiba Intl', 'Monastir', 'northern hemisphere'),
#  ('Carthage', 'Tunis', 'northern hemisphere'),
#  ('Sidi Ahmed Air Base', 'Bizerte', 'northern hemisphere'),
#  ('Remada', 'Remada', 'northern hemisphere'),
#  ('Gafsa', 'Gafsa', 'northern hemisphere'),
#  ('Gabes', 'Gabes', 'northern hemisphere'),
#  ('Borj El Amri', 'Bordj El Amri', 'northern hemisphere'),
#  ('Zarzis', 'Djerba', 'northern hemisphere'),
#  ('El Borma', 'El Borma', 'northern hemisphere'),
#  ('Thyna', 'Sfax', 'northern hemisphere'),
#  ('Nefta', 'Tozeur', 'northern hemisphere'),
#  ('Niamtougou International', 'Niatougou', 'northern hemisphere'),
#  ('Gnassingbe Eyadema Intl', 'Lome', 'northern hemisphere'),
#  ('Deurne', 'Antwerp', 'northern hemisphere'),
#  ('Beauvechain', 'Beauvechain', 'northern hemisphere'),
#  ('Kleine Brogel', 'Kleine Brogel', 'northern hemisphere'),
#  ('Brussels Natl', 'Brussels', 'northern hemisphere'),
#  ('Bertrix', 'Bertrix', 'northern hemisphere'),
#  ('Brussels South', 'Charleroi', 'northern hemisphere'),
#  ('Chievres Ab', 'Chievres', 'northern hemisphere'),
#  ('Koksijde', 'Koksijde', 'northern hemisphere'),
#  ('Florennes', 'Florennes', 'northern hemisphere'),
#  ('Wevelgem', 'Kortrijk-vevelgem', 'northern hemisphere'),
#  ('Liege', 'Liege', 'northern hemisphere'),
#  ('Oostende', 'Ostend', 'northern hemisphere'),
#  ('Zutendaal', 'Zutendaal', 'northern hemisphere'),
#  ('Sint Truiden', 'Sint-truiden', 'northern hemisphere'),
#  ('Saint Hubert Mil', 'St.-hubert', 'northern hemisphere'),
#  ('Ursel', 'Ursel', 'northern hemisphere'),
#  ('Weelde', 'Weelde', 'northern hemisphere'),
#  ('Zoersel', 'Zoersel', 'northern hemisphere'),
#  ('Bautzen', 'Bautzen', 'northern hemisphere'),
#  ('Altenburg Nobitz', 'Altenburg', 'northern hemisphere'),
#  ('Dessau', 'Dessau', 'northern hemisphere'),
#  ('Eisenhuttenstadt', 'Eisenhuettenstadt', 'northern hemisphere'),
#  ('Putnam County Airport', 'Greencastle', 'northern hemisphere'),
#  ('Grossenhain', 'Suhl', 'northern hemisphere'),
#  ('Merseburg', 'Muehlhausen', 'northern hemisphere'),
#  ('Halle Oppin', 'Halle', 'northern hemisphere'),
#  ('Riesa Gohlis', 'Riesa', 'northern hemisphere'),
#  ('Rechlin Larz', 'Rechlin-laerz', 'northern hemisphere'),
#  ('Strausberg', 'Strausberg', 'northern hemisphere'),
#  ('Schonhagen', 'Schoenhagen', 'northern hemisphere'),
#  ('Barth', 'Barth', 'northern hemisphere'),
#  ('Jena Schongleina', 'Jena', 'northern hemisphere'),
#  ('Kyritz', 'Kyritz', 'northern hemisphere'),
#  ('Magdeburg', 'Magdeburg', 'northern hemisphere'),
#  ('Rothenburg Gorlitz', 'Rothenburg/ol', 'northern hemisphere'),
#  ('Anklam', 'Anklam', 'northern hemisphere'),
#  ('Cottbus Drewitz', 'Cottbus', 'northern hemisphere'),
#  ('Kamenz', 'Kamenz', 'northern hemisphere'),
#  ('Schonefeld', 'Berlin', 'northern hemisphere'),
#  ('Dresden', 'Dresden', 'northern hemisphere'),
#  ('Erfurt', 'Erfurt', 'northern hemisphere'),
#  ('Frankfurt Main', 'Frankfurt', 'northern hemisphere'),
#  ('Munster Osnabruck', 'Munster', 'northern hemisphere'),
#  ('Hamburg', 'Hamburg', 'northern hemisphere'),
#  ('Tempelhof', 'Berlin', 'northern hemisphere'),
#  ('Koln Bonn', 'Cologne', 'northern hemisphere'),
#  ('Dusseldorf', 'Duesseldorf', 'northern hemisphere'),
#  ('Franz Josef Strauss', 'Munich', 'northern hemisphere'),
#  ('Nurnberg', 'Nuernberg', 'northern hemisphere'),
#  ('Leipzig Halle', 'Leipzig', 'northern hemisphere'),
#  ('Saarbrucken', 'Saarbruecken', 'northern hemisphere'),
#  ('Stuttgart', 'Stuttgart', 'northern hemisphere'),
#  ('Tegel', 'Berlin', 'northern hemisphere'),
#  ('Hannover', 'Hannover', 'northern hemisphere'),
#  ('Neuenland', 'Bremen', 'northern hemisphere'),
#  ('Egelsbach', 'Egelsbach', 'northern hemisphere'),
#  ('Frankfurt Hahn', 'Hahn', 'northern hemisphere'),
#  ('Mannheim City', 'Mannheim', 'northern hemisphere'),
#  ('Allendorf Eder', 'Allendorf', 'northern hemisphere'),
#  ('Worms', 'Worms', 'northern hemisphere'),
#  ('Mainz Finthen', 'Mainz', 'northern hemisphere'),
#  ('Eisenach Kindel', 'Eisenach', 'northern hemisphere'),
#  ('Siegerland', 'Siegerland', 'northern hemisphere'),
#  ('Hamburg Finkenwerder', 'Hamburg', 'northern hemisphere'),
#  ('Kiel Holtenau', 'Kiel', 'northern hemisphere'),
#  ('Lubeck Blankensee', 'Luebeck', 'northern hemisphere'),
#  ('Dahlemer Binz', 'Dahlemer Binz', 'northern hemisphere'),
#  ('Meinerzhagen', 'Meinerzhagen', 'northern hemisphere'),
#  ('Arnsberg Menden', 'Arnsberg', 'northern hemisphere'),
#  ('Essen Mulheim', 'Essen', 'northern hemisphere'),
#  ('Bielefeld', 'Bielefeld', 'northern hemisphere'),
#  ('Monchengladbach', 'Moenchengladbach', 'northern hemisphere'),
#  ('Paderborn Lippstadt', 'Paderborn', 'northern hemisphere'),
#  ('Stadtlohn Vreden', 'Stadtlohn', 'northern hemisphere'),
#  ('Dortmund', 'Dortmund', 'northern hemisphere'),
#  ('Augsburg', 'Augsburg', 'northern hemisphere'),
#  ('Biberach An Der Riss', 'Biberach', 'northern hemisphere'),
#  ('Eggenfelden', 'Eggenfelden', 'northern hemisphere'),
#  ('Mindelheim Mattsies', 'Mindelheim', 'northern hemisphere'),
#  ('Oberpfaffenhofen', 'Oberpfaffenhofen', 'northern hemisphere'),
#  ('Straubing', 'Straubing', 'northern hemisphere'),
#  ('Vilshofen', 'Vilshofen', 'northern hemisphere'),
#  ('Leutkirch Unterzeil', 'Leutkirch', 'northern hemisphere'),
#  ('Friedrichshafen', 'Friedrichshafen', 'northern hemisphere'),
#  ('Schwerin Parchim', 'Parchim', 'northern hemisphere'),
#  ('Stendal Borstel', 'Stendal', 'northern hemisphere'),
#  ('Aalen Heidenheim Elchingen', 'Aalen-heidenheim', 'northern hemisphere'),
#  ('Bayreuth', 'Bayreuth', 'northern hemisphere'),
#  ('Burg Feuerstein', 'Burg Feuerstein', 'northern hemisphere'),
#  ('Hof Plauen', 'Hof', 'northern hemisphere'),
#  ('Hassfurt Schweinfurt', 'Hassfurt', 'northern hemisphere'),
#  ('Koblenz Winningen', 'Koblenz', 'northern hemisphere'),
#  ('Trier Fohren', 'Trier', 'northern hemisphere'),
#  ('Speyer', 'Speyer', 'northern hemisphere'),
#  ('Zweibrucken', 'Zweibruecken', 'northern hemisphere'),
#  ('Donaueschingen Villingen', 'Donaueschingen', 'northern hemisphere'),
#  ('Freiburg', 'Freiburg', 'northern hemisphere'),
#  ('Mengen Hohentengen', 'Mengen', 'northern hemisphere'),
#  ('Schwabisch Hall', 'Schwaebisch Hall', 'northern hemisphere'),
#  ('Finsterwalde Schacksdorf', 'Soest', 'northern hemisphere'),
#  ('Braunschweig Wolfsburg', 'Braunschweig', 'northern hemisphere'),
#  ('Kassel Calden', 'Kassel', 'northern hemisphere'),
#  ('Hildesheim', 'Hildesheim', 'northern hemisphere'),
#  ('Bremerhaven', 'Bremerhaven', 'northern hemisphere'),
#  ('Emden', 'Emden', 'northern hemisphere'),
#  ('Leer Papenburg', 'Leer', 'northern hemisphere'),
#  ('Wilhelmshaven Mariensiel', 'Wilhelmshaven', 'northern hemisphere'),
#  ('Borkum', 'Borkum', 'northern hemisphere'),
#  ('Norderney', 'Norderney', 'northern hemisphere'),
#  ('Flensburg Schaferhaus', 'Flensburg', 'northern hemisphere'),
#  ('Rendsburg Schachtholm', 'Rendsburg', 'northern hemisphere'),
#  ('Westerland Sylt', 'Westerland', 'northern hemisphere'),
#  ('Amari', 'Armari Air Force Base', 'northern hemisphere'),
#  ('Kardla', 'Kardla', 'northern hemisphere'),
#  ('Kuressaare', 'Kuressaare', 'northern hemisphere'),
#  ('Parnu', 'Parnu', 'northern hemisphere'),
#  ('Tallinn', 'Tallinn-ulemiste International', 'northern hemisphere'),
#  ('Tartu', 'Tartu', 'northern hemisphere'),
#  ('Enontekio', 'Enontekio', 'northern hemisphere'),
#  ('Eura', 'Eura', 'northern hemisphere'),
#  ('Halli', 'Halli', 'northern hemisphere'),
#  ('Helsinki Malmi', 'Helsinki', 'northern hemisphere'),
#  ('Helsinki Vantaa', 'Helsinki', 'northern hemisphere'),
#  ('Hameenkyro', 'Hameenkyro', 'northern hemisphere'),
#  ('Hanko', 'Hanko', 'northern hemisphere'),
#  ('Hyvinkaa', 'Hyvinkaa', 'northern hemisphere'),
#  ('Kiikala', 'Kikala', 'northern hemisphere'),
#  ('Immola', 'Immola', 'northern hemisphere'),
#  ('Kitee', 'Kitee', 'northern hemisphere'),
#  ('Ivalo', 'Ivalo', 'northern hemisphere'),
#  ('Joensuu', 'Joensuu', 'northern hemisphere'),
#  ('Jyvaskyla', 'Jyvaskyla', 'northern hemisphere'),
#  ('Kauhava', 'Kauhava', 'northern hemisphere'),
#  ('Kemi Tornio', 'Kemi', 'northern hemisphere'),
#  ('Kajaani', 'Kajaani', 'northern hemisphere'),
#  ('Kauhajoki', 'Kauhajoki', 'northern hemisphere'),
#  ('Kruunupyy', 'Kruunupyy', 'northern hemisphere'),
#  ('Kemijarvi', 'Kemijarvi', 'northern hemisphere'),
#  ('Kuusamo', 'Kuusamo', 'northern hemisphere'),
#  ('Kittila', 'Kittila', 'northern hemisphere'),
#  ('Kuopio', 'Kuopio', 'northern hemisphere'),
#  ('Lahti Vesivehmaa', 'Vesivehmaa', 'northern hemisphere'),
#  ('Lappeenranta', 'Lappeenranta', 'northern hemisphere'),
#  ('Mariehamn', 'Mariehamn', 'northern hemisphere'),
#  ('Menkijarvi', 'Menkijarvi', 'northern hemisphere'),
#  ('Mikkeli', 'Mikkeli', 'northern hemisphere'),
#  ('Nummela', 'Nummela', 'northern hemisphere'),
#  ('Oulu', 'Oulu', 'northern hemisphere'),
#  ('Piikajarvi', 'Piikajarvi', 'northern hemisphere'),
#  ('Pori', 'Pori', 'northern hemisphere'),
#  ('Pudasjarvi', 'Pudasjarvi', 'northern hemisphere'),
#  ('Pyhasalmi', 'Pyhasalmi', 'northern hemisphere'),
#  ('Raahe Pattijoki', 'Pattijoki', 'northern hemisphere'),
#  ('Rantasalmi', 'Rantasalmi', 'northern hemisphere'),
#  ('Rovaniemi', 'Rovaniemi', 'northern hemisphere'),
#  ('Rayskala', 'Rayskala', 'northern hemisphere'),
#  ('Savonlinna', 'Savonlinna', 'northern hemisphere'),
#  ('Selanpaa', 'Selanpaa', 'northern hemisphere'),
#  ('Sodankyla', 'Sodankyla', 'northern hemisphere'),
#  ('Tampere Pirkkala', 'Tampere', 'northern hemisphere'),
#  ('Teisko', 'Teisko', 'northern hemisphere'),
#  ('Turku', 'Turku', 'northern hemisphere'),
#  ('Utti', 'Utti', 'northern hemisphere'),
#  ('Vaasa', 'Vaasa', 'northern hemisphere'),
#  ('Varkaus', 'Varkaus', 'northern hemisphere'),
#  ('Ylivieska', 'Ylivieska-raudaskyla', 'northern hemisphere'),
#  ('Belfast Intl', 'Belfast', 'northern hemisphere'),
#  ('St Angelo', 'Enniskillen', 'northern hemisphere'),
#  ('Belfast City', 'Belfast', 'northern hemisphere'),
#  ('City of Derry', 'Londonderry', 'northern hemisphere'),
#  ('Birmingham', 'Birmingham', 'northern hemisphere'),
#  ('Coventry', 'Coventry', 'northern hemisphere'),
#  ('Leicester', 'Leicester', 'northern hemisphere'),
#  ('Gloucestershire', 'Golouchestershire', 'northern hemisphere'),
#  ('Wolverhampton', 'Halfpenny Green', 'northern hemisphere'),
#  ('Kemble', 'Pailton', 'northern hemisphere'),
#  ('Turweston', 'Turweston', 'northern hemisphere'),
#  ('Wellesbourne Mountford', 'Wellesbourne', 'northern hemisphere'),
#  ('Manchester', 'Manchester', 'northern hemisphere'),
#  ('Manchester Woodford', 'Woodfort', 'northern hemisphere'),
#  ('Chivenor', 'Chivenor', 'northern hemisphere'),
#  ('St Mawgan', 'Newquai', 'northern hemisphere'),
#  ('Lyneham', 'Lyneham', 'northern hemisphere'),
#  ('Boscombe Down', 'Boscombe Down', 'northern hemisphere'),
#  ('Culdrose', 'Culdrose', 'northern hemisphere'),
#  ('St Athan', 'St. Athan', 'northern hemisphere'),
#  ('Yeovilton', 'Yeovilton', 'northern hemisphere'),
#  ('Haverfordwest', 'Haverfordwest', 'northern hemisphere'),
#  ('Cardiff', 'Cardiff', 'northern hemisphere'),
#  ('Swansea', 'Swansea', 'northern hemisphere'),
#  ('Bristol', 'Bristol', 'northern hemisphere'),
#  ('Liverpool', 'Liverpool', 'northern hemisphere'),
#  ('Luton', 'London', 'northern hemisphere'),
#  ('Plymouth', 'Plymouth', 'northern hemisphere'),
#  ('Bournemouth', 'Bournemouth', 'northern hemisphere'),
#  ('Southampton', 'Southampton', 'northern hemisphere'),
#  ('Lasham', 'Lasham', 'northern hemisphere'),
#  ('Alderney', 'Alderney', 'northern hemisphere'),
#  ('Guernsey', 'Guernsey', 'northern hemisphere'),
#  ('Jersey', 'Jersey', 'northern hemisphere'),
#  ('Shoreham', 'Shoreham By Sea', 'northern hemisphere'),
#  ('Biggin Hill', 'Biggin Hill', 'northern hemisphere'),
#  ('Gatwick', 'London', 'northern hemisphere'),
#  ('City', 'London', 'northern hemisphere'),
#  ('Farnborough', 'Farnborough', 'northern hemisphere'),
#  ('Chalgrove', 'Chalsgrove', 'northern hemisphere'),
#  ('Blackbushe', 'Blackbushe', 'northern hemisphere'),
#  ('Heathrow', 'London', 'northern hemisphere'),
#  ('Southend', 'Southend', 'northern hemisphere'),
#  ('Lydd', 'Lydd', 'northern hemisphere'),
#  ('Manston', 'Manston', 'northern hemisphere'),
#  ('Brough', 'Brough', 'northern hemisphere'),
#  ('Carlisle', 'Carlisle', 'northern hemisphere'),
#  ('Gamston', 'Repton', 'northern hemisphere'),
#  ('Blackpool', 'Blackpool', 'northern hemisphere'),
#  ('Humberside', 'Humberside', 'northern hemisphere'),
#  ('Walney Island', 'Barrow Island', 'northern hemisphere'),
#  ('Leeds Bradford', 'Leeds', 'northern hemisphere'),
#  ('Warton', 'Warton', 'northern hemisphere'),
#  ('Hawarden', 'Hawarden', 'northern hemisphere'),
#  ('Isle Of Man', 'Isle Of Man', 'northern hemisphere'),
#  ('Newcastle', 'Newcastle', 'northern hemisphere'),
#  ('Durham Tees Valley Airport', 'Teesside', 'northern hemisphere'),
#  ('Nottingham East Midlands', 'East Midlands', 'northern hemisphere'),
#  ('Llanbedr', 'Llanbedr', 'northern hemisphere'),
#  ('Ternhill', 'Ternhill', 'northern hemisphere'),
#  ('Shawbury', 'Shawbury', 'northern hemisphere'),
#  ('Woodvale', 'Woodvale', 'northern hemisphere'),
#  ('Kirkwall', 'Kirkwall', 'northern hemisphere'),
#  ('Sumburgh', 'Sumburgh', 'northern hemisphere'),
#  ('Wick', 'Wick', 'northern hemisphere'),
#  ('Dyce', 'Aberdeen', 'northern hemisphere'),
#  ('Inverness', 'Inverness', 'northern hemisphere'),
#  ('Glasgow', 'Glasgow', 'northern hemisphere'),
#  ('Edinburgh', 'Edinburgh', 'northern hemisphere'),
#  ('Islay', 'Islay', 'northern hemisphere'),
#  ('Prestwick', 'Prestwick', 'northern hemisphere'),
#  ('Benbecula', 'Benbecula', 'northern hemisphere'),
#  ('Scatsta', 'Scatsta', 'northern hemisphere'),
#  ('Dundee', 'Dundee', 'northern hemisphere'),
#  ('Stornoway', 'Stornoway', 'northern hemisphere'),
#  ('Tiree', 'Tiree', 'northern hemisphere'),
#  ('Leuchars', 'Leuchars', 'northern hemisphere'),
#  ('Lossiemouth', 'Lossiemouth', 'northern hemisphere'),
#  ('Cambridge', 'Cambridge', 'northern hemisphere'),
#  ('Conington', 'Peterborough', 'northern hemisphere'),
#  ('Norwich', 'Norwich', 'northern hemisphere'),
#  ('Stansted', 'London', 'northern hemisphere'),
#  ('North Weald', 'North Weald', 'northern hemisphere'),
#  ('Sheffield City', 'Fowlmere', 'northern hemisphere'),
#  ('Cranfield', 'Cranfield', 'northern hemisphere'),
#  ('Exeter', 'Exeter', 'northern hemisphere'),
#  ('Bristol Filton', 'Bristol', 'northern hemisphere'),
#  ('Kidlington', 'Oxford', 'northern hemisphere'),
#  ('Benson', 'Benson', 'northern hemisphere'),
#  ('Lakenheath', 'Lakenheath', 'northern hemisphere'),
#  ('Mildenhall', 'Mildenhall', 'northern hemisphere'),
#  ('Wattisham', 'Wattisham', 'northern hemisphere'),
#  ('Wyton', 'Wyton', 'northern hemisphere'),
#  ('Fairford', 'Fairford', 'northern hemisphere'),
#  ('Brize Norton', 'Brize Norton', 'northern hemisphere'),
#  ('Odiham', 'Odiham', 'northern hemisphere'),
#  ('Cosford', 'Cosford', 'northern hemisphere'),
#  ('Northolt', 'Northolt', 'northern hemisphere'),
#  ('Coningsby', 'Coningsby', 'northern hemisphere'),
#  ('Dishforth', 'Dishforth', 'northern hemisphere'),
#  ('Leeming', 'Leeming', 'northern hemisphere'),
#  ('Church Fenton', 'Church Fenton', 'northern hemisphere'),
#  ('Honington', 'Honington', 'northern hemisphere'),
#  ('Cottesmore', 'Cottesmore', 'northern hemisphere'),
#  ('Scampton', 'Scampton', 'northern hemisphere'),
#  ('Wittering', 'Wittering', 'northern hemisphere'),
#  ('Linton On Ouse', 'Linton-on-ouse', 'northern hemisphere'),
#  ('Waddington', 'Waddington', 'northern hemisphere'),
#  ('Topcliffe', 'Topcliffe', 'northern hemisphere'),
#  ('Cranwell', 'Cranwell', 'northern hemisphere'),
#  ('Barkston Heath', 'Barkston Heath', 'northern hemisphere'),
#  ('Marham', 'Marham', 'northern hemisphere'),
#  ('Mount Pleasant', 'Mount Pleasant', 'southern hemisphere'),
#  ('Schiphol', 'Amsterdam', 'northern hemisphere'),
#  ('Budel', 'Weert', 'northern hemisphere'),
#  ('Maastricht', 'Maastricht', 'northern hemisphere'),
#  ('Deelen', 'Deelen', 'northern hemisphere'),
#  ('Drachten', 'Drachten', 'northern hemisphere'),
#  ('Eindhoven', 'Eindhoven', 'northern hemisphere'),
#  ('Eelde', 'Groningen', 'northern hemisphere'),
#  ('Gilze Rijen', 'Gilze-rijen', 'northern hemisphere'),
#  ('De Kooy', 'De Kooy', 'northern hemisphere'),
#  ('Lelystad', 'Lelystad', 'northern hemisphere'),
#  ('Leeuwarden', 'Leeuwarden', 'northern hemisphere'),
#  ('Rotterdam', 'Rotterdam', 'northern hemisphere'),
#  ('Soesterberg', 'Soesterberg', 'northern hemisphere'),
#  ('Twenthe', 'Enschede', 'northern hemisphere'),
#  ('Valkenburg', 'Valkenburg', 'northern hemisphere'),
#  ('Woensdrecht', 'Woensdrecht', 'northern hemisphere'),
#  ('Cork', 'Cork', 'northern hemisphere'),
#  ('Galway', 'Galway', 'northern hemisphere'),
#  ('Dublin', 'Dublin', 'northern hemisphere'),
#  ('Ireland West Knock', 'Connaught', 'northern hemisphere'),
#  ('Kerry', 'Kerry', 'northern hemisphere'),
#  ('Casement', 'Casement', 'northern hemisphere'),
#  ('Shannon', 'Shannon', 'northern hemisphere'),
#  ('Sligo', 'Sligo', 'northern hemisphere'),
#  ('Waterford', 'Waterford', 'northern hemisphere'),
#  ('Aarhus', 'Aarhus', 'northern hemisphere'),
#  ('Billund', 'Billund', 'northern hemisphere'),
#  ('Kastrup', 'Copenhagen', 'northern hemisphere'),
#  ('Esbjerg', 'Esbjerg', 'northern hemisphere'),
#  ('Gronholt Hillerod', 'Gronholt', 'northern hemisphere'),
#  ('Karup', 'Karup', 'northern hemisphere'),
#  ('Laeso', 'Laeso', 'northern hemisphere'),
#  ('Lolland Falster Maribo', 'Maribo', 'northern hemisphere'),
#  ('Odense', 'Odense', 'northern hemisphere'),
#  ('Krusa Padborg', 'Krusa-padborg', 'northern hemisphere'),
#  ('Roskilde', 'Copenhagen', 'northern hemisphere'),
#  ('Bornholm Ronne', 'Ronne', 'northern hemisphere'),
#  ('Sonderborg', 'Soenderborg', 'northern hemisphere'),
#  ('Skrydstrup', 'Skrydstrup', 'northern hemisphere'),
#  ('Skive', 'Skive', 'northern hemisphere'),
#  ('Thisted', 'Thisted', 'northern hemisphere'),
#  ('Kolding Vamdrup', 'Kolding', 'northern hemisphere'),
#  ('Vagar', 'Vagar', 'northern hemisphere'),
#  ('Aars', 'Vesthimmerland', 'northern hemisphere'),
#  ('Stauning', 'Stauning', 'northern hemisphere'),
#  ('Aalborg', 'Aalborg', 'northern hemisphere'),
#  ('Luxembourg', 'Luxemburg', 'northern hemisphere'),
#  ('Vigra', 'Alesund', 'northern hemisphere'),
#  ('Andenes', 'Andoya', 'northern hemisphere'),
#  ('Alta', 'Alta', 'northern hemisphere'),
#  ('Bomoen', 'Voss', 'northern hemisphere'),
#  ('Bronnoy', 'Bronnoysund', 'northern hemisphere'),
#  ('Bodo', 'Bodo', 'northern hemisphere'),
#  ('Flesland', 'Bergen', 'northern hemisphere'),
#  ('Batsfjord', 'Batsfjord', 'northern hemisphere'),
#  ('Kjevik', 'Kristiansand', 'northern hemisphere'),
#  ('Dagali', 'Geilo', 'northern hemisphere'),
#  ('Bardufoss', 'Bardufoss', 'northern hemisphere'),
#  ('Evenes', 'Harstad/Narvik', 'northern hemisphere'),
#  ('Leirin', 'Fagernes', 'northern hemisphere'),
#  ('Floro', 'Floro', 'northern hemisphere'),
#  ('Gardermoen', 'Oslo', 'northern hemisphere'),
#  ('Karmoy', 'Haugesund', 'northern hemisphere'),
#  ('Hasvik', 'Hasvik', 'northern hemisphere'),
#  ('Kvernberget', 'Kristiansund', 'northern hemisphere'),
#  ('Kjeller', 'Kjeller', 'northern hemisphere'),
#  ('Hoybuktmoen', 'Kirkenes', 'northern hemisphere'),
#  ('Lista', 'Farsund', 'northern hemisphere'),
#  ('Aro', 'Molde', 'northern hemisphere'),
#  ('Kjaerstad', 'Mosjoen', 'northern hemisphere'),
#  ('Banak', 'Lakselv', 'northern hemisphere'),
#  ('Notodden', 'Notodden', 'northern hemisphere'),
#  ('Orland', 'Orland', 'northern hemisphere'),
#  ('Roros', 'Roros', 'northern hemisphere'),
#  ('Moss', 'Rygge', 'northern hemisphere'),
#  ('Longyear', 'Svalbard', 'northern hemisphere'),
#  ('Geiteryggen', 'Skien', 'northern hemisphere'),
#  ('Sorstokken', 'Stord', 'northern hemisphere'),
#  ('Stokka', 'Sandnessjoen', 'northern hemisphere'),
#  ('Langnes', 'Tromso', 'northern hemisphere'),
#  ('Torp', 'Sandefjord', 'northern hemisphere'),
#  ('Vaernes', 'Trondheim', 'northern hemisphere'),
#  ('Sola', 'Stavanger', 'northern hemisphere'),
#  ('Babice', 'Warsaw', 'northern hemisphere'),
#  ('Lech Walesa', 'Gdansk', 'northern hemisphere'),
#  ('Balice', 'Krakow', 'northern hemisphere'),
#  ('Muchowiec', 'Katowice', 'northern hemisphere'),
#  ('Pyrzowice', 'Katowice', 'northern hemisphere'),
#  ('Mielec', 'Mielec', 'northern hemisphere'),
#  ('Lawica', 'Poznan', 'northern hemisphere'),
#  ('Jasionka', 'Rzeszow', 'northern hemisphere'),
#  ('Goleniow', 'Szczecin', 'northern hemisphere'),
#  ('Redzikowo', 'Slupsk', 'northern hemisphere'),
#  ('Swidwin', 'Shapaja', 'northern hemisphere'),
#  ('Okecie', 'Warsaw', 'northern hemisphere'),
#  ('Strachowice', 'Wroclaw', 'northern hemisphere'),
#  ('Babimost', 'Zielona Gora', 'northern hemisphere'),
#  ('Malmen', 'Linkoeping', 'northern hemisphere'),
#  ('Bravalla', 'Norrkoeping', 'northern hemisphere'),
#  ('Uppsala', 'Uppsala', 'northern hemisphere'),
#  ('Ronneby', 'Ronneby', 'northern hemisphere'),
#  ('Rada', 'Rada', 'northern hemisphere'),
#  ('Landvetter', 'Gothenborg', 'northern hemisphere'),
#  ('Jonkoping', 'Joenkoeping', 'northern hemisphere'),
#  ('Falkoping', 'Falkoping', 'northern hemisphere'),
#  ('Lidkoping', 'Lidkoping', 'northern hemisphere'),
#  ('Save', 'Gothenborg', 'northern hemisphere'),
#  ('Skovde', 'Skovde', 'northern hemisphere'),
#  ('Trollhattan Vanersborg', 'Trollhattan', 'northern hemisphere'),
#  ('Karlsborg', 'Karlsborg', 'northern hemisphere'),
#  ('Satenas', 'Satenas', 'northern hemisphere'),
#  ('Barkarby', 'Stockholm', 'northern hemisphere'),
#  ('Karlskoga', 'Karlskoga', 'northern hemisphere'),
#  ('Mora', 'Mora', 'northern hemisphere'),
#  ('Skavsta', 'Stockholm', 'northern hemisphere'),
#  ('Arvika', 'Arvika', 'northern hemisphere'),
#  ('Emmaboda', 'Emmaboda', 'northern hemisphere'),
#  ('Feringe', 'Ljungby', 'northern hemisphere'),
#  ('Kristianstad', 'Kristianstad', 'northern hemisphere'),
#  ('Landskrona', 'Landskrona', 'northern hemisphere'),
#  ('Oskarshamn', 'Oskarshamn', 'northern hemisphere'),
#  ('Anderstorp', 'Anderstorp', 'northern hemisphere'),
#  ('Kalmar', 'Kalkmar', 'northern hemisphere'),
#  ('Sturup', 'Malmoe', 'northern hemisphere'),
#  ('Halmstad', 'Halmstad', 'northern hemisphere'),
#  ('Hagshult', 'Hagshult', 'northern hemisphere'),
#  ('Kronoberg', 'Vaxjo', 'northern hemisphere'),
#  ('Hallviken', 'Hallviken', 'northern hemisphere'),
#  ('Hedlanda', 'Hede', 'northern hemisphere'),
#  ('Sveg', 'Sveg', 'northern hemisphere'),
#  ('Gallivare', 'Gallivare', 'northern hemisphere'),
#  ('Hudiksvall', 'Hudiksvall', 'northern hemisphere'),
#  ('Jokkmokk', 'Jokkmokk', 'northern hemisphere'),
#  ('Kramfors Solleftea', 'Kramfors', 'northern hemisphere'),
#  ('Lycksele', 'Lycksele', 'northern hemisphere'),
#  ('Optand', 'Optand', 'northern hemisphere'),
#  ('Sundsvall Harnosand', 'Sundsvall', 'northern hemisphere'),
#  ('Ornskoldsvik', 'Ornskoldsvik', 'northern hemisphere'),
#  ('Pitea', 'Pitea', 'northern hemisphere'),
#  ('Kiruna', 'Kiruna', 'northern hemisphere'),
#  ('Orsa', 'Orsa', 'northern hemisphere'),
#  ('Skelleftea', 'Skelleftea', 'northern hemisphere'),
#  ('Sattna', 'Sattna', 'northern hemisphere'),
#  ('Umea', 'Umea', 'northern hemisphere'),
#  ('Vilhelmina', 'Vilhelmina', 'northern hemisphere'),
#  ('Arvidsjaur', 'Arvidsjaur', 'northern hemisphere'),
#  ('Orebro', 'Orebro', 'northern hemisphere'),
#  ('Vasteras', 'Vasteras', 'northern hemisphere'),
#  ('Kallax', 'Lulea', 'northern hemisphere'),
#  ('Vidsel', 'Vidsel', 'northern hemisphere'),
#  ('Arboga', 'Arboga', 'northern hemisphere'),
#  ('Arlanda', 'Stockholm', 'northern hemisphere'),
#  ('Bromma', 'Stockholm', 'northern hemisphere'),
#  ('Borlange', 'Borlange', 'northern hemisphere'),
#  ('Hultsfred', 'Hultsfred', 'northern hemisphere'),
#  ('Gavle', 'Gavle', 'northern hemisphere'),
#  ('Saab', 'Linkoeping', 'northern hemisphere'),
#  ('Kungsangen', 'Norrkoeping', 'northern hemisphere'),
#  ('Eskilstuna', 'Eskilstuna', 'northern hemisphere'),
#  ('Visby', 'Visby', 'northern hemisphere'),
#  ('Kalixfors', 'Kalixfors', 'northern hemisphere'),
#  ('Spangdahlem Ab', 'Spangdahlem', 'northern hemisphere'),
#  ('Ramstein Ab', 'Ramstein', 'northern hemisphere'),
#  ('Bamberg Aaf', 'Bamberg', 'northern hemisphere'),
#  ('Giebelstadt Aaf', 'Giebelstadt', 'northern hemisphere'),
#  ('Buckeburg', 'Brueckeburg', 'northern hemisphere'),
#  ('Celle', 'Celle', 'northern hemisphere'),
#  ('Rheine Bentlage', 'Rheine-brentlange', 'northern hemisphere'),
#  ('Fritzlar', 'Fritzlar', 'northern hemisphere'),
#  ('Laupheim', 'Laupheim', 'northern hemisphere'),
#  ('Mendig', 'Mendig', 'northern hemisphere'),
#  ('Niederstetten', 'Niederstetten', 'northern hemisphere'),
#  ('Roth', 'Roth', 'northern hemisphere'),
#  ('Fassberg', 'Fassberg', 'northern hemisphere'),
#  ('Grafenwohr Aaf', 'Grafenwoehr', 'northern hemisphere'),
#  ('Hanau Aaf', 'Hanau', 'northern hemisphere'),
#  ('Hohenfels Aaf', 'Hohenfels', 'northern hemisphere'),
#  ('Kitzingen Aaf', 'Kitzingen', 'northern hemisphere'),
#  ('Nordholz', 'Nordholz', 'northern hemisphere'),
#  ('Diepholz', 'Diepholz', 'northern hemisphere'),
#  ('Geilenkirchen', 'Geilenkirchen', 'northern hemisphere'),
#  ('Hohn', 'Hohn', 'northern hemisphere'),
#  ('Jever', 'Jever', 'northern hemisphere'),
#  ('Laage', 'Laage', 'northern hemisphere'),
#  ('Norvenich', 'Noervenich', 'northern hemisphere'),
#  ('Schleswig', 'Schleswig', 'northern hemisphere'),
#  ('Wittmundhafen', 'Wittmundhafen', 'northern hemisphere'),
#  ('Neubrandenburg', 'Neubrandenburg', 'northern hemisphere'),
#  ('Wunstorf', 'Wunstorf', 'northern hemisphere'),
#  ('Vilseck Aaf', 'Vilseck', 'northern hemisphere'),
#  ('Coleman Aaf', 'Coleman', 'northern hemisphere'),
#  ('Wiesbaden Aaf', 'Wiesbaden', 'northern hemisphere'),
#  ('Landsberg Lech', 'Landsberg', 'northern hemisphere'),
#  ('Buchel', 'Buechel', 'northern hemisphere'),
#  ('Erding', 'Erding', 'northern hemisphere'),
#  ('Furstenfeldbruck', 'Fuerstenfeldbruck', 'northern hemisphere'),
#  ('Holzdorf', 'Holzdorf', 'northern hemisphere'),
#  ('Ingolstadt Manching', 'Ingolstadt', 'northern hemisphere'),
#  ('Lechfeld', 'Lechfeld', 'northern hemisphere'),
#  ('Neuburg', 'Neuburg', 'northern hemisphere'),
#  ('Gutersloh', 'Guetersloh', 'northern hemisphere'),
#  ('Alexander Bay', 'Alexander Bay', 'southern hemisphere'),
#  ('Aggeneys', 'Aggeneys', 'southern hemisphere'),
#  ('Brakpan', 'Brakpan', 'southern hemisphere'),
#  ('Bhisho', 'Bisho', 'southern hemisphere'),
#  ('Bloemfontein Intl', 'Bloemfontein', 'southern hemisphere'),
#  ('Bethlehem', 'Bethlehem', 'southern hemisphere'),
#  ('Bothaville', 'Bothaville', 'southern hemisphere'),
#  ('Cape Town Intl', 'Cape Town', 'southern hemisphere'),
#  ('Calvinia', 'Calvinia', 'southern hemisphere'),
#  ('Durban Intl', 'Durban', 'southern hemisphere'),
#  ('East London', 'East London', 'southern hemisphere'),
#  ('Ermelo', 'Ermelo', 'southern hemisphere'),
#  ('Ficksburg Sentraoes', 'Ficksburg', 'southern hemisphere'),
#  ('Grand Central', 'Johannesburg', 'southern hemisphere'),
#  ('George', 'George', 'southern hemisphere'),
#  ('Graaff Reinet', 'Graaff Reinet', 'southern hemisphere'),
#  ('Grahamstown', 'Grahamstown', 'southern hemisphere'),
#  ('Greytown', 'Greytown', 'southern hemisphere'),
#  ('Harmony', 'Harmony', 'southern hemisphere'),
#  ('Harrismith', 'Harrismith', 'southern hemisphere'),
#  ('Hoedspruit Afb', 'Hoedspruit', 'southern hemisphere'),
#  ('Gariep Dam', 'Hendrik Verwoerddam', 'southern hemisphere'),
#  ('Johannesburg Intl', 'Johannesburg', 'southern hemisphere'),
#  ('P C Pelser', 'Klerksdorp', 'southern hemisphere'),
#  ('Kimberley', 'Kimberley', 'southern hemisphere'),
#  ('Krugersdorp', 'Krugersdorp', 'southern hemisphere'),
#  ('Kroonstad', 'Kroonstad', 'southern hemisphere'),
#  ('Johan Pienaar', 'Kuruman', 'southern hemisphere'),
#  ('Kleinsee', 'Kleinsee', 'southern hemisphere'),
#  ('Lanseria', 'Johannesburg', 'southern hemisphere'),
#  ('Lichtenburg', 'Lichtenburg', 'southern hemisphere'),
#  ('Makhado Afb', 'Lambertsbaai', 'southern hemisphere'),
#  ('Langebaanweg', 'Langebaanweg', 'southern hemisphere'),
#  ('Ladysmith', 'Ladysmith', 'southern hemisphere'),
#  ('Middelburg', 'Middelburg', 'southern hemisphere'),
#  ('Margate', 'Margate', 'southern hemisphere'),
#  ('Marble Hall', 'Marble Hall', 'southern hemisphere'),
#  ('Majuba Power Station', 'Majuba Power Station', 'southern hemisphere'),
#  ('Susse', 'Kangia', 'northern hemisphere'),
#  ('Malelane', 'Malalane', 'southern hemisphere'),
#  ('Messina', 'Musina', 'southern hemisphere'),
#  ('Mkuzi', 'Mkuze', 'southern hemisphere'),
#  ('Newcastle', 'Newcastle', 'southern hemisphere'),
#  ('Nylstroom', 'Nylstroom', 'southern hemisphere'),
#  ('Overberg', 'Overberg', 'southern hemisphere'),
#  ('Oudtshoorn', 'Oudtshoorn', 'southern hemisphere'),
#  ('Port Elizabeth Intl', 'Port Elizabeth', 'southern hemisphere'),
#  ('Plettenberg Bay', 'Plettenberg Bay', 'southern hemisphere'),
#  ('Phalaborwa', 'Phalaborwa', 'southern hemisphere'),
#  ('Polokwane International', 'Polokwane', 'southern hemisphere'),
#  ('Port St Johns', 'Port Saint Johns', 'southern hemisphere'),
#  ('Pietermaritzburg', 'Pietermaritzburg', 'southern hemisphere'),
#  ('Pilanesberg Intl', 'Pilanesberg', 'southern hemisphere'),
#  ('Polokwane Intl', 'Potgietersrus', 'southern hemisphere'),
#  ('Potchefstroom', 'Potchefstroom', 'southern hemisphere'),
#  ('Parys', 'Parys', 'southern hemisphere'),
#  ('Queenstown', 'Queenstown', 'southern hemisphere'),
#  ('Richards Bay', "Richard's Bay", 'southern hemisphere'),
#  ('Rustenburg', 'Rustenburg', 'southern hemisphere'),
#  ('Robertson', 'Robertson', 'southern hemisphere'),
#  ('Springbok', 'Springbok', 'southern hemisphere'),
#  ('Secunda', 'Secunda', 'southern hemisphere'),
#  ('Saldanha Vredenburg', 'Saldanha', 'southern hemisphere'),
#  ('Springs', 'Springs', 'southern hemisphere'),
#  ('Swartkop', 'Swartkop', 'southern hemisphere'),
#  ('Sishen', 'Sishen', 'southern hemisphere'),
#  ('Hendrik Swellengrebel', 'Swellendam', 'southern hemisphere'),
#  ('Skukuza', 'Skukuza', 'southern hemisphere'),
#  ('Tommys Fld', "Tommy's Field", 'southern hemisphere'),
#  ('New Tempe', 'Bloemfontein', 'southern hemisphere'),
#  ('Tutuka Power Station', 'Tutuka', 'southern hemisphere'),
#  ('Tzaneen', 'Tzaneen', 'southern hemisphere'),
#  ('Prince Mangosuthu Buthelezi', 'Ulundi', 'southern hemisphere'),
#  ('Upington', 'Upington', 'southern hemisphere'),
#  ('Mthatha', 'Umtata', 'southern hemisphere'),
#  ('Vryburg', 'Vryburg', 'southern hemisphere'),
#  ('Virginia', 'Durban', 'southern hemisphere'),
#  ('Vredendal', 'Vredendal', 'southern hemisphere'),
#  ('Vereeniging', 'Vereeniging', 'southern hemisphere'),
#  ('Wonderboom', 'Pretoria', 'southern hemisphere'),
#  ('Witbank', 'Witbank', 'southern hemisphere'),
#  ('Waterkloof Afb', 'Waterkloof', 'southern hemisphere'),
#  ('Welkom', 'Welkom', 'southern hemisphere'),
#  ('Ysterplaat', 'Ysterplaat', 'southern hemisphere'),
#  ('Zeerust', 'Zeerust', 'southern hemisphere'),
#  ('Francistown', 'Francistown', 'southern hemisphere'),
#  ('Jwaneng', 'Jwaneng', 'southern hemisphere'),
#  ('Kasane', 'Kasane', 'southern hemisphere'),
#  ('Maun', 'Maun', 'southern hemisphere'),
#  ('Sir Seretse Khama Intl', 'Gaberone', 'southern hemisphere'),
#  ('Selebi Phikwe', 'Selebi-phikwe', 'southern hemisphere'),
#  ('Maya Maya', 'Brazzaville', 'southern hemisphere'),
#  ('Owando', 'Owando', 'southern hemisphere'),
#  ('Ouesso', 'Ouesso', 'northern hemisphere'),
#  ('Pointe Noire', 'Pointe-noire', 'southern hemisphere'),
#  ('Matsapha', 'Manzini', 'southern hemisphere'),
#  ('Bangui M Poko', 'Bangui', 'northern hemisphere'),
#  ('Berberati', 'Berberati', 'northern hemisphere'),
#  ('Bata', 'Bata', 'northern hemisphere'),
#  ('Malabo', 'Malabo', 'northern hemisphere'),
#  ('Ascension Aux Af', 'Wide Awake', 'southern hemisphere'),
#  ('Sir Seewoosagur Ramgoolam Intl', 'Plaisance', 'southern hemisphere'),
#  ('Plaine Corail', 'Rodriguez Island', 'southern hemisphere'),
#  ('Diego Garcia Nsf', 'Diego Garcia Island', 'southern hemisphere'),
#  ('Tiko', 'Tiko', 'northern hemisphere'),
#  ('Douala', 'Douala', 'northern hemisphere'),
#  ('Salak', 'Maroua', 'northern hemisphere'),
#  ('Foumban Nkounja', 'Foumban', 'northern hemisphere'),
#  ('Ngaoundere', "N'gaoundere", 'northern hemisphere'),
#  ('Garoua', 'Garoua', 'northern hemisphere'),
#  ('Bafoussam', 'Bafoussam', 'northern hemisphere'),
#  ('Bamenda', 'Bamenda', 'northern hemisphere'),
#  ('Yaounde Ville', 'Yaounde', 'northern hemisphere'),
#  ('Kasompe', 'Kasompe', 'southern hemisphere'),
#  ('Livingstone', 'Livingstone', 'southern hemisphere'),
#  ('Lusaka Intl', 'Lusaka', 'southern hemisphere'),
#  ('Mfuwe', 'Mfuwe', 'southern hemisphere'),
#  ('Mongu', 'Mongu', 'southern hemisphere'),
#  ('Ndola', 'Ndola', 'southern hemisphere'),
#  ('Southdowns', 'Southdowns', 'southern hemisphere'),
#  ('Prince Said Ibrahim', 'Moroni', 'southern hemisphere'),
#  ('Bandaressalam', 'Moheli', 'southern hemisphere'),
#  ('Ouani', 'Anjouan', 'southern hemisphere'),
#  ('Dzaoudzi Pamandzi', 'Dzaoudzi', 'southern hemisphere'),
#  ('St Denis Gillot', 'St.-denis', 'southern hemisphere'),
#  ('St Pierre Pierrefonds', 'St.-pierre', 'southern hemisphere'),
#  ('Ivato', 'Antananarivo', 'southern hemisphere'),
#  ('Miandrivazo', 'Miandrivazo', 'southern hemisphere'),
#  ('Sainte Marie', 'Sainte Marie', 'southern hemisphere'),
#  ('Toamasina', 'Toamasina', 'southern hemisphere'),
#  ('Morondava', 'Morondava', 'southern hemisphere'),
#  ('Arrachart', 'Antsiranana', 'southern hemisphere'),
#  ('Avaratra', 'Mananara', 'southern hemisphere'),
#  ('Andapa', 'Andapa', 'southern hemisphere'),
#  ('Ambilobe', 'Ambilobe', 'southern hemisphere'),
#  ('Antsirabato', 'Antalaha', 'southern hemisphere'),
#  ('Analalava', 'Analalava', 'southern hemisphere'),
#  ('Philibert Tsiranana', 'Mahajanga', 'southern hemisphere'),
#  ('Fascene', 'Nosy-be', 'southern hemisphere'),
#  ('Besalampy', 'Besalampy', 'southern hemisphere'),
#  ('Maroantsetra', 'Maroantsetra', 'southern hemisphere'),
#  ('Sambava', 'Sambava', 'southern hemisphere'),
#  ('Vohimarina', 'Vohemar', 'southern hemisphere'),
#  ('Ambalabe', 'Antsohihy', 'southern hemisphere'),
#  ('Ampampamena', 'Ampampamena', 'southern hemisphere'),
#  ('Tolagnaro', 'Tolagnaro', 'southern hemisphere'),
#  ('Fianarantsoa', 'Fianarantsoa', 'southern hemisphere'),
#  ('Farafangana', 'Farafangana', 'southern hemisphere'),
#  ('Manakara', 'Manakara', 'southern hemisphere'),
#  ('Mananjary', 'Mananjary', 'southern hemisphere'),
#  ('Morombe', 'Morombe', 'southern hemisphere'),
#  ('Toliara', 'Toliara', 'southern hemisphere'),
#  ('Mbanza Congo', "M'banza-congo", 'southern hemisphere'),
#  ('Benguela', 'Benguela', 'southern hemisphere'),
#  ('Cabinda', 'Cabinda', 'southern hemisphere'),
#  ('Culebra Airport', 'Culebra Island', 'northern hemisphere'),
#  ('Huambo', 'Huambo', 'southern hemisphere'),
#  ('Kuito', 'Kuito', 'southern hemisphere'),
#  ('Lobito', 'Lobito', 'southern hemisphere'),
#  ('Luanda 4 De Fevereiro', 'Luanda', 'southern hemisphere'),
#  ('Malanje', 'Malanje', 'southern hemisphere'),
#  ('Menongue', 'Menongue', 'southern hemisphere'),
#  ('Negage', 'Negage', 'southern hemisphere'),
#  ('Porto Amboim', 'Porto Amboim', 'southern hemisphere'),
#  ('Saurimo', 'Saurimo', 'southern hemisphere'),
#  ('Soyo', 'Soyo', 'southern hemisphere'),
#  ('Lubango', 'Lubango', 'southern hemisphere'),
#  ('Luena', 'Luena', 'southern hemisphere'),
#  ('Uige', 'Uige', 'southern hemisphere'),
#  ('Xangongo', 'Xangongo', 'southern hemisphere'),
#  ('Oyem', 'Oyem', 'northern hemisphere'),
#  ('Okondja', 'Okondja', 'southern hemisphere'),
#  ('Lambarene', 'Lambarene', 'southern hemisphere'),
#  ('Bitam', 'Bitam', 'northern hemisphere'),
#  ('Port Gentil', 'Port Gentil', 'southern hemisphere'),
#  ('Omboue Hopital', 'Omboue Hospial', 'southern hemisphere'),
#  ('Makokou', 'Makokou', 'northern hemisphere'),
#  ('Leon M Ba', 'Libreville', 'northern hemisphere'),
#  ('Mvengue', 'Franceville', 'southern hemisphere'),
#  ('Principe', 'Principe', 'northern hemisphere'),
#  ('Sao Tome Intl', 'Sao Tome', 'northern hemisphere'),
#  ('Beira', 'Beira', 'southern hemisphere'),
#  ('Inhambane', 'Inhambane', 'southern hemisphere'),
#  ('Lichinga', 'Lichinga', 'southern hemisphere'),
#  ('Lumbo', 'Lumbo', 'southern hemisphere'),
#  ('Maputo', 'Maputo', 'southern hemisphere'),
#  ('Mueda', 'Mueda', 'southern hemisphere'),
#  ('Mocimboa Da Praia', 'Mocimboa Da Praia', 'southern hemisphere'),
#  ('Marrupa', 'Marrupa', 'southern hemisphere'),
#  ('Nacala', 'Nacala', 'southern hemisphere'),
#  ('Nampula', 'Nampula', 'southern hemisphere'),
#  ('Pemba', 'Pemba', 'southern hemisphere'),
#  ('Quelimane', 'Quelimane', 'southern hemisphere'),
#  ('Songo', 'Songo', 'southern hemisphere'),
#  ('Tete Chingodzi', 'Tete', 'southern hemisphere'),
#  ('Ulongwe', 'Ulongwe', 'southern hemisphere'),
#  ('Vilankulo', 'Vilankulu', 'southern hemisphere'),
#  ('Alphonse', 'Alphonse', 'southern hemisphere'),
#  ('Desroches', 'Desroches', 'southern hemisphere'),
#  ('Farquhar', 'Farquhar', 'southern hemisphere'),
#  ('Seychelles Intl', 'Mahe', 'southern hemisphere'),
#  ('Praslin', 'Praslin', 'southern hemisphere'),
#  ('Coetivy', 'Coetivy', 'southern hemisphere'),
#  ('Abeche', 'Abeche', 'northern hemisphere'),
#  ('Moundou', 'Moundou', 'northern hemisphere'),
#  ('Ndjamena Hassan Djamous', "N'djamena", 'northern hemisphere'),
#  ('Faya Largeau', 'Faya-largeau', 'northern hemisphere'),
#  ('J M Nkomo Intl', 'Bulawayo', 'southern hemisphere'),
#  ('Charles Prince', 'Harare', 'southern hemisphere'),
#  ('Buffalo Range', 'Chiredzi', 'southern hemisphere'),
#  ('Victoria Falls Intl', 'Victoria Falls', 'southern hemisphere'),
#  ('Harare Intl', 'Harare', 'southern hemisphere'),
#  ('Kariba Intl', 'Kariba', 'southern hemisphere'),
#  ('Mutoko', 'Mutoko', 'southern hemisphere'),
#  ('Mutare', 'Mutare', 'southern hemisphere'),
#  ('Masvingo Intl', 'Masvingo', 'southern hemisphere'),
#  ('Zvishavane', 'Zvishavane', 'southern hemisphere'),
#  ('Gweru Thornhill', 'Gwert', 'southern hemisphere'),
#  ('Hwange National Park', 'Hwange National Park', 'southern hemisphere'),
#  ('Chileka Intl', 'Blantyre', 'southern hemisphere'),
#  ('Karonga', 'Karonga', 'southern hemisphere'),
#  ('Kasungu', 'Kasungu', 'southern hemisphere'),
#  ('Kamuzu Intl', 'Lilongwe', 'southern hemisphere'),
#  ('Mzuzu', 'Mzuzu', 'southern hemisphere'),
#  ...]

# %% [markdown]
# ### Subqueries
#
# For more complex queries it can be helpful to break them down into multiple parts. Subqueries are a natural way to do this.
#
# Suppose I wanted to know, after collecting together the highest airport in each country, which one's name comes alphabetically first.
#
# I might break this down by first collecting the highest airports and then _wrapping_ that query in a higher query that selects the name and country I want _from_ the result of that first query:

# %%
cursor.execute(
"""
SELECT MIN(name), country FROM
(SELECT name, code, country, MAX(CAST(altitude AS INT))
FROM airports
GROUP BY country)
"""
).fetchall()
# Out:
# [('Abha', 'Saudi Arabia')]

# %% [markdown]
# ## Goal 5: Using sql within pandas to filter
#
# `.query()`
#
# [query documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html)

# %%
# Get data for an example
import pandas as pd
shelter_data=pd.read_csv('https://data.austintexas.gov/api/\
views/9t4d-g238/rows.csv?accessType=DOWNLOAD')
shelter_data.dtypes
# Out:
# Animal ID           object
# Name                object
# DateTime            object
# MonthYear           object
# Date of Birth       object
# Outcome Type        object
# Outcome Subtype     object
# Animal Type         object
# Sex upon Outcome    object
# Age upon Outcome    object
# Breed               object
# Color               object
# dtype: object

# %%
shelter_data[shelter_data['Name'] == "Max"].head()
# Out:
#     Animal ID Name                DateTime               MonthYear  \
# 55    A736717  Max  10/21/2016 02:45:00 PM  10/21/2016 02:45:00 PM
# 172   A766116  Max  02/13/2018 11:14:00 AM  02/13/2018 11:14:00 AM
# 410   A688196  Max  09/16/2014 12:20:00 PM  09/16/2014 12:20:00 PM
# 540   A579608  Max  07/21/2014 12:43:00 PM  07/21/2014 12:43:00 PM
# 873   A745151  Max  03/13/2017 07:12:00 PM  03/13/2017 07:12:00 PM
#
#     Date of Birth     Outcome Type Outcome Subtype Animal Type  \
# 55     10/16/2013  Return to Owner             NaN         Dog
# 172    02/02/2015  Return to Owner             NaN         Dog
# 410    09/16/2005       Euthanasia       Suffering         Dog
# 540    06/09/2010  Return to Owner             NaN         Dog
# 873    11/13/2016  Return to Owner             NaN         Dog
#
#     Sex upon Outcome Age upon Outcome                     Breed  \
# 55     Neutered Male          3 years                   Pug Mix
# 172    Neutered Male          3 years  Rottweiler/Staffordshire
# 410    Neutered Male          9 years  Jack Russell Terrier Mix
# 540    Neutered Male          4 years    Labrador Retriever Mix
# 873    Neutered Male         3 months       German Shepherd Mix
#
#                Color
# 55     Brown Brindle
# 172         Blue/Tan
# 410  Chocolate/White
# 540      Black/White
# 873            White

# %%
# With .query()

max_data = shelter_data.query('Name == "Max"')
max_data.head()
# Out:
#     Animal ID Name                DateTime               MonthYear  \
# 55    A736717  Max  10/21/2016 02:45:00 PM  10/21/2016 02:45:00 PM
# 172   A766116  Max  02/13/2018 11:14:00 AM  02/13/2018 11:14:00 AM
# 410   A688196  Max  09/16/2014 12:20:00 PM  09/16/2014 12:20:00 PM
# 540   A579608  Max  07/21/2014 12:43:00 PM  07/21/2014 12:43:00 PM
# 873   A745151  Max  03/13/2017 07:12:00 PM  03/13/2017 07:12:00 PM
#
#     Date of Birth     Outcome Type Outcome Subtype Animal Type  \
# 55     10/16/2013  Return to Owner             NaN         Dog
# 172    02/02/2015  Return to Owner             NaN         Dog
# 410    09/16/2005       Euthanasia       Suffering         Dog
# 540    06/09/2010  Return to Owner             NaN         Dog
# 873    11/13/2016  Return to Owner             NaN         Dog
#
#     Sex upon Outcome Age upon Outcome                     Breed  \
# 55     Neutered Male          3 years                   Pug Mix
# 172    Neutered Male          3 years  Rottweiler/Staffordshire
# 410    Neutered Male          9 years  Jack Russell Terrier Mix
# 540    Neutered Male          4 years    Labrador Retriever Mix
# 873    Neutered Male         3 months       German Shepherd Mix
#
#                Color
# 55     Brown Brindle
# 172         Blue/Tan
# 410  Chocolate/White
# 540      Black/White
# 873            White

# %% [markdown]
# ## Goal 6: Transfering from sqlite to pandas

# %% [markdown]
# `.read_sql()`

# %%
import pandas as pd
db_path = os.path.join(data_path,'flights.db')
conn = sqlite3.connect(db_path)
df = pd.read_sql("SELECT * FROM airports LIMIT 50", conn)
df.head()
# Out:
#    index id                        name          city           country code  \
# 0      0  1                      Goroka        Goroka  Papua New Guinea  GKA
# 1      1  2                      Madang        Madang  Papua New Guinea  MAG
# 2      2  3                 Mount Hagen   Mount Hagen  Papua New Guinea  HGU
# 3      3  4                      Nadzab        Nadzab  Papua New Guinea  LAE
# 4      4  5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea  POM
#
#    icao   latitude   longitude altitude offset dst              timezone
# 0  AYGA  -6.081689  145.391881     5282     10   U  Pacific/Port_Moresby
# 1  AYMD  -5.207083    145.7887       20     10   U  Pacific/Port_Moresby
# 2  AYMH  -5.826789  144.295861     5388     10   U  Pacific/Port_Moresby
# 3  AYNZ  -6.569828  146.726242      239     10   U  Pacific/Port_Moresby
# 4  AYPY  -9.443383   147.22005      146     10   U  Pacific/Port_Moresby

# %% [markdown]
# **Exercise for later**:
# Convert one of the earlier queries in the lesson to a pandas data frame

# %%
# !pip install pandasql
# Out:
# Requirement already satisfied: pandasql in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (0.7.3)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from pandasql) (1.1.3)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from pandasql) (1.18.5)
# Requirement already satisfied: sqlalchemy in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from pandasql) (1.3.19)
# Requirement already satisfied: pytz>=2017.2 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from pandas->pandasql) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from pandas->pandasql) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\learn-env\lib\site-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)

# %% [markdown]
# `pandasql` is a library that allows SQL-style querying of `pandas` DataFrames.

# %%
import pandasql

# %%
pandasql.sqldf("SELECT name, code FROM df LIMIT 10", globals())
# Out:
#                          name code
# 0                      Goroka  GKA
# 1                      Madang  MAG
# 2                 Mount Hagen  HGU
# 3                      Nadzab  LAE
# 4  Port Moresby Jacksons Intl  POM
# 5                  Wewak Intl  WWK
# 6                  Narsarsuaq  UAK
# 7                        Nuuk  GOH
# 8           Sondre Stromfjord  SFJ
# 9              Thule Air Base  THU

# %% [markdown]
# ## On Your Own
#
# The [Chinook database](https://github.com/lerocha/chinook-database) is a sample database, representing a digital media store.
#
# You need to create a query that can rank tracks in term of popularity.
#
# The name of the database is `Chinook_Sqlite.sqlite`
#
# Database information:<br>
# - How many tables are in the database?
# - What's the primary key of each table?
# - What foreign keys join the tables together?
# - If you had to draw a schema of how the tables are connected, what would it look like?
#
# To answer the question:<br>
# - What are the max and min dates in the Invoice table?
# - What tables would you need to answer "what is your most popular track?"
# - What values from each table?

# %%
def table_column(query):
    results = cursor.execute(query).description
    return [x[0] for x in results]

# %%
# Getting Started
db_path = os.path.join(data_path, 'Chinook_Sqlite.sqlite')
con = sqlite3.connect(db_path)

# %%
cursor2 = con.cursor()

# %%
cursor2.execute(
"""
SELECT tbl_name
FROM sqlite_master
WHERE type='table'
"""
)

# %%
cursor2.fetchall()
# Out:
# [('Album',),
#  ('Artist',),
#  ('Customer',),
#  ('Employee',),
#  ('Genre',),
#  ('Invoice',),
#  ('InvoiceLine',),
#  ('MediaType',),
#  ('Playlist',),
#  ('PlaylistTrack',),
#  ('Track',)]

# %%
cursor2.execute(
"""
SELECT*FROM Invoice
"""
).description
# Out:
# (('InvoiceId', None, None, None, None, None, None),
#  ('CustomerId', None, None, None, None, None, None),
#  ('InvoiceDate', None, None, None, None, None, None),
#  ('BillingAddress', None, None, None, None, None, None),
#  ('BillingCity', None, None, None, None, None, None),
#  ('BillingState', None, None, None, None, None, None),
#  ('BillingCountry', None, None, None, None, None, None),
#  ('BillingPostalCode', None, None, None, None, None, None),
#  ('Total', None, None, None, None, None, None))

# %%
cursor2.execute(
"""
SELECT MIN(InvoiceDate), MAX(InvoiceDate)
FROM Invoice
"""
).fetchall()
# Out:
# [('2009-01-01 00:00:00', '2013-12-22 00:00:00')]

# %%
cursor2.execute(
"""
SELECT 
FROM Track
"""
).description
# Out:
# (('TrackId', None, None, None, None, None, None),
#  ('Name', None, None, None, None, None, None),
#  ('AlbumId', None, None, None, None, None, None),
#  ('MediaTypeId', None, None, None, None, None, None),
#  ('GenreId', None, None, None, None, None, None),
#  ('Composer', None, None, None, None, None, None),
#  ('Milliseconds', None, None, None, None, None, None),
#  ('Bytes', None, None, None, None, None, None),
#  ('UnitPrice', None, None, None, None, None, None))
